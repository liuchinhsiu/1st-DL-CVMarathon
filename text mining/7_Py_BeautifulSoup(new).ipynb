# %% [markdown]
# # html 語言與 Beautiful Soup

# %% [markdown]
# * 本週開始，我們要介紹網路爬蟲基本方法與技巧。
# * 今天討論 request 與 beautiful soup 的用法，下過討論 regular expression, 是字串處理的進階工具，第三週討論幾個綜合的爬蟲案例。
# * 由於網頁多半以html 語言撰寫，BeuatifulSoup4 是解析html檔案非常好用的工具。因此，值得好好學學。
# * 安裝 python, Anaconda 之後，會自動安裝 BeuatifulSoup4，不須另外安裝。

# %% [markdown]
# #  html file
# * html 是網頁最常見的編寫工具，它的基本特徵是以__成對的tag(標記)__。
# * 這是一個層次井然的語言結構，每個 tag 都有特定的意義，tag 裡面有tag，可以有許多層。
# * 我們的任務是從別人寫好的html網頁中，截取我們要的資料，通常是網址，或文字、數字資料。

# %% [markdown]
# ## 一個很簡單的範例
# * 請檢查各__標記__夾的__內容__是什麼？中間是否有夾著__字串__？是否有定義__屬性__？標記共有幾層？
# * 重要的_標記_有 < TITLE> </TITLE>, < div> </div>, < a> </a>, < p> </p>都是成對顯示。
# * _屬性_ <> 為標記內宣告的變數，例如 < a href="http://somegreatsite1.com">, < P align=justify>, < div class="first">
# * _字串_ 為啟始標記與結束標記內所夾的文字，例如  < a>.....</a>, < p> ..... < /p>

# %%
# html的基本範例，html_doc 是個字串 string, ''' 表長字串
# 注意，成對的 tag，每個tag 都有不同的意義
html_doc='''
<HTML>
    <HEAD><TITLE>標題在這裡</TITLE></HEAD>
    <div class="first">
        <a href="http://somegreatsite1.com" id="link1">Link1</a>關於這個聯結的文字說明
        <a href="http://somegreatsite2.com" id="link2">Link2</a>關於這個聯結的文字說明
        <P align=justify> 這是段落文字，可以很長! </P> 
    </div>
</HTML> 
'''

# %% [markdown]
# ### 稍微複雜一點，真正的網頁遠比這個複雜得多

# %%
# html的基本範例，html_doc 是個字串 string, ''' 表長字串
html_doc='''
<HTML>
<HEAD><TITLE>標題在這裡</TITLE></HEAD>
<BODY BGCOLOR="FFFFFF">
<div class="first">
<a href="http://somegreatsite1.com" id="link1">Link Name1</a>is the first link to another web site
<a href="http://somegreatsite2.com" id="link2">Link Name2</a>is the second link to another web site
<a href="http://somegreatsite3.com" id="link3">Link Name3</a>is the third link to another web site
<P  align=justify> This is a paragraph 1! </P> 
<P  align=justify> This is a paragraph 2! </P> 
</div>    
<div class="second">
Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
<P  align=justify> This is a paragraph 1! </P> 
<P  align=justify> This is a paragraph 2! </P> 
<P> This is a paragraph 3! </P> 
<P> This is a paragraph 4! </P> 
<P> This is a paragraph 5! </p>
</div>  
</BODY>
</HTML> 
'''

# %% [markdown]
# # 借助 BeuautifulSoup 進行資料的剖析與選取

# %% [markdown]
# ## 呼叫 BeautifulSoup 模組 (要注意大小寫)

# %%
from bs4 import BeautifulSoup
import re

# %%
from bs4 import BeautifulSoup
import re

# %%
soup = BeautifulSoup(html_doc, "html.parser")
print(soup)
# Out:
# <html>
# <head><title>標題在這裡</title></head>
# <body bgcolor="FFFFFF">
# <div class="first">
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>is the first link to another web site
# <a href="http://somegreatsite2.com" id="link2">Link Name2</a>is the second link to another web site
# <a href="http://somegreatsite3.com" id="link3">Link Name3</a>is the third link to another web site
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# </div>
# <div class="second">
# Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# <p> This is a paragraph 3! </p>
# <p> This is a paragraph 4! </p>
# <p> This is a paragraph 5! </p>
# </div>
# </body>
# </html>

# %%
# 讀取 string，產生一個 soup object，
# html_doc 是前面我們定義的 string, "html.parser" 告訴 BeautifulSoup 我們要解析 html 文件。
# 煮湯
soup = BeautifulSoup(html_doc,"html.parser")
# 列印 soup object，看起來與前面的string無異，但已被加料了，可以進行許多後續的處理。
print (soup)
# Out:
# <html>
# <head><title>標題在這裡</title></head>
# <body bgcolor="FFFFFF">
# <div class="first">
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>is the first link to another web site
# <a href="http://somegreatsite2.com" id="link2">Link Name2</a>is the second link to another web site
# <a href="http://somegreatsite3.com" id="link3">Link Name3</a>is the third link to another web site
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# </div>
# <div class="second">
# Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# <p> This is a paragraph 3! </p>
# <p> This is a paragraph 4! </p>
# <p> This is a paragraph 5! </p>
# </div>
# </body>
# </html>

# %% [markdown]
# ## .prettify() 顯示成對的層次結構

# %%
# 顯示層次，但還不是看得很清楚。
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    標題在這裡
#   </title>
#  </head>
#  <body bgcolor="FFFFFF">
#   <div class="first">
#    <a href="http://somegreatsite1.com" id="link1">
#     Link Name1
#    </a>
#    is the first link to another web site
#    <a href="http://somegreatsite2.com" id="link2">
#     Link Name2
#    </a>
#    is the second link to another web site
#    <a href="http://somegreatsite3.com" id="link3">
#     Link Name3
#    </a>
#    is the third link to another web site
#    <p align="justify">
#     This is a paragraph 1!
#    </p>
#    <p align="justify">
#     This is a paragraph 2!
#    </p>
#   </div>
#   <div class="second">
#    Send me mail at
#    <a href="mailto:support@yourcompany.com">
#     support@yourcompany.com
#    </a>
#    <p align="justify">
#     This is a paragraph 1!
#    </p>
#    <p align="justify">
#     This is a paragraph 2!
#    </p>
#    <p>
#     This is a paragraph 3!
#    </p>
#    <p>
#     This is a paragraph 4!
#    </p>
#    <p>
#     This is a paragraph 5!
#    </p>
#   </div>
#  </body>
# </html>

# %% [markdown]
# # 重點是要截取資訊

# %% [markdown]
# ## 尋找標記.tag
# * 例如 .a，表示尋找 < a> 標記，並列出其內容。
# * 注意：只顯示找到的第一個的內容

# %%
# 尋找第一個 <a> tag
soup.a
# Out:
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>

# %%
soup.a
# Out:
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>

# %%
# 用 find 指今亦可，結果一樣, 顯示找到的第一個 tag 
soup.find('a')
# Out:
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>

# %%
soup.find('a')
# Out:
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>

# %% [markdown]
# ##  標記內的屬性，href=, id=

# %%
# <a> 內的屬性 href，亦即網址聯結，注意要用中括弧。
soup.a['href']
# Out:
# 'http://somegreatsite1.com'

# %%
#  <a> 內的屬性 id
soup.a['id']
# Out:
# 'link1'

# %% [markdown]
# ## 標記內的字串
# ### 找出 < a>..... < /a>包含的字串，三種方法 .contents,  .string, .text

# %%
# <a> 包夾的字串, list 格式
soup.a.contents
# Out:
# ['Link Name1']

# %%
soup.a.contents
# Out:
# ['Link Name1']

# %%
# <a> 包夾的字串，string 格式
soup.a.string
# Out:
# 'Link Name1'

# %%
soup.a.string
# Out:
# 'Link Name1'

# %%
# 效果一樣，string 格式
soup.a.text
# Out:
# 'Link Name1'

# %%
soup.a.text
# Out:
# 'Link Name1'

# %% [markdown]
# ## < div> 標記的內容

# %%
soup.div
# Out:
# <div class="first">
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>is the first link to another web site
# <a href="http://somegreatsite2.com" id="link2">Link Name2</a>is the second link to another web site
# <a href="http://somegreatsite3.com" id="link3">Link Name3</a>is the third link to another web site
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# </div>

# %%
# 第一個 div 內夾的 string。\n 表跳行符號
soup.div.text
# Out:
# '\nLink Name1is the first link to another web site\nLink Name2is the second link to another web site\nLink Name3is the third link to another web site\n This is a paragraph 1! \n This is a paragraph 2! \n'

# %%
# 取消跳行符號，直接跳行
print (soup.div.text)
# Out:
# Link Name1is the first link to another web site
# Link Name2is the second link to another web site
# Link Name3is the third link to another web site
#  This is a paragraph 1!
#  This is a paragraph 2!

# %% [markdown]
# ## < p> 標記的內容

# %%
# <p> 內有一個屬性 align, 其值為 justify
soup.p
# Out:
# <p align="justify"> This is a paragraph 1! </p>

# %%
# 只顯示包含的 string
soup.p.text
# Out:
# ' This is a paragraph 1! '

# %% [markdown]
# # 找出符合條件的所有內容

# %% [markdown]
# # .find_all() 指令
# * 找出所有合於條件的所有內容，存成 list。

# %% [markdown]
# ##  列出所有的 < a> 的內容，存成 list

# %%
# list
list_a=soup.find_all("a")
print (len(list_a))
print (list_a)
# Out:
# 4
# [<a href="http://somegreatsite1.com" id="link1">Link Name1</a>, <a href="http://somegreatsite2.com" id="link2">Link Name2</a>, <a href="http://somegreatsite3.com" id="link3">Link Name3</a>, <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>]

# %%
list_a = soup.find_all("a")
print(len(list_a))
print(list_a)
# Out:
# 4
# [<a href="http://somegreatsite1.com" id="link1">Link Name1</a>, <a href="http://somegreatsite2.com" id="link2">Link Name2</a>, <a href="http://somegreatsite3.com" id="link3">Link Name3</a>, <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>]

# %%
# 印出找到的第一個聯結
print (list_a[0]['href'])
# Out:
# http://somegreatsite1.com

# %%
# 所有的聯結都印出來
for a in list_a:
    print (a['href'])
# Out:
# http://somegreatsite1.com
# http://somegreatsite2.com
# http://somegreatsite3.com
# mailto:support@yourcompany.com

# %% [markdown]
# ## < p>  印出所有的段落文字

# %%
list_p=soup.find_all("p")
print(list_p)
for p in list_p:
    print(p.text)
# Out:
# [<p align="justify"> This is a paragraph 1! </p>, <p align="justify"> This is a paragraph 2! </p>, <p align="justify"> This is a paragraph 1! </p>, <p align="justify"> This is a paragraph 2! </p>, <p> This is a paragraph 3! </p>, <p> This is a paragraph 4! </p>, <p> This is a paragraph 5! </p>]
#  This is a paragraph 1!
#  This is a paragraph 2!
#  This is a paragraph 1!
#  This is a paragraph 2!
#  This is a paragraph 3!
#  This is a paragraph 4!
#  This is a paragraph 5!

# %%
list_p = soup.find_all('p')
print(list_p)

for p in list_p:
    print(p.text)
# Out:
# [<p align="justify"> This is a paragraph 1! </p>, <p align="justify"> This is a paragraph 2! </p>, <p align="justify"> This is a paragraph 1! </p>, <p align="justify"> This is a paragraph 2! </p>, <p> This is a paragraph 3! </p>, <p> This is a paragraph 4! </p>, <p> This is a paragraph 5! </p>]
#  This is a paragraph 1!
#  This is a paragraph 2!
#  This is a paragraph 1!
#  This is a paragraph 2!
#  This is a paragraph 3!
#  This is a paragraph 4!
#  This is a paragraph 5!

# %% [markdown]
# ## 尋找所有 < div> 下面屬性class為second的東東

# %%
# list
# a= soup.find_all('div')
# print(a)

list_div=soup.find_all("div", {'class':"second"}) #注意{}
print (list_div)
# Out:
# [<div class="second">
# Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# <p> This is a paragraph 3! </p>
# <p> This is a paragraph 4! </p>
# <p> This is a paragraph 5! </p>
# </div>]

# %%
list_div = soup.find_all('div', {'class':'second'})
print(list_div)
# Out:
# [<div class="second">
# Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# <p> This is a paragraph 3! </p>
# <p> This is a paragraph 4! </p>
# <p> This is a paragraph 5! </p>
# </div>]

# %%
# 接續上例，印出 < p> 內的文字，存成 list
paragraph=[]
# 找出所有合於條件的 <div>
list_div=soup.find_all("div", {'class':"second"})
# 如果有找到的話
if len(list_div)>0:
    for li in list_div:    
        # 找出所有的 <p>
        list_p=li.find_all("p")
        for p in list_p:
            # 加入 list
            paragraph.append(p.text)
    print (paragraph)
# Out:
# [' This is a paragraph 1! ', ' This is a paragraph 2! ', ' This is a paragraph 3! ', ' This is a paragraph 4! ', ' This is a paragraph 5! ']

# %%
paragraph = []
list_div = soup.find_all('div', {'class':'second'})
if len(list_div)>0:
    for ln in list_div:
        list_p = ln.find_all('p')
        for p in list_p:
            paragraph.append(p.text)
            
print(paragraph)
# Out:
# [' This is a paragraph 1! ', ' This is a paragraph 2! ', ' This is a paragraph 3! ', ' This is a paragraph 4! ', ' This is a paragraph 5! ']

# %%
# 第一個 div 夾的的 string
list_div[0].text
# Out:
# '\nSend me mail at support@yourcompany.com\n This is a paragraph 1! \n This is a paragraph 2! \n This is a paragraph 3! \n This is a paragraph 4! \n This is a paragraph 5! \n'

# %%
# 比較 .text 與 .contents 的差異 (string 與 list 的差別)
list_div[0].contents
# Out:
# ['\nSend me mail at ',
#  <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>,
#  '\n',
#  <p align="justify"> This is a paragraph 1! </p>,
#  '\n',
#  <p align="justify"> This is a paragraph 2! </p>,
#  '\n',
#  <p> This is a paragraph 3! </p>,
#  '\n',
#  <p> This is a paragraph 4! </p>,
#  '\n',
#  <p> This is a paragraph 5! </p>,
#  '\n']

# %%
# 0 表示 list 裡面的第一個元素。
list_div[0].contents[0]
# Out:
# '\nSend me mail at '

# %% [markdown]
# # 真正的 html檔，手動下載某一篇文章，存成html格式
# * 範例檔 "d:/my python/_news/20180302_這裡要移除 蔣介石銅像變木乃伊.html

# %% [markdown]
# ## step 1 檢查 soup是否成功?

# %%
# 完整檔名，隨便找一個檔測試
path="C:/Users/HSIU/Desktop/108-1/python_ntu/news"
file_name=path +'/'+'20180302_這裡要移除 蔣介石銅像變木乃伊.html'
# 讀取檔案，注意此檔格式為 'big5'，無須 encoding。*****
content = open(file_name,'r').read() 
# print(content)
# 若為 utf-8 則須 encoding
#content = open(file_name,'r',encoding='utf8').read()  

# 開始煮湯
soup = BeautifulSoup(content,"html.parser")
soup

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    聯合知識庫 - 全球最大的中文新聞資料庫平台
#   </title>
#   <link href="/images/newdata/css_2017/css/fontello.css" rel="stylesheet"/>
#   <link href="/images/newdata/css_2017/font-awesome.min.css" rel="stylesheet"/>
#   <!-- // masterslidercss 套件 -->
#   <link href="/images/newdata/css_2017/masterslider.css" rel="stylesheet"/>
#   <link href="/images/newdata/css_2017/style.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div id="container">
#    <!-- // 燈箱遮罩 -->
#    <div class="overlay close">
#    </div>
#    <!-- // 手機左右側滑選單收合遮罩 -->
#    <div class="mob-menu-overlay close">
#    </div>
#    <!-- // header+menu -->
#    <!--#include virtual="inc/header.html" -->
#    <header>
#     <!-- // toprow menu -->
#     <div class="toprow_bar mob-none">
#      <div class="wrapper clearfix">
#       <ul class="toprow">
#        <li>
#         <a href="/udn">
#          全文報紙
#         </a>
#        </li>
#        <li>
#         <a href="/fullpage/">
#          原版報紙
#         </a>
#        </li>
#        <li>
#         <a href="/image/">
#          新聞圖庫
#         </a>
#        </li>
#        <li>
#         <a href="/bsw/">
#          商業周刊
#         </a>
#        </li>
#        <li>
#         <a href="/gvm/">
#          遠見
#         </a>
#        </li>
#        <li>
#         <a href="/brain/">
#          動腦
#         </a>
#        </li>
#        <li>
#         <a href="/video/">
#          影音
#         </a>
#        </li>
#        <li>
#         <a href="/faq/authority.html">
#          授權
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="wrapper top clearfix">
#      <!-- // mobile left+right icon -->
#      <span class="button menu-button-left">
#       <i aria-hidden="true" class="fa fa-reorder">
#       </i>
#      </span>
#      <span class="button menu-button-right">
#       <i aria-hidden="true" class="fa fa-user">
#       </i>
#      </span>
#      <!-- // logo -->
#      <div class="logo-group">
#       <div class="logo">
#        <div class="link clearfix">
#         <a class="data-index" href="/ndapp/Index">
#         </a>
#         <a class="index" href="/ndapp/Index?cp=udn">
#         </a>
#        </div>
#        <img alt="全文報紙資料庫" src="/images/newdata/images_2017/logo.svg" title="全文報紙資料庫"/>
#       </div>
#       <div class="logo-ip">
#        <img alt="定址會員" src="/images/newdata/images_2017/logo-ip.svg" title="定址會員"/>
#       </div>
#      </div>
#      <ul class="menu clearfix">
#       <li>
#        <a class="fa-user-times" href="/ndapp/Logout?toUrl=/udn">
#         登出
#        </a>
#       </li>
#       <li class="question-circle">
#        <a class="fa-question-circle" href="/faq/fulltext.html" target="_blank">
#         常見問題
#        </a>
#       </li>
#       <li class="web-none">
#        <a class="fa-info-circle popup-btn pop-text" data-popup="聯合知識庫提供之線上資料庫查詢服務，僅供個人閱讀、瀏覽，禁止重製轉載、禁止以程式或機器讀取擷取或下載資料。若有研究分析及其他利用需求，請與我們聯繫授權事宜。" href="">
#         著作權聲明
#        </a>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <div class="print-header-control clearfix">
#     <div class="logo-data">
#      <img alt="聯合知識庫" src="/images/newdata/images_2017/logo.svg" title="聯合知識庫"/>
#     </div>
#     <button class="friendlyPrint">
#      <i aria-hidden="true" class="fa fa-print">
#      </i>
#      友善列印
#     </button>
#    </div>
#    <main>
#     <div class="wrapper clearfix">
#      <!-- // mainbar -->
#      <div class="clearfix" id="mainbar">
#       <!-- // breadcrumb -->
#       <div class="breadcrumb">
#        <a href="/ndapp/Index">
#         首頁
#        </a>
#        <a href="/ndapp/Index?cp=udn">
#         全文報紙資料庫
#        </a>
#        <a href="/ndapp/Searchdec?SearchString=%A7%DC%AA%A7%2B%A4%E9%B4%C1%3E%3D20081005%2B%A4%E9%B4%C1%3C%3D20180913%2B%B3%F8%A7%4F%3D%C1%70%A6%58%B3%F8&amp;select=1&amp;sharepage=20&amp;kind=2&amp;page=10&amp;udndbid=udndata">
#         標題頁
#        </a>
#        <a>
#         內文頁
#        </a>
#       </div>
#       <section class="story">
#        <div class="story-btn-group">
#         <button class="send" onclick="javascript:window.open('/ndapp/FwdArticle?id=8976034&amp;udndbid=udndata&amp;searchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D')">
#          <i aria-hidden="true" class="fa fa-envelope-o">
#          </i>
#          <span class="text">
#           轉寄
#          </span>
#         </button>
#         <button class="mob-none contacts popup-btn pop-html-big-H" data-html="#print">
#          <i aria-hidden="true" class="fa fa-print">
#          </i>
#          列印
#         </button>
#        </div>
#        <div class="story-content" id="print">
#         <div class="story-title">
#          <h2>
#           全國警局唯一留存
#          </h2>
#          <h1>
#           這裡要移除 蔣介石銅像變木乃伊
#          </h1>
#         </div>
#         <span class="story-report">
#          【記者吳淑君、游明煌╱基隆報導】
#         </span>
#         <article>
#          <div class="ms-staff-carousel ms-filters-template pic">
#           <div class="master-slider ms-skin-default" id="masterslider">
#            <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#             <img alt="兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#              <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href="">
#              </a>
#              <div class="ms-layer description" data-duration="100">
#               兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#              </div>
#             </img>
#            </div>
#           </div>
#          </div>
#          <div class="print-pic">
#           <div class="print-pic-img">
#            <img src="/ndapp/ShowSmallPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=">
#            </img>
#           </div>
#           <div class="print-pic-description">
#            兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#           </div>
#          </div>
#          <p>
#           這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來
#           <font color="RED">
#            抗爭
#           </font>
#           。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。
#           <p>
#            市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。
#            <p>
#             游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。
#             <p>
#              基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。
#              <p>
#               基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。
#               <p>
#               </p>
#              </p>
#             </p>
#            </p>
#           </p>
#          </p>
#         </article>
#         <span class="story-source">
#          【2018-03-02/聯合報/B2版/新北基隆要聞】
#         </span>
#        </div>
#       </section>
#       <button class="hide button-color popup-btn pop-html" data-html="#message-1" id="addAuSuccess">
#        狀態一
#       </button>
#       <button class="hide button-color popup-btn pop-text" data-popup="&lt;p&gt;很抱歉！您加入的資料中含有不可授權的資料，無法加入文章線上授權中！&lt;/p&gt;" id="addAuFail">
#        狀態三
#       </button>
#      </div>
#      <!-- // sidebar -->
#      <!-- // 會員資訊+會員服務+功能服務 -->
#      <!--#include virtual="inc/sidebar-service.html" -->
#      <aside class="service">
#       <!-- // 會員資訊 -->
#       <div class="info flex-space-between">
#       </div>
#       <!-- // 會員服務 -->
#       <div class="member">
#        <div class="title">
#         會員服務
#        </div>
#        <a class="fa-unlock popup-btn pop-html-big" data-html="#authority" href="">
#         我可使用的權限
#        </a>
#        <span>
#         <i aria-hidden="true" class="fa fa-database">
#         </i>
#         我可使用的資料庫有
#         <ul>
#          <li>
#           全文報紙資料庫
#          </li>
#         </ul>
#        </span>
#       </div>
#      </aside>
#      <!-- // 我可使用的權限 -->
#      <div class="hide" id="authority">
#       <div class="authority-more">
#        <div class="table-head left">
#         您目前可使用的權限如下
#        </div>
#        <div class="table-border table-row list">
#         <ul class="table-head-two three">
#          <li class="center serve">
#           付費商品
#          </li>
#          <li class="center points">
#           可閱讀則數
#          </li>
#          <li class="center deadline">
#           到期日
#          </li>
#         </ul>
#         <ul class="authority-content">
#          <li>
#           <div class="serve">
#            定址會員-不含圖庫.全頁
#           </div>
#           <div class="points">
#            0
#           </div>
#           <div class="deadline">
#            2018.12.31
#           </div>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <aside class="clearfix" id="sidebar">
#       <hr class="space-5-15"/>
#       <div class="other-news">
#        <div class="title">
#         其他新聞
#        </div>
#        <div class="detail">
#         本頁為
#         <span class="mark">
#          199/6457
#         </span>
#         筆
#        </div>
#        <ul>
#         <li>
#          <a href="/ndapp/Story?no=200&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976038&amp;showUserSearch=&amp;firstFatherCateID=">
#           馬頭山今環評 高市：絕不敷衍放水
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=201&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975999&amp;showUserSearch=&amp;firstFatherCateID=">
#           航空城2512公頃 重納宏竹、兩河？
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=202&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976184&amp;showUserSearch=&amp;firstFatherCateID=">
#           把軍公教政治化，台灣只會更動盪
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=203&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975227&amp;showUserSearch=&amp;firstFatherCateID=">
#           人人都可能成為上校
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=204&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975217&amp;showUserSearch=&amp;firstFatherCateID=">
#           意識形態治國 莫怪陳抗不斷
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=205&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974319&amp;showUserSearch=&amp;firstFatherCateID=">
#           對軍、公教不同調 冒出矛盾
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=206&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974312&amp;showUserSearch=&amp;firstFatherCateID=">
#           軍人年改最終版 待兩院討論
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=207&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974300&amp;showUserSearch=&amp;firstFatherCateID=">
#           八百壯士3訴求：溝通、暫緩、釋憲
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=208&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974316&amp;showUserSearch=&amp;firstFatherCateID=">
#           藍疾呼「別踐踏國軍尊嚴」
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=209&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974269&amp;showUserSearch=&amp;firstFatherCateID=">
#           「維安不力」 質疑聲起
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=210&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974272&amp;showUserSearch=&amp;firstFatherCateID=">
#           維安署長面臨考驗
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=211&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974278&amp;showUserSearch=&amp;firstFatherCateID=">
#           國安問題 軍人年改不可不慎
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=212&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974369&amp;showUserSearch=&amp;firstFatherCateID=">
#           濕地，你們還好嗎？
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=213&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974090&amp;showUserSearch=&amp;firstFatherCateID=">
#           亞泥釋善意 經部促3方會商
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=214&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973396&amp;showUserSearch=&amp;firstFatherCateID=">
#           原保地不拆屋就撤租 承租人抗議
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=215&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973409&amp;showUserSearch=&amp;firstFatherCateID=">
#           加國回補老兵福利 軍改想過嗎
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=216&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971715&amp;showUserSearch=&amp;firstFatherCateID=">
#           說文解字看新聞
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=217&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971916&amp;showUserSearch=&amp;firstFatherCateID=">
#           藍轉戰公投 聚焦反核食、空汙
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=218&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8968607&amp;showUserSearch=&amp;firstFatherCateID=">
#           卡管…卡掉台大多元色彩
#          </a>
#         </li>
#         <li>
#          <a href="/ndapp/Story?no=219&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8963320&amp;showUserSearch=&amp;firstFatherCateID=">
#           等了20年 北大安置住宅入厝
#          </a>
#         </li>
#        </ul>
#       </div>
#      </aside>
#     </div>
#    </main>
#    <!-- // 版權聲明 -->
#    <!--#include virtual="inc/footer.html" -->
#    <footer>
#     <div class="footer-menu mob-none clearfix">
#      <!--
#     <a href="http://co.udn.com/co/index">關於我們</a>
#     <a href="/faq/authority.html">圖文轉載授權</a>
#     <a href="/faq/marketing.html">行銷業務</a>
#     <a href="https://udn.com/page/topic/495">著作權聲明</a>
#     <a href="http://www.udngroup.com/information/privacy">隱私權聲明</a>
#     <a href="https://udn.com/page/topic/185">服務條款</a>
#     <a href="/aboutus.html">udndata介紹</a>
#     <a href="/faq/service.html">客服</a>
# 	-->
#      <script src="/js/footer_data_b.js">
#      </script>
#      <script>
#       ft_t5()
#      </script>
#     </div>
#     <div class="copyright">
#      聯合線上公司 著作權所有 © udn.com All Rights Reserved.
#     </div>
#     <!-- google analytics -->
#     <script>
#      (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-19660006-1', 'auto');
#
# 	ga('create', 'UA-20357535-1', 'auto', {'name': 'udndata'});
#
# 	ga('send', 'pageview');
#
# 	ga('udndata.send', 'pageview');
#     </script>
#     <!-- google analytics -->
#     <!-- TEK1110B0001 -->
#     <!-- Begin comScore Tag -->
#     <script>
#      var _comscore = _comscore || [];
#
# 	  _comscore.push({ c1: "2", c2: "7390954" });
#
# 	  (function() {
#
# 	    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#
# 	    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#
# 	    el.parentNode.insertBefore(s, el);
#
# 	  })();
#     </script>
#     <noscript>
#      <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=7390954&amp;cv=2.0&amp;cj=1">
#      </img>
#     </noscript>
#     <!-- End comScore Tag -->
#    </footer>
#    <!-- // gotop -->
#    <a href="#top" id="gotop">
#     Top
#    </a>
#    <!-- // 公版 -->
#    <div class="popup close">
#     <div class="close-btn btn-right">
#      <i class="i-close">
#      </i>
#     </div>
#     <div class="popup-content">
#     </div>
#     <div class="btn-group-setup center">
#     </div>
#    </div>
#    <!-- // 訊息狀態 demo -->
#    <div class="hide" id="message-1">
#     <div class="message-1">
#      <p class="center">
#       您勾選的資料已成功加入「文章線上授權」！！
#      </p>
#      <div class="btn-group center">
#       <button class="button-close" onclick="javascript: window.location.href='/ndapp/authority/AuIndex'">
#        查看「文章線上授權」
#       </button>
#       <button class="button-close">
#        繼續查詢
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- jquery 主程式 -->
#   <script src="/images/newdata/js_2017/jquery-1.11.1.min.js">
#   </script>
#   <!-- masterslider 主程式 + 設定檔 -->
#   <script src="/images/newdata/js_2017/masterslider.js">
#   </script>
#   <script src="/images/newdata/js_2017/masterslider-setup.js">
#   </script>
#   <!-- jquery 其他程式    -->
#   <script src="/images/newdata/js_2017/openBox.js">
#   </script>
#   <script src="/images/newdata/js_2017/function.js">
#   </script>
#   <script>
#    $(function() {
# /*
# 		$('.add').on('mouseenter mouseleave', function(e) {
#         // console.log(e.target.classList[1]);
#         var event = e.type;
#         // var test = e.target.classList[1]
#
#         if (e.target.classList.contains('select-clipping')) {
#           return false;
#         }
#         // console.log('continue');
#         $('.clipping-pop').hide();
#
#         if (event === 'mouseenter') {
#           $(this).children('.clipping-pop').show();
#           $('.overlay').addClass('opacity');
#           $('.overlay').removeClass('close');
#         } else {
#           $(this).children('.clipping-pop').hide();
#           $('.overlay').removeClass('opacity');
#           $('.overlay').addClass('close');
#         }
#
#       });
#
#       $('.overlay').on('mouseover', function() {
#         // $('.overlay').addClass('close');
#         $('.clipping-pop').hide();
#       });
# */
#      $('.add').on('click', function (e) {
#         var chkThis = e.target === this;
#         var chkSpan = e.target.nodeName.toLowerCase() === 'span';
# 		console.log( e.target.nodeName);
#         var chkFa = e.target.classList.contains('fa-plus-square');
#
#         if (chkThis || chkSpan || chkFa) {
#           $(this).toggleClass('active');
#         }
#       });
#
#       $('.add-clipping, .select-clipping').on('focus', function() {
#         $(this).prev(":radio").prop('checked', true);
#       });
#
#
#
#
#
#
#
#     });
#
# 	//文庫內文頁觀看全頁報紙影像
# 	function checkfull( id, check ) {
# 		if(check=="yes"){
# 			//var ans = window.confirm( "觀看全頁報紙影像需扣儲值點數一點，您要觀看嗎?\n全頁報紙影像僅供觀看，不提供下載功能。\n影像檔輸出速度較慢，請稍待。" );
# 			var ans = window.confirm( "觀看全頁報紙影像需扣可閱讀則數一則，您要觀看嗎?\n全頁報紙影像僅供觀看，不提供下載功能。\n影像檔輸出速度較慢，請稍待。" );
# 			if( ans ) {
# 				window.open( '/ndapp/ShowFullPaper?id=' + id ,'check','scrollbars,resizable=yes,width='+screen.width+','+'height='+screen.height);
# 			}
# 			return false;
# 		}else if(check=="no"){
# 			window.open( '/ndapp/ShowFullPaper?id=' + id ,'check','scrollbars,resizable=yes,width='+screen.width+','+'height='+screen.height);
# 		}
# 	}
#
#
#
#
#     $('.contacts').on('click', function () {
#       $('.popup-content').before("<div class='print-header clearfix'><div class='logo-data'><img src='/images/newdata/images_2017/logo-data.svg' alt='聯合資料庫' title='聯合資料庫'></div><button class='friendlyPrint'><i class='fa fa-print' aria-hidden='true'></i>友善列印</button></div>");
#       $('.pic').hide();
#       $('.print-pic').show();
#     });
#
#     $('body').on('click', '.friendlyPrint', function (e) {
#       $('.print-header').remove();
#       $('.popup, .overlay').addClass('close');
#       $('.popup').removeAttr('style');
#       $('.popup-content, .btn-group-setup').empty();
#       window.print();
#       $('.pic').show();
#       $('.print-pic').hide();
#       $('.friendlyPrint').remove();
#     });
#
#     var printPicW = $('.print-pic-img img').width();
#     var printPicH = $('.print-pic-img img').height();
#     var imgScale = printPicW / printPicH;
#     var originalScale = $('.print-pic-img').width() / $('.print-pic-img img').height();
#
#     if (printPicW > printPicH && imgScale < originalScale) {
#       $('.print-pic-img img').css({ 'width': '100%', 'height': 'auto' });
#     } else {
#       $('.print-pic-img img').css({ 'width': 'auto', 'height': '100%' });
#     }
#   </script>
#  </body>
# </html>

# %%
soup.find_all('div')
# Out:
# [<div id="container">
#  <!-- // 燈箱遮罩 -->
#  <div class="overlay close"></div>
#  <!-- // 手機左右側滑選單收合遮罩 -->
#  <div class="mob-menu-overlay close"></div>
#  <!-- // header+menu -->
#  <!--#include virtual="inc/header.html" -->
#  <header>
#  <!-- // toprow menu -->
#  <div class="toprow_bar mob-none">
#  <div class="wrapper clearfix">
#  <ul class="toprow">
#  <li><a href="/udn">全文報紙</a></li>
#  <li><a href="/fullpage/">原版報紙</a></li>
#  <li><a href="/image/">新聞圖庫</a></li>
#  <li><a href="/bsw/">商業周刊</a></li>
#  <li><a href="/gvm/">遠見</a></li>
#  <li><a href="/brain/">動腦</a></li>
#  <li><a href="/video/">影音</a></li>
#  <li><a href="/faq/authority.html">授權</a></li>
#  </ul>
#  </div>
#  </div>
#  <div class="wrapper top clearfix">
#  <!-- // mobile left+right icon -->
#  <span class="button menu-button-left">
#  <i aria-hidden="true" class="fa fa-reorder"></i>
#  </span>
#  <span class="button menu-button-right">
#  <i aria-hidden="true" class="fa fa-user"></i>
#  </span>
#  <!-- // logo -->
#  <div class="logo-group">
#  <div class="logo">
#  <div class="link clearfix">
#  <a class="data-index" href="/ndapp/Index"></a>
#  <a class="index" href="/ndapp/Index?cp=udn"></a>
#  </div>
#  <img alt="全文報紙資料庫" src="/images/newdata/images_2017/logo.svg" title="全文報紙資料庫"/>
#  </div>
#  <div class="logo-ip">
#  <img alt="定址會員" src="/images/newdata/images_2017/logo-ip.svg" title="定址會員"/>
#  </div>
#  </div>
#  <ul class="menu clearfix">
#  <li>
#  <a class="fa-user-times" href="/ndapp/Logout?toUrl=/udn">登出</a>
#  </li>
#  <li class="question-circle">
#  <a class="fa-question-circle" href="/faq/fulltext.html" target="_blank">常見問題</a>
#  </li>
#  <li class="web-none">
#  <a class="fa-info-circle popup-btn pop-text" data-popup="聯合知識庫提供之線上資料庫查詢服務，僅供個人閱讀、瀏覽，禁止重製轉載、禁止以程式或機器讀取擷取或下載資料。若有研究分析及其他利用需求，請與我們聯繫授權事宜。" href="">著作權聲明</a>
#  </li>
#  </ul>
#  </div>
#  </header>
#  <div class="print-header-control clearfix">
#  <div class="logo-data">
#  <img alt="聯合知識庫" src="/images/newdata/images_2017/logo.svg" title="聯合知識庫"/>
#  </div>
#  <button class="friendlyPrint">
#  <i aria-hidden="true" class="fa fa-print"></i>友善列印</button>
#  </div>
#  <main>
#  <div class="wrapper clearfix">
#  <!-- // mainbar -->
#  <div class="clearfix" id="mainbar">
#  <!-- // breadcrumb -->
#  <div class="breadcrumb"><a href="/ndapp/Index">首頁</a><a href="/ndapp/Index?cp=udn">全文報紙資料庫</a><a href="/ndapp/Searchdec?SearchString=%A7%DC%AA%A7%2B%A4%E9%B4%C1%3E%3D20081005%2B%A4%E9%B4%C1%3C%3D20180913%2B%B3%F8%A7%4F%3D%C1%70%A6%58%B3%F8&amp;select=1&amp;sharepage=20&amp;kind=2&amp;page=10&amp;udndbid=udndata">標題頁</a><a>內文頁</a></div>
#  <section class="story">
#  <div class="story-btn-group">
#  <button class="send" onclick="javascript:window.open('/ndapp/FwdArticle?id=8976034&amp;udndbid=udndata&amp;searchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D')"><i aria-hidden="true" class="fa fa-envelope-o"></i><span class="text">轉寄</span></button>
#  <button class="mob-none contacts popup-btn pop-html-big-H" data-html="#print"> <i aria-hidden="true" class="fa fa-print"></i>列印</button>
#  </div>
#  <div class="story-content" id="print">
#  <div class="story-title">
#  <h2>全國警局唯一留存</h2>
#  <h1>這裡要移除 蔣介石銅像變木乃伊</h1>
#  </div>
#  <span class="story-report">【記者吳淑君、游明煌╱基隆報導】</span>
#  <article>
#  <div class="ms-staff-carousel ms-filters-template pic">
#  <div class="master-slider ms-skin-default" id="masterslider">
#  <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#  <img alt="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#  <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href=""></a>
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>
#  </img></div>
#  </div>
#  </div>
#  <div class="print-pic">
#  <div class="print-pic-img">
#  <img src="/ndapp/ShowSmallPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=">
#  </img></div>
#  <div class="print-pic-description">
#                    	  兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#
#                    </div>
#  </div>
#  <p>這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來<font color="RED">抗爭</font>。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。<p>
#  市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。<p>
#  游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。<p>
#  基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。<p>
#  基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。<p>
#  </p>
#  </p></p></p></p></p></article>
#  <span class="story-source">【2018-03-02/聯合報/B2版/新北基隆要聞】</span>
#  </div>
#  </section>
#  <button class="hide button-color popup-btn pop-html" data-html="#message-1" id="addAuSuccess">狀態一</button>
#  <button class="hide button-color popup-btn pop-text" data-popup="&lt;p&gt;很抱歉！您加入的資料中含有不可授權的資料，無法加入文章線上授權中！&lt;/p&gt;" id="addAuFail">狀態三</button>
#  </div>
#  <!-- // sidebar -->
#  <!-- // 會員資訊+會員服務+功能服務 -->
#  <!--#include virtual="inc/sidebar-service.html" -->
#  <aside class="service">
#  <!-- // 會員資訊 -->
#  <div class="info flex-space-between">
#  </div>
#  <!-- // 會員服務 -->
#  <div class="member">
#  <div class="title">會員服務</div>
#  <a class="fa-unlock popup-btn pop-html-big" data-html="#authority" href="">我可使用的權限</a>
#  <span>
#  <i aria-hidden="true" class="fa fa-database"></i>我可使用的資料庫有
#  		  <ul>
#  <li>全文報紙資料庫</li>
#  </ul>
#  </span>
#  </div>
#  </aside>
#  <!-- // 我可使用的權限 -->
#  <div class="hide" id="authority">
#  <div class="authority-more">
#  <div class="table-head left">您目前可使用的權限如下</div>
#  <div class="table-border table-row list">
#  <ul class="table-head-two three">
#  <li class="center serve">付費商品</li>
#  <li class="center points">可閱讀則數</li>
#  <li class="center deadline">到期日</li>
#  </ul>
#  <ul class="authority-content">
#  <li>
#  <div class="serve">定址會員-不含圖庫.全頁</div>
#  <div class="points">0</div>
#  <div class="deadline">2018.12.31</div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <aside class="clearfix" id="sidebar">
#  <hr class="space-5-15"/>
#  <div class="other-news">
#  <div class="title">其他新聞</div>
#  <div class="detail">本頁為<span class="mark">199/6457</span>筆</div>
#  <ul>
#  <li><a href="/ndapp/Story?no=200&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976038&amp;showUserSearch=&amp;firstFatherCateID=">馬頭山今環評 高市：絕不敷衍放水</a></li>
#  <li><a href="/ndapp/Story?no=201&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975999&amp;showUserSearch=&amp;firstFatherCateID=">航空城2512公頃 重納宏竹、兩河？</a></li>
#  <li><a href="/ndapp/Story?no=202&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976184&amp;showUserSearch=&amp;firstFatherCateID=">把軍公教政治化，台灣只會更動盪</a></li>
#  <li><a href="/ndapp/Story?no=203&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975227&amp;showUserSearch=&amp;firstFatherCateID=">人人都可能成為上校</a></li>
#  <li><a href="/ndapp/Story?no=204&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975217&amp;showUserSearch=&amp;firstFatherCateID=">意識形態治國 莫怪陳抗不斷</a></li>
#  <li><a href="/ndapp/Story?no=205&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974319&amp;showUserSearch=&amp;firstFatherCateID=">對軍、公教不同調 冒出矛盾</a></li>
#  <li><a href="/ndapp/Story?no=206&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974312&amp;showUserSearch=&amp;firstFatherCateID=">軍人年改最終版 待兩院討論</a></li>
#  <li><a href="/ndapp/Story?no=207&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974300&amp;showUserSearch=&amp;firstFatherCateID=">八百壯士3訴求：溝通、暫緩、釋憲</a></li>
#  <li><a href="/ndapp/Story?no=208&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974316&amp;showUserSearch=&amp;firstFatherCateID=">藍疾呼「別踐踏國軍尊嚴」</a></li>
#  <li><a href="/ndapp/Story?no=209&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974269&amp;showUserSearch=&amp;firstFatherCateID=">「維安不力」 質疑聲起</a></li>
#  <li><a href="/ndapp/Story?no=210&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974272&amp;showUserSearch=&amp;firstFatherCateID=">維安署長面臨考驗</a></li>
#  <li><a href="/ndapp/Story?no=211&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974278&amp;showUserSearch=&amp;firstFatherCateID=">國安問題 軍人年改不可不慎</a></li>
#  <li><a href="/ndapp/Story?no=212&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974369&amp;showUserSearch=&amp;firstFatherCateID=">濕地，你們還好嗎？</a></li>
#  <li><a href="/ndapp/Story?no=213&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974090&amp;showUserSearch=&amp;firstFatherCateID=">亞泥釋善意 經部促3方會商</a></li>
#  <li><a href="/ndapp/Story?no=214&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973396&amp;showUserSearch=&amp;firstFatherCateID=">原保地不拆屋就撤租 承租人抗議</a></li>
#  <li><a href="/ndapp/Story?no=215&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973409&amp;showUserSearch=&amp;firstFatherCateID=">加國回補老兵福利 軍改想過嗎</a></li>
#  <li><a href="/ndapp/Story?no=216&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971715&amp;showUserSearch=&amp;firstFatherCateID=">說文解字看新聞</a></li>
#  <li><a href="/ndapp/Story?no=217&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971916&amp;showUserSearch=&amp;firstFatherCateID=">藍轉戰公投 聚焦反核食、空汙</a></li>
#  <li><a href="/ndapp/Story?no=218&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8968607&amp;showUserSearch=&amp;firstFatherCateID=">卡管…卡掉台大多元色彩</a></li>
#  <li><a href="/ndapp/Story?no=219&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8963320&amp;showUserSearch=&amp;firstFatherCateID=">等了20年 北大安置住宅入厝</a></li>
#  </ul>
#  </div>
#  </aside>
#  </div>
#  </main>
#  <!-- // 版權聲明 -->
#  <!--#include virtual="inc/footer.html" -->
#  <footer>
#  <div class="footer-menu mob-none clearfix">
#  <!--
#      <a href="http://co.udn.com/co/index">關於我們</a>
#      <a href="/faq/authority.html">圖文轉載授權</a>
#      <a href="/faq/marketing.html">行銷業務</a>
#      <a href="https://udn.com/page/topic/495">著作權聲明</a>
#      <a href="http://www.udngroup.com/information/privacy">隱私權聲明</a>
#      <a href="https://udn.com/page/topic/185">服務條款</a>
#      <a href="/aboutus.html">udndata介紹</a>
#      <a href="/faq/service.html">客服</a>
#  	-->
#  <script src="/js/footer_data_b.js"></script>
#  <script>ft_t5()</script>
#  </div>
#  <div class="copyright">聯合線上公司 著作權所有 © udn.com All Rights Reserved.</div>
#  <!-- google analytics -->
#  <script>
#
#  	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#
#  	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
#  	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
#  	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#  	ga('create', 'UA-19660006-1', 'auto');
#
#  	ga('create', 'UA-20357535-1', 'auto', {'name': 'udndata'});
#
#  	ga('send', 'pageview');
#
#  	ga('udndata.send', 'pageview');
#
#  	</script>
#  <!-- google analytics -->
#  <!-- TEK1110B0001 -->
#  <!-- Begin comScore Tag -->
#  <script>
#
#  	  var _comscore = _comscore || [];
#
#  	  _comscore.push({ c1: "2", c2: "7390954" });
#
#  	  (function() {
#
#  	    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#
#  	    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#
#  	    el.parentNode.insertBefore(s, el);
#
#  	  })();
#
#  	</script>
#  <noscript>
#  <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=7390954&amp;cv=2.0&amp;cj=1">
#  </img></noscript>
#  <!-- End comScore Tag -->
#  </footer>
#  <!-- // gotop -->
#  <a href="#top" id="gotop">Top</a>
#  <!-- // 公版 -->
#  <div class="popup close">
#  <div class="close-btn btn-right"><i class="i-close"></i></div>
#  <div class="popup-content"></div>
#  <div class="btn-group-setup center"></div>
#  </div>
#  <!-- // 訊息狀態 demo -->
#  <div class="hide" id="message-1">
#  <div class="message-1">
#  <p class="center">您勾選的資料已成功加入「文章線上授權」！！</p>
#  <div class="btn-group center">
#  <button class="button-close" onclick="javascript: window.location.href='/ndapp/authority/AuIndex'">查看「文章線上授權」</button><button class="button-close">繼續查詢</button>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="overlay close"></div>,
#  <div class="mob-menu-overlay close"></div>,
#  <div class="toprow_bar mob-none">
#  <div class="wrapper clearfix">
#  <ul class="toprow">
#  <li><a href="/udn">全文報紙</a></li>
#  <li><a href="/fullpage/">原版報紙</a></li>
#  <li><a href="/image/">新聞圖庫</a></li>
#  <li><a href="/bsw/">商業周刊</a></li>
#  <li><a href="/gvm/">遠見</a></li>
#  <li><a href="/brain/">動腦</a></li>
#  <li><a href="/video/">影音</a></li>
#  <li><a href="/faq/authority.html">授權</a></li>
#  </ul>
#  </div>
#  </div>,
#  <div class="wrapper clearfix">
#  <ul class="toprow">
#  <li><a href="/udn">全文報紙</a></li>
#  <li><a href="/fullpage/">原版報紙</a></li>
#  <li><a href="/image/">新聞圖庫</a></li>
#  <li><a href="/bsw/">商業周刊</a></li>
#  <li><a href="/gvm/">遠見</a></li>
#  <li><a href="/brain/">動腦</a></li>
#  <li><a href="/video/">影音</a></li>
#  <li><a href="/faq/authority.html">授權</a></li>
#  </ul>
#  </div>,
#  <div class="wrapper top clearfix">
#  <!-- // mobile left+right icon -->
#  <span class="button menu-button-left">
#  <i aria-hidden="true" class="fa fa-reorder"></i>
#  </span>
#  <span class="button menu-button-right">
#  <i aria-hidden="true" class="fa fa-user"></i>
#  </span>
#  <!-- // logo -->
#  <div class="logo-group">
#  <div class="logo">
#  <div class="link clearfix">
#  <a class="data-index" href="/ndapp/Index"></a>
#  <a class="index" href="/ndapp/Index?cp=udn"></a>
#  </div>
#  <img alt="全文報紙資料庫" src="/images/newdata/images_2017/logo.svg" title="全文報紙資料庫"/>
#  </div>
#  <div class="logo-ip">
#  <img alt="定址會員" src="/images/newdata/images_2017/logo-ip.svg" title="定址會員"/>
#  </div>
#  </div>
#  <ul class="menu clearfix">
#  <li>
#  <a class="fa-user-times" href="/ndapp/Logout?toUrl=/udn">登出</a>
#  </li>
#  <li class="question-circle">
#  <a class="fa-question-circle" href="/faq/fulltext.html" target="_blank">常見問題</a>
#  </li>
#  <li class="web-none">
#  <a class="fa-info-circle popup-btn pop-text" data-popup="聯合知識庫提供之線上資料庫查詢服務，僅供個人閱讀、瀏覽，禁止重製轉載、禁止以程式或機器讀取擷取或下載資料。若有研究分析及其他利用需求，請與我們聯繫授權事宜。" href="">著作權聲明</a>
#  </li>
#  </ul>
#  </div>,
#  <div class="logo-group">
#  <div class="logo">
#  <div class="link clearfix">
#  <a class="data-index" href="/ndapp/Index"></a>
#  <a class="index" href="/ndapp/Index?cp=udn"></a>
#  </div>
#  <img alt="全文報紙資料庫" src="/images/newdata/images_2017/logo.svg" title="全文報紙資料庫"/>
#  </div>
#  <div class="logo-ip">
#  <img alt="定址會員" src="/images/newdata/images_2017/logo-ip.svg" title="定址會員"/>
#  </div>
#  </div>,
#  <div class="logo">
#  <div class="link clearfix">
#  <a class="data-index" href="/ndapp/Index"></a>
#  <a class="index" href="/ndapp/Index?cp=udn"></a>
#  </div>
#  <img alt="全文報紙資料庫" src="/images/newdata/images_2017/logo.svg" title="全文報紙資料庫"/>
#  </div>,
#  <div class="link clearfix">
#  <a class="data-index" href="/ndapp/Index"></a>
#  <a class="index" href="/ndapp/Index?cp=udn"></a>
#  </div>,
#  <div class="logo-ip">
#  <img alt="定址會員" src="/images/newdata/images_2017/logo-ip.svg" title="定址會員"/>
#  </div>,
#  <div class="print-header-control clearfix">
#  <div class="logo-data">
#  <img alt="聯合知識庫" src="/images/newdata/images_2017/logo.svg" title="聯合知識庫"/>
#  </div>
#  <button class="friendlyPrint">
#  <i aria-hidden="true" class="fa fa-print"></i>友善列印</button>
#  </div>,
#  <div class="logo-data">
#  <img alt="聯合知識庫" src="/images/newdata/images_2017/logo.svg" title="聯合知識庫"/>
#  </div>,
#  <div class="wrapper clearfix">
#  <!-- // mainbar -->
#  <div class="clearfix" id="mainbar">
#  <!-- // breadcrumb -->
#  <div class="breadcrumb"><a href="/ndapp/Index">首頁</a><a href="/ndapp/Index?cp=udn">全文報紙資料庫</a><a href="/ndapp/Searchdec?SearchString=%A7%DC%AA%A7%2B%A4%E9%B4%C1%3E%3D20081005%2B%A4%E9%B4%C1%3C%3D20180913%2B%B3%F8%A7%4F%3D%C1%70%A6%58%B3%F8&amp;select=1&amp;sharepage=20&amp;kind=2&amp;page=10&amp;udndbid=udndata">標題頁</a><a>內文頁</a></div>
#  <section class="story">
#  <div class="story-btn-group">
#  <button class="send" onclick="javascript:window.open('/ndapp/FwdArticle?id=8976034&amp;udndbid=udndata&amp;searchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D')"><i aria-hidden="true" class="fa fa-envelope-o"></i><span class="text">轉寄</span></button>
#  <button class="mob-none contacts popup-btn pop-html-big-H" data-html="#print"> <i aria-hidden="true" class="fa fa-print"></i>列印</button>
#  </div>
#  <div class="story-content" id="print">
#  <div class="story-title">
#  <h2>全國警局唯一留存</h2>
#  <h1>這裡要移除 蔣介石銅像變木乃伊</h1>
#  </div>
#  <span class="story-report">【記者吳淑君、游明煌╱基隆報導】</span>
#  <article>
#  <div class="ms-staff-carousel ms-filters-template pic">
#  <div class="master-slider ms-skin-default" id="masterslider">
#  <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#  <img alt="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#  <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href=""></a>
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>
#  </img></div>
#  </div>
#  </div>
#  <div class="print-pic">
#  <div class="print-pic-img">
#  <img src="/ndapp/ShowSmallPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=">
#  </img></div>
#  <div class="print-pic-description">
#                    	  兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#
#                    </div>
#  </div>
#  <p>這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來<font color="RED">抗爭</font>。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。<p>
#  市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。<p>
#  游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。<p>
#  基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。<p>
#  基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。<p>
#  </p>
#  </p></p></p></p></p></article>
#  <span class="story-source">【2018-03-02/聯合報/B2版/新北基隆要聞】</span>
#  </div>
#  </section>
#  <button class="hide button-color popup-btn pop-html" data-html="#message-1" id="addAuSuccess">狀態一</button>
#  <button class="hide button-color popup-btn pop-text" data-popup="&lt;p&gt;很抱歉！您加入的資料中含有不可授權的資料，無法加入文章線上授權中！&lt;/p&gt;" id="addAuFail">狀態三</button>
#  </div>
#  <!-- // sidebar -->
#  <!-- // 會員資訊+會員服務+功能服務 -->
#  <!--#include virtual="inc/sidebar-service.html" -->
#  <aside class="service">
#  <!-- // 會員資訊 -->
#  <div class="info flex-space-between">
#  </div>
#  <!-- // 會員服務 -->
#  <div class="member">
#  <div class="title">會員服務</div>
#  <a class="fa-unlock popup-btn pop-html-big" data-html="#authority" href="">我可使用的權限</a>
#  <span>
#  <i aria-hidden="true" class="fa fa-database"></i>我可使用的資料庫有
#  		  <ul>
#  <li>全文報紙資料庫</li>
#  </ul>
#  </span>
#  </div>
#  </aside>
#  <!-- // 我可使用的權限 -->
#  <div class="hide" id="authority">
#  <div class="authority-more">
#  <div class="table-head left">您目前可使用的權限如下</div>
#  <div class="table-border table-row list">
#  <ul class="table-head-two three">
#  <li class="center serve">付費商品</li>
#  <li class="center points">可閱讀則數</li>
#  <li class="center deadline">到期日</li>
#  </ul>
#  <ul class="authority-content">
#  <li>
#  <div class="serve">定址會員-不含圖庫.全頁</div>
#  <div class="points">0</div>
#  <div class="deadline">2018.12.31</div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <aside class="clearfix" id="sidebar">
#  <hr class="space-5-15"/>
#  <div class="other-news">
#  <div class="title">其他新聞</div>
#  <div class="detail">本頁為<span class="mark">199/6457</span>筆</div>
#  <ul>
#  <li><a href="/ndapp/Story?no=200&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976038&amp;showUserSearch=&amp;firstFatherCateID=">馬頭山今環評 高市：絕不敷衍放水</a></li>
#  <li><a href="/ndapp/Story?no=201&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975999&amp;showUserSearch=&amp;firstFatherCateID=">航空城2512公頃 重納宏竹、兩河？</a></li>
#  <li><a href="/ndapp/Story?no=202&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976184&amp;showUserSearch=&amp;firstFatherCateID=">把軍公教政治化，台灣只會更動盪</a></li>
#  <li><a href="/ndapp/Story?no=203&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975227&amp;showUserSearch=&amp;firstFatherCateID=">人人都可能成為上校</a></li>
#  <li><a href="/ndapp/Story?no=204&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975217&amp;showUserSearch=&amp;firstFatherCateID=">意識形態治國 莫怪陳抗不斷</a></li>
#  <li><a href="/ndapp/Story?no=205&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974319&amp;showUserSearch=&amp;firstFatherCateID=">對軍、公教不同調 冒出矛盾</a></li>
#  <li><a href="/ndapp/Story?no=206&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974312&amp;showUserSearch=&amp;firstFatherCateID=">軍人年改最終版 待兩院討論</a></li>
#  <li><a href="/ndapp/Story?no=207&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974300&amp;showUserSearch=&amp;firstFatherCateID=">八百壯士3訴求：溝通、暫緩、釋憲</a></li>
#  <li><a href="/ndapp/Story?no=208&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974316&amp;showUserSearch=&amp;firstFatherCateID=">藍疾呼「別踐踏國軍尊嚴」</a></li>
#  <li><a href="/ndapp/Story?no=209&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974269&amp;showUserSearch=&amp;firstFatherCateID=">「維安不力」 質疑聲起</a></li>
#  <li><a href="/ndapp/Story?no=210&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974272&amp;showUserSearch=&amp;firstFatherCateID=">維安署長面臨考驗</a></li>
#  <li><a href="/ndapp/Story?no=211&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974278&amp;showUserSearch=&amp;firstFatherCateID=">國安問題 軍人年改不可不慎</a></li>
#  <li><a href="/ndapp/Story?no=212&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974369&amp;showUserSearch=&amp;firstFatherCateID=">濕地，你們還好嗎？</a></li>
#  <li><a href="/ndapp/Story?no=213&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974090&amp;showUserSearch=&amp;firstFatherCateID=">亞泥釋善意 經部促3方會商</a></li>
#  <li><a href="/ndapp/Story?no=214&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973396&amp;showUserSearch=&amp;firstFatherCateID=">原保地不拆屋就撤租 承租人抗議</a></li>
#  <li><a href="/ndapp/Story?no=215&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973409&amp;showUserSearch=&amp;firstFatherCateID=">加國回補老兵福利 軍改想過嗎</a></li>
#  <li><a href="/ndapp/Story?no=216&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971715&amp;showUserSearch=&amp;firstFatherCateID=">說文解字看新聞</a></li>
#  <li><a href="/ndapp/Story?no=217&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971916&amp;showUserSearch=&amp;firstFatherCateID=">藍轉戰公投 聚焦反核食、空汙</a></li>
#  <li><a href="/ndapp/Story?no=218&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8968607&amp;showUserSearch=&amp;firstFatherCateID=">卡管…卡掉台大多元色彩</a></li>
#  <li><a href="/ndapp/Story?no=219&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8963320&amp;showUserSearch=&amp;firstFatherCateID=">等了20年 北大安置住宅入厝</a></li>
#  </ul>
#  </div>
#  </aside>
#  </div>,
#  <div class="clearfix" id="mainbar">
#  <!-- // breadcrumb -->
#  <div class="breadcrumb"><a href="/ndapp/Index">首頁</a><a href="/ndapp/Index?cp=udn">全文報紙資料庫</a><a href="/ndapp/Searchdec?SearchString=%A7%DC%AA%A7%2B%A4%E9%B4%C1%3E%3D20081005%2B%A4%E9%B4%C1%3C%3D20180913%2B%B3%F8%A7%4F%3D%C1%70%A6%58%B3%F8&amp;select=1&amp;sharepage=20&amp;kind=2&amp;page=10&amp;udndbid=udndata">標題頁</a><a>內文頁</a></div>
#  <section class="story">
#  <div class="story-btn-group">
#  <button class="send" onclick="javascript:window.open('/ndapp/FwdArticle?id=8976034&amp;udndbid=udndata&amp;searchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D')"><i aria-hidden="true" class="fa fa-envelope-o"></i><span class="text">轉寄</span></button>
#  <button class="mob-none contacts popup-btn pop-html-big-H" data-html="#print"> <i aria-hidden="true" class="fa fa-print"></i>列印</button>
#  </div>
#  <div class="story-content" id="print">
#  <div class="story-title">
#  <h2>全國警局唯一留存</h2>
#  <h1>這裡要移除 蔣介石銅像變木乃伊</h1>
#  </div>
#  <span class="story-report">【記者吳淑君、游明煌╱基隆報導】</span>
#  <article>
#  <div class="ms-staff-carousel ms-filters-template pic">
#  <div class="master-slider ms-skin-default" id="masterslider">
#  <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#  <img alt="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#  <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href=""></a>
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>
#  </img></div>
#  </div>
#  </div>
#  <div class="print-pic">
#  <div class="print-pic-img">
#  <img src="/ndapp/ShowSmallPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=">
#  </img></div>
#  <div class="print-pic-description">
#                    	  兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#
#                    </div>
#  </div>
#  <p>這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來<font color="RED">抗爭</font>。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。<p>
#  市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。<p>
#  游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。<p>
#  基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。<p>
#  基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。<p>
#  </p>
#  </p></p></p></p></p></article>
#  <span class="story-source">【2018-03-02/聯合報/B2版/新北基隆要聞】</span>
#  </div>
#  </section>
#  <button class="hide button-color popup-btn pop-html" data-html="#message-1" id="addAuSuccess">狀態一</button>
#  <button class="hide button-color popup-btn pop-text" data-popup="&lt;p&gt;很抱歉！您加入的資料中含有不可授權的資料，無法加入文章線上授權中！&lt;/p&gt;" id="addAuFail">狀態三</button>
#  </div>,
#  <div class="breadcrumb"><a href="/ndapp/Index">首頁</a><a href="/ndapp/Index?cp=udn">全文報紙資料庫</a><a href="/ndapp/Searchdec?SearchString=%A7%DC%AA%A7%2B%A4%E9%B4%C1%3E%3D20081005%2B%A4%E9%B4%C1%3C%3D20180913%2B%B3%F8%A7%4F%3D%C1%70%A6%58%B3%F8&amp;select=1&amp;sharepage=20&amp;kind=2&amp;page=10&amp;udndbid=udndata">標題頁</a><a>內文頁</a></div>,
#  <div class="story-btn-group">
#  <button class="send" onclick="javascript:window.open('/ndapp/FwdArticle?id=8976034&amp;udndbid=udndata&amp;searchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D')"><i aria-hidden="true" class="fa fa-envelope-o"></i><span class="text">轉寄</span></button>
#  <button class="mob-none contacts popup-btn pop-html-big-H" data-html="#print"> <i aria-hidden="true" class="fa fa-print"></i>列印</button>
#  </div>,
#  <div class="story-content" id="print">
#  <div class="story-title">
#  <h2>全國警局唯一留存</h2>
#  <h1>這裡要移除 蔣介石銅像變木乃伊</h1>
#  </div>
#  <span class="story-report">【記者吳淑君、游明煌╱基隆報導】</span>
#  <article>
#  <div class="ms-staff-carousel ms-filters-template pic">
#  <div class="master-slider ms-skin-default" id="masterslider">
#  <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#  <img alt="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#  <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href=""></a>
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>
#  </img></div>
#  </div>
#  </div>
#  <div class="print-pic">
#  <div class="print-pic-img">
#  <img src="/ndapp/ShowSmallPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=">
#  </img></div>
#  <div class="print-pic-description">
#                    	  兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#
#                    </div>
#  </div>
#  <p>這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來<font color="RED">抗爭</font>。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。<p>
#  市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。<p>
#  游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。<p>
#  基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。<p>
#  基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。<p>
#  </p>
#  </p></p></p></p></p></article>
#  <span class="story-source">【2018-03-02/聯合報/B2版/新北基隆要聞】</span>
#  </div>,
#  <div class="story-title">
#  <h2>全國警局唯一留存</h2>
#  <h1>這裡要移除 蔣介石銅像變木乃伊</h1>
#  </div>,
#  <div class="ms-staff-carousel ms-filters-template pic">
#  <div class="master-slider ms-skin-default" id="masterslider">
#  <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#  <img alt="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#  <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href=""></a>
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>
#  </img></div>
#  </div>
#  </div>,
#  <div class="master-slider ms-skin-default" id="masterslider">
#  <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#  <img alt="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#  <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href=""></a>
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>
#  </img></div>
#  </div>,
#  <div class="ms-slide" data-delay="1" data-fill-mode="fit">
#  <img alt="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="/images/newdata/images_2017/masterslider/blank.gif" title="兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。">
#  <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href=""></a>
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>
#  </img></div>,
#  <div class="ms-layer description" data-duration="100">
#  	                       		兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
#  	                      </div>,
#  <div class="print-pic">
#  <div class="print-pic-img">
#  <img src="/ndapp/ShowSmallPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=">
#  </img></div>
#  <div class="print-pic-description">
#                    	  兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#
#                    </div>
#  </div>,
#  <div class="print-pic-img">
#  <img src="/ndapp/ShowSmallPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=">
#  </img></div>,
#  <div class="print-pic-description">
#                    	  兩樣情
#  基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#
#                    </div>,
#  <div class="info flex-space-between">
#  </div>,
#  <div class="member">
#  <div class="title">會員服務</div>
#  <a class="fa-unlock popup-btn pop-html-big" data-html="#authority" href="">我可使用的權限</a>
#  <span>
#  <i aria-hidden="true" class="fa fa-database"></i>我可使用的資料庫有
#  		  <ul>
#  <li>全文報紙資料庫</li>
#  </ul>
#  </span>
#  </div>,
#  <div class="title">會員服務</div>,
#  <div class="hide" id="authority">
#  <div class="authority-more">
#  <div class="table-head left">您目前可使用的權限如下</div>
#  <div class="table-border table-row list">
#  <ul class="table-head-two three">
#  <li class="center serve">付費商品</li>
#  <li class="center points">可閱讀則數</li>
#  <li class="center deadline">到期日</li>
#  </ul>
#  <ul class="authority-content">
#  <li>
#  <div class="serve">定址會員-不含圖庫.全頁</div>
#  <div class="points">0</div>
#  <div class="deadline">2018.12.31</div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="authority-more">
#  <div class="table-head left">您目前可使用的權限如下</div>
#  <div class="table-border table-row list">
#  <ul class="table-head-two three">
#  <li class="center serve">付費商品</li>
#  <li class="center points">可閱讀則數</li>
#  <li class="center deadline">到期日</li>
#  </ul>
#  <ul class="authority-content">
#  <li>
#  <div class="serve">定址會員-不含圖庫.全頁</div>
#  <div class="points">0</div>
#  <div class="deadline">2018.12.31</div>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="table-head left">您目前可使用的權限如下</div>,
#  <div class="table-border table-row list">
#  <ul class="table-head-two three">
#  <li class="center serve">付費商品</li>
#  <li class="center points">可閱讀則數</li>
#  <li class="center deadline">到期日</li>
#  </ul>
#  <ul class="authority-content">
#  <li>
#  <div class="serve">定址會員-不含圖庫.全頁</div>
#  <div class="points">0</div>
#  <div class="deadline">2018.12.31</div>
#  </li>
#  </ul>
#  </div>,
#  <div class="serve">定址會員-不含圖庫.全頁</div>,
#  <div class="points">0</div>,
#  <div class="deadline">2018.12.31</div>,
#  <div class="other-news">
#  <div class="title">其他新聞</div>
#  <div class="detail">本頁為<span class="mark">199/6457</span>筆</div>
#  <ul>
#  <li><a href="/ndapp/Story?no=200&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976038&amp;showUserSearch=&amp;firstFatherCateID=">馬頭山今環評 高市：絕不敷衍放水</a></li>
#  <li><a href="/ndapp/Story?no=201&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975999&amp;showUserSearch=&amp;firstFatherCateID=">航空城2512公頃 重納宏竹、兩河？</a></li>
#  <li><a href="/ndapp/Story?no=202&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976184&amp;showUserSearch=&amp;firstFatherCateID=">把軍公教政治化，台灣只會更動盪</a></li>
#  <li><a href="/ndapp/Story?no=203&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975227&amp;showUserSearch=&amp;firstFatherCateID=">人人都可能成為上校</a></li>
#  <li><a href="/ndapp/Story?no=204&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975217&amp;showUserSearch=&amp;firstFatherCateID=">意識形態治國 莫怪陳抗不斷</a></li>
#  <li><a href="/ndapp/Story?no=205&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974319&amp;showUserSearch=&amp;firstFatherCateID=">對軍、公教不同調 冒出矛盾</a></li>
#  <li><a href="/ndapp/Story?no=206&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974312&amp;showUserSearch=&amp;firstFatherCateID=">軍人年改最終版 待兩院討論</a></li>
#  <li><a href="/ndapp/Story?no=207&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974300&amp;showUserSearch=&amp;firstFatherCateID=">八百壯士3訴求：溝通、暫緩、釋憲</a></li>
#  <li><a href="/ndapp/Story?no=208&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974316&amp;showUserSearch=&amp;firstFatherCateID=">藍疾呼「別踐踏國軍尊嚴」</a></li>
#  <li><a href="/ndapp/Story?no=209&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974269&amp;showUserSearch=&amp;firstFatherCateID=">「維安不力」 質疑聲起</a></li>
#  <li><a href="/ndapp/Story?no=210&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974272&amp;showUserSearch=&amp;firstFatherCateID=">維安署長面臨考驗</a></li>
#  <li><a href="/ndapp/Story?no=211&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974278&amp;showUserSearch=&amp;firstFatherCateID=">國安問題 軍人年改不可不慎</a></li>
#  <li><a href="/ndapp/Story?no=212&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974369&amp;showUserSearch=&amp;firstFatherCateID=">濕地，你們還好嗎？</a></li>
#  <li><a href="/ndapp/Story?no=213&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974090&amp;showUserSearch=&amp;firstFatherCateID=">亞泥釋善意 經部促3方會商</a></li>
#  <li><a href="/ndapp/Story?no=214&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973396&amp;showUserSearch=&amp;firstFatherCateID=">原保地不拆屋就撤租 承租人抗議</a></li>
#  <li><a href="/ndapp/Story?no=215&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973409&amp;showUserSearch=&amp;firstFatherCateID=">加國回補老兵福利 軍改想過嗎</a></li>
#  <li><a href="/ndapp/Story?no=216&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971715&amp;showUserSearch=&amp;firstFatherCateID=">說文解字看新聞</a></li>
#  <li><a href="/ndapp/Story?no=217&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971916&amp;showUserSearch=&amp;firstFatherCateID=">藍轉戰公投 聚焦反核食、空汙</a></li>
#  <li><a href="/ndapp/Story?no=218&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8968607&amp;showUserSearch=&amp;firstFatherCateID=">卡管…卡掉台大多元色彩</a></li>
#  <li><a href="/ndapp/Story?no=219&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8963320&amp;showUserSearch=&amp;firstFatherCateID=">等了20年 北大安置住宅入厝</a></li>
#  </ul>
#  </div>,
#  <div class="title">其他新聞</div>,
#  <div class="detail">本頁為<span class="mark">199/6457</span>筆</div>,
#  <div class="footer-menu mob-none clearfix">
#  <!--
#      <a href="http://co.udn.com/co/index">關於我們</a>
#      <a href="/faq/authority.html">圖文轉載授權</a>
#      <a href="/faq/marketing.html">行銷業務</a>
#      <a href="https://udn.com/page/topic/495">著作權聲明</a>
#      <a href="http://www.udngroup.com/information/privacy">隱私權聲明</a>
#      <a href="https://udn.com/page/topic/185">服務條款</a>
#      <a href="/aboutus.html">udndata介紹</a>
#      <a href="/faq/service.html">客服</a>
#  	-->
#  <script src="/js/footer_data_b.js"></script>
#  <script>ft_t5()</script>
#  </div>,
#  <div class="copyright">聯合線上公司 著作權所有 © udn.com All Rights Reserved.</div>,
#  <div class="popup close">
#  <div class="close-btn btn-right"><i class="i-close"></i></div>
#  <div class="popup-content"></div>
#  <div class="btn-group-setup center"></div>
#  </div>,
#  <div class="close-btn btn-right"><i class="i-close"></i></div>,
#  <div class="popup-content"></div>,
#  <div class="btn-group-setup center"></div>,
#  <div class="hide" id="message-1">
#  <div class="message-1">
#  <p class="center">您勾選的資料已成功加入「文章線上授權」！！</p>
#  <div class="btn-group center">
#  <button class="button-close" onclick="javascript: window.location.href='/ndapp/authority/AuIndex'">查看「文章線上授權」</button><button class="button-close">繼續查詢</button>
#  </div>
#  </div>
#  </div>,
#  <div class="message-1">
#  <p class="center">您勾選的資料已成功加入「文章線上授權」！！</p>
#  <div class="btn-group center">
#  <button class="button-close" onclick="javascript: window.location.href='/ndapp/authority/AuIndex'">查看「文章線上授權」</button><button class="button-close">繼續查詢</button>
#  </div>
#  </div>,
#  <div class="btn-group center">
#  <button class="button-close" onclick="javascript: window.location.href='/ndapp/authority/AuIndex'">查看「文章線上授權」</button><button class="button-close">繼續查詢</button>
#  </div>]

# %% [markdown]
# ## 先想想要讀取什麼資料？

# %%
# 讀取標題，h1,h2,h3,h4
# 在 tag "div", 屬性 class = story-title
list_div=soup.find_all("div", {'class':"story-title"})
if len(list_div)>0:
    for div in list_div:
        try:
            h1=div.h1.text
        except:
            h1=''
        try:
            h2=div.h2.text
        except:    
            h2=''
        try:    
            h3=div.h3.text
        except:
            h3=''
        try:    
            h4=div.h4.text
        except:
            h4=''        
print (h1)
print (h2)
print (h3)
print (h4)

# 讀取作者
# 在 tab "span", 屬性 class = story-title
list_span=soup.find_all("span", {'class':"story-report"})
if len(list_span)>0:
    author=list_span[0].text
print (author)

# 讀取時間及版次    
# 在 tab "span", 屬性 class = story-source
list_span=soup.find_all("span", {'class':"story-source"})
if len(list_span)>0:
    time=list_span[0].text
print (time)

# 讀取內文
# 在 tab "p"
list_p=soup.find_all("p")
for p in list_p:
    print(p.text)
# Out:
# 這裡要移除 蔣介石銅像變木乃伊
# 全國警局唯一留存
#
#
# 【記者吳淑君、游明煌╱基隆報導】
# 【2018-03-02/聯合報/B2版/新北基隆要聞】
# 這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來抗爭。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。
# 市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。
# 游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。
# 基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。
# 基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。
#
#
#
# 市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。
# 游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。
# 基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。
# 基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。
#
#
#
# 游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。
# 基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。
# 基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。
#
#
#
# 基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。
# 基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。
#
#
#
# 基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。
#
#
#
#
# 您勾選的資料已成功加入「文章線上授權」！！

# %% [markdown]
# ## 多個 html 檔
# * 這是聯合報有關抗爭的文章，92篇。都放在 d:/My python/_news/ 下面

# %%
import os
import re
path="C:/Users/HSIU/Desktop/108-1/python_ntu"
# List 記錄所有的檔名
doc_list = []
# 指定資料夾
os.chdir(path+'/news') #改變工作目錄的路徑
# 找出所有.html 檔
for f in os.listdir("."):
    # 檔案篩選
     if f.endswith(".html"):
#             print(f)
#         第一個字母會是亂碼，先去除    
        f=re.sub("\ufeff","",f)        
        doc_list.append(f)       
print (len(doc_list))
doc_list
# Out:
# 92
# ['20180101_許悔之、許含光 父子的咖啡對談.html',
#  '20180102_港萬人遊行 反高鐵一地兩檢.html',
#  '20180103_臨會審總預算 藍擬提200 刪減凍結案.html',
#  '20180103_遭點名換將 六部全否認.html',
#  '20180104_北檢潑髒水 把證人當犯人.html',
#  '20180104_徵農地建滯洪池 農民嘉縣府前抗議.html',
#  '20180104_監院糾正政院、勞動部.html',
#  '20180105_下周一 夜宿立院 勞團不排除激烈行動.html',
#  '20180205_卡在濕地、保安林、特農區.html',
#  '20180205_窮人的快速公路 紅燈、車禍多 用路人又愛又恨.html',
#  '20180205_經費排擠、抗爭不斷 西濱快速路變調.html',
#  '20180205_西濱快速路 30年未完工.html',
#  '20180206_反過勞公投連署 有望跨第一階段門檻.html',
#  '20180207_黎明溝整治 打造會呼吸的河川.html',
#  '20180209_青創進駐民治議事廳？地方反對.html',
#  '20180211_只靠名嘴動嘴皮 國民黨繼續在野吧！.html',
#  '20180211_等了20年 北大安置住宅入厝.html',
#  '20180221_卡管…卡掉台大多元色彩.html',
#  '20180225_藍轉戰公投 聚焦反核食、空汙.html',
#  '20180225_說文解字看新聞.html',
#  '20180227_加國回補老兵福利 軍改想過嗎.html',
#  '20180227_原保地不拆屋就撤租 承租人抗議.html',
#  '20180228_「維安不力」 質疑聲起.html',
#  '20180228_亞泥釋善意 經部促3方會商.html',
#  '20180228_八百壯士3訴求：溝通、暫緩、釋憲.html',
#  '20180228_國安問題 軍人年改不可不慎.html',
#  '20180228_對軍、公教不同調 冒出矛盾.html',
#  '20180228_濕地，你們還好嗎？.html',
#  '20180228_維安署長面臨考驗.html',
#  '20180228_藍疾呼「別踐踏國軍尊嚴」.html',
#  '20180228_軍人年改最終版 待兩院討論.html',
#  '20180301_人人都可能成為上校.html',
#  '20180301_意識形態治國 莫怪陳抗不斷.html',
#  '20180302_把軍公教政治化，台灣只會更動盪.html',
#  '20180302_航空城2512公頃 重納宏竹、兩河？.html',
#  '20180302_這裡要移除 蔣介石銅像變木乃伊.html',
#  '20180302_馬頭山今環評 高市：絕不敷衍放水.html']

# %% [markdown]
#   # 測試成功，讀取多篇文章

# %%
head=[]
author=[]
time=[]
texts=[]
i=0
h1=[]
h2=[]
h3=[]
h4=[]
# 讀取各篇文章，成為一個 list
for f in doc_list: 
    i+=1
    # 完整檔名，隨便找一個檔測試
    file_name=path +'/news/'+ f
    # 讀取檔案，注意格式為 'big5'，無毋 encoding。*****
    content = open(file_name,'r').read()  
    # 煮湯
    soup = BeautifulSoup(content,"html.parser")

    # 讀取標題，h1,h2,h3,h4
    list_div=soup.find_all("div", {'class':"story-title"})
    if len(list_div)>0:
        for div in list_div:
            try:
                h1=div.h1.text
            except:
                h1=''
            try:
                 h2=div.h2.text
            except:    
                h2=''
            try:    
                 h3=div.h3.text
            except:
                h3=''
            try:    
                 h4=div.h4.text
            except:
                h4=''   
                
        head.append(h1+h2+h3+h4)
        # 讀取作者
        list_span=soup.find_all("span", {'class':"story-report"})
        if len(list_span)>0:
            string=list_span[0].text
            # 去掉特殊符號
            string=re.sub("【","",string)
            string=re.sub("】","",string)  
            author.append(string)
        else:
            author.append('')

        # 讀取時間及版次    
        list_span=soup.find_all("span", {'class':"story-source"})
        if len(list_span)>0:
            string=list_span[0].text
            # 去掉特殊符號
            string=re.sub("【","",string)
            string=re.sub("】","",string)  
            time.append(string)
        else:
            time.append('')

        # 讀取內文
        string=''
        list_p=soup.find_all("p")
        for p in list_p:
            string=string+p.text
            
        # 異體字轉換
        string=re.sub("台","臺",string)         
        # 刪除中文的空格符號，這些看起來像是亂碼先刪除
        string=re.sub("\ufeff","",string)
        string=re.sub("\u3000","",string)            
            
        texts.append(string)    
    # 每處理完10篇文章，報告進度。******    
    if i%10==0:
        print (i, 'done')
    elif i==len(doc_list):
        print ('finished')
        
print(texts)
# Out:
# 10 done
# 20 done
# 30 done
# 40 done
# 50 done
# 60 done
# 70 done
# 80 done
# 90 done
# finished
# ['對詩人許悔之和歌手許含光來說，這一場難得的咖啡約會，是創作人的對話，也是父子間的「告解」，「這是父子間永遠甜蜜又有張力的地方。」\n詩人玩笑地用了一個大白話：「今天，恩怨做個了結。」\n許氏栽培 超越階級\n父子都有新作，老爸出了新書「我的強迫症」，兒子推出首張創作專輯「曖曖」，呈現方式不同，創作的本質接近。許悔之疼兒子，一再說：「多寫Lumi。」卻總是忍不住長篇大論，許含光則是在爸爸暫離座時，才會突然活潑起來。典型的父子。\n「我跟他母親有點超出階級在養他。但我知道他有才華。」許悔之數著兒子會鋼琴、小提琴，維也納音樂學院想收、10幾分鐘的「流浪者之歌」幾次就記住譜，「我告訴他，我不有錢，如果你願意，我會努力，但人生的抉擇，要你自己走。」\n只要兒子選的，老爸就挺。當年髮禁解除，國一的許含光留長髮被保守的學校關切，大詩人到學校抗爭；有老師寫信來提到性別認同云云，許悔之揚言提告。\n「後來我們父子有一段對話，就是創作者永遠有跟時代交鋒的難題，如果你要，我會繼續為你奮戰，但是有一天，你要為自己奮戰，只是有的時候要付出代價。」他說，如果兒子還想為頭髮抗爭，老爸可以再次出馬，嚇得許含光忙說：「爸，你不要再來了。」\n結果學古典樂的許含光，現在以長髮造型，出了首張流行專輯，有如集合了自己會的所有曲彙，在父親看來，有民謠、有Blues，更偏英式搖滾，有一點Radiohead、一點U2，煙嗓帶點迷幻搖滾，像早期Pink Floyd、The Doors主唱Jim Morrison，「是沒那麼偉大啦，但就像一個年輕人的第一本詩集，就會什麼都想弄進去。」\n「我其實蠻哀怨的，因為有些朋友都先聽過了。」許悔之這「星爸」，很晚才拿到兒子的作品聽。\n許含光誠實說，不想把音樂或任何作品主動給爸爸看，不是因為他是詩人，「而是以父子的角度，就是不想把日記給爸爸看。」反正老爸不小心看到，會自己過來點評，像許悔之就覺得歌詞該押韻。\n尼采、體制、搖滾 父子交心\n許悔之珍惜著與兒子的三個重要時刻。其一是，國一的許含光突然問：「請問你的尼采都放在哪裡？」被這超齡問題嚇到的老爸，出借了尼采專書與「查拉圖斯特拉如是說」。\n幾天後，許含光又問：「爸，你覺得什麼是體制？」許悔之覺得這是堪比魯迅被問「有沒有靈魂」一樣的哲學問題，於是反問兒子的答案。少年回答：「就是你們這些大人設的制度和規矩。」\n「這件事情對我很有啟發。」許悔之想到自己也是國中開始想叛逆，「等衝突很大時，就會想開始創作，創作變成你跟這個世界的情歌、情詩。Lumi的那段話，是我跟他這20多年來最重要的時刻。」\n聽到這件往事，許含光笑：「小時候想讀一些很
都是我很珍貴的時刻。」\n悔之老師 「寫詩沒我好」\n許悔之形容創作：「是對這世界很精緻的瘋狂、很細膩的不滿。創作者像精衛填海，一首歌、一首詩，像一顆石頭，可以把自己心海填平，把世界變美。」\n安靜的許含光聽了又笑：「悔之老師喜歡講話很凝重，小孩子聽了壓力就很大。」他對外人，常常以「悔之老師」指涉老爸，就是從「好玩」變成「習慣」的稱呼。\n但許含光不免被問到會不會拿爸爸的詩入歌。在一次父執輩聚會的場合，他一句「不會，因為我的詩寫得比他好」，害許悔之嚷「這是這輩子最大的傷害」。他當然懂這只是年輕人的玩笑。\n許悔之一點都不希望兒子變詩人：「寫詩很可憐，還是做歌手好。雖然他的詩真的寫得好，只比我差一點，他是有老靈魂的新世代。」 ...

# %%
import pandas as pd   
data=list(zip(head,author,time,texts))
df=pd.DataFrame(data,columns=['title','author','time','text'])
df
# Out:
#                                                 title  \
# 0                                許悔之、許含光 父子的咖啡對談詩人與歌手
# 1   港萬人遊行 反高鐵一地兩檢廣深港高鐵 香港段終點採陸式查驗 民陣搭講台批評 抗議隊伍在政府大...
# 2   臨會審總預算 藍擬提200 刪減凍結案民進黨團將勞基法修正案列第一優先 內容「幾乎沒協商空間...
# 3                                         遭點名換將 六部全否認
# 4                                  北檢潑髒水 把證人當犯人周泓旭共諜案
# 5                                    徵農地建滯洪池 農民嘉縣府前抗議
# 6                     監院糾正政院、勞動部「一例一休 輕率修法」勞方、資方、政府三輸
# 7                                  下周一 夜宿立院 勞團不排除激烈行動
# 8    時力鏈鎖議場 民進黨破門反制反對修勞基法 國民黨團揚言文攻 備七百案修正動議 時力赴總統府前靜坐
# 9                                 盟友反目 朝野還有協商空間？《冷眼集》
# 10                                濕地立法三年 基金沒編半毛中央能量不足
# 11                              立委上街 警柔性勸導准出不准進 暫時不驅離
# 12              勞基法再戰府院堅持「往前走」民進黨團盼今開始協商「時力若不來 是他們的事」
# 13      勞基鬥法 立院臨會延燒民進黨堅持修法 蔡與時力溝通未果 十餘勞團今夜宿立院 籲立即停止修法
# 14               國民黨攜時力 聯合作戰？藍委：只有問一下 徐永明：會尊重、考量國民黨動作
# 15                                封鎖國會大戲：一面權力的照妖鏡《社論》
# 16                         綠委守大門「身心俱疲」風雨交加 蚊子偷襲 睡不安穩…
# 17                                  蔡籲協商 時力拒絕蔡總統回信洪慈庸
# 18                                    別低估「政治危機」《新聞分析》
# 19          勞基法今強行表決？藍準備武鬥國民黨設定底線不能在周三前完成三讀 朝野恐爆發肢體衝突
# 20                             勞基鬥法 今拚3讀時力退出協商、勞團臥軌北車
# 21                      勞工抗議史第3度臥軌交部強烈譴責 勞團：民意被拒馬圍在外面
# 22                                    時力被帶離 柯Ｐ：SOP會更多
# 23                            7休1改為14休4 拍板勞基法修法 抗爭中完成
# 24                                      勞團喊：我們心沉痛丟鞋嗆聲
# 25                                       抗爭博版面 手腳被看破！
# 26                                       抗爭為勞工 算計又如何？
# 27                      綠奇招 擋藍案海戰術國民黨批詐術  質疑「變形一事不二議」
# # 下載一個真正的網頁 html

# %% [markdown]
# ## 觀察網頁的程式碼

# %% [markdown]
# ### 現在的流覽器都有提供網頁原始碼檢查工具。以下，我們就用 Crome 簡單解說。
# * 首先，找到目標網頁，開啟網頁。
# * 第二，流覽網頁，看看它有什麼內容，每個聯結按一按，確定你定要擷取的資訊位置在哪裡。
# * 第三，在你要的資訊上面，滑鼠右鍵，選擇 [檢查網頁原始碼]，或[檢查] (inspection), 兩者都試試看，比較其差異。這個時候你會看到網頁的原始碼，找到目標資訊出現的位置。特別注意你要下載的資料前面的標記(tag)是什麼？其前後的標記是什麼？
# * 第四，每行程式左邊的「三角形」鍵頭，可開啟、縮合，便於顯示不同的層級。
# * 第五，左側頁面與右側程式相互對應，滑鼠移至左側圖面上的任何元件，滑鼠右鍵[檢查]，可看到相應的程式碼。滑鼠移至左側程式碼，相應的網頁畫面在右側會以色塊標示。
# * 第六，選按[network], 再 refresh 網頁，可以看到網頁登載的元件，以及各個子聯結的清單，按 [headers], [preview], [rsponse] 可以檢查各個聯結的內容。這可以幫助我們判斷我們要的資訊是位於哪個子聯結。這些子聯結都可以複製，便於進一步的分析。
# * 第七、很多網頁因為資訊太多，都有分頁的設計，點選 [下一頁] 看看網頁的結構是否有變化，變化的規則是什麼。
# * 第八、如果你要一次擷取多個網頁的資料，要注意各網頁的格式是否統一，如果不統一，就要撰寫適用各種情況的程式，否則會讀取錯誤。你會發現，資料格式不統一，通常是網路爬蟲很大的困擾。
# * 第九、Beautiful Soup 通常要配合 Regular Expression 一起使用，下一個講次，我們會討論， Regular Expression。

# %% [markdown]
# ## 先進去網頁，檢查網頁的結構
# * 資料在哪一個 tag 下面？
# * 是否必須到下一個聯結？
# * 聯結命名的規則？
# * 下一頁的網址命名規則？
# * get or post ? 本週我們只介紹 get
# * 動態或靜態 ? 本週只介紹靜態網頁。

# %% [markdown]
# * 現在我們要試試真正的網頁，咱們台大的首頁 http://www.nd.ntu.edu.tw/
# * 裡面有許許多多的資料，我們要選擇自己要的東西。

# %% [markdown]
# ## 方法一：使用 urllib.request.urlopen()

# %%
# beautiful soup
import urllib
import urllib.request
from bs4 import BeautifulSoup
import io
import os
import json
import re

# %%
# 國發所首頁
url='http://www.nd.ntu.edu.tw/'
# request.urlopen()提出進入網頁的要求
thepage=urllib.request.urlopen(url)
# 產生一個 soup object
soup=BeautifulSoup(thepage,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="orbit" lang="zh_tw">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/uploads/site/favicon/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    國立臺灣大學國家發展研究所
#   </title>
#   <link href="/assets/fontawesome/font-awesome-25cef4302d1b8fc05d28ac847626ecf3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/bootstrap/bootstrap-c07da65a73e80a09cabdf7a174a0635e.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/template/template-371b47ba8210ddd35fbd86df9516c51f.css" media="screen" rel="stylesheet"/>
#   <script src="/assets/lib/jquery-1.11.0.min-2cf9b70a257975f2833f682170097171.js">
#   </script>
#   <script src="/assets/bootstrap-c33cd72c8e754f012f5a68e0da4ad2db.js">
#   </script>
#   <script src="/assets/plugin/modernizr-b53b2a89dfd7a6d30aacfd4bd61ed506.js">
#   </script>
#   <script src="/assets/plugin/jquery-bullseye-min-695b302cc70f7f0277388c8759c2f01c.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.min-0181da5907c893e384e384f8ad2946de.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.video.min-8064c0652b44b69572d3ac653bedd6bd.js">
#   </script>
#   <script src="/assets/app-76e2704a8fa6c4fa895f3d420a243c56.js">
#   </script>
#   <script src="/assets/frontend-8338adc0c5e32b6d28215ca591059bb9.js">
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/assets/plugin/html5shiv-f1c171a5086388761a3fb837a304070b.js"></script>
#     <script src="/assets/plugin/response.min-ba150f83ff9f8a3cf90f406ddbaecef7.js"></script>
#   <![endif]-->
#   <link href="/assets/basic/icon" media="screen" rel="stylesheet"/>
#   <link href="/assets/lib/orbit_bar/orbit-bar" media="screen" rel="stylesheet"/>
#  </head>
#  <body class="page-home" data-module="home">
#   <div id="orbit-bar">
#    <input id="open-orbit-login" type="checkbox"/>
#    <label class="cover" for="open-orbit-login">
#    </label>
#    <div class="login-window">
#     <div class="login-header">
#      <label class="close" for="open-orbit-login">
#       ×
#      </label>
#      <h3>
#       登入 Orbit
#      </h3>
#     </div>
#     <div class="login-body">
#      <form accept-charset="UTF-8" action="/sessions?locale=zh_tw" class="container" method="post">
#       <div style="display:none">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="JQNz78LM4gNIQbZ1qUUVL5Y5vxS+5mQgcwFgo9wF5m4="/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-user">
#         </i>
#        </span>
#        <input class="input" id="user_user_id" name="user_name" placeholder="使用者帳號" size="30" title="username" type="text"/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-lock">
#         </i>
#        </span>
#        <input class="input" id="user_password" name="password" placeholder="密碼" size="30" type="password"/>
#       </div>
#       <div class="login-submit-wrap">
#        <div class="submit">
#         <button class="login-btn" type="submit">
#          登入
#         </button>
#        </div>
#       </div>
#       <div class="login-sign-up-btn">
#        <a href="/users/new" rel="nofollow">
#         Sign up now
#        </a>
#       </div>
#      </form>
#     </div>
#    </div>
#    <input id="open-orbit-nav" type="checkbox"/>
#    <div class="orbit-bar-inner">
#     <label for="open-orbit-nav">
#      <i class="icons-list-2">
#      </i>
#     </label>
#     <h2 class="orbit-bar-title">
#      <a href="/">
#       Orbit
#      </a>
#     </h2>
#     <ul class="orbit-bar-menu">
#      <li>
#       <span class="orbit-bar-logo">
#        <img alt="Orbit Bar Logo" src="/uploads/site/default_image/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg"/>
#       </span>
#      </li>
#      <li>
#       <a class="orbit-bar-home" href="/">
#        <i class="icons-house">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <ul class="orbit-bar-search-sign-language">
#      <li>
#       <form action="http://www.google.com/custom" id="search" method="get" target="_blank">
#        <input name="client" type="hidden" value="pub-&amp;amp"/>
#        <input id="ie" name="ie" type="hidden" value="utf-8"/>
#        <input id="oe" name="oe" type="hidden" value="utf-8"/>
#        <input id="cof" name="cof" type="hidden" value="AH:center;AWFID:03de271f1940eea3;"/>
#        <input name="domains" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input name="sitesearch" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input id="q" name="q" placeholder="全站搜尋" type="search" value="" x-webkit-speech=""/>
#       </form>
#      </li>
#      <li>
#       <span id="language">
#        <i class="icons-earth orbit-bar-language-icon">
#        </i>
#        <span class="orbit-bar-language-text">
#         Language
#        </span>
#       </span>
#       <ul>
#        <li class="active">
#         繁體中文
#        </li>
#        <li>
#         <a accesskey="s" href="/?locale=zh_cn">
#          简体中文
#         </a>
#        </li>
#        <li class="">
#         <a accesskey="e" href="/?locale=en">
#          English
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a accesskey="L" class="sr-only" href="/zh_tw/accesskey" id="accesskey_login" title="Login">
#        :::
#       </a>
#       <label for="open-orbit-login">
#        <i class="icons-login">
#        </i>
#       </label>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <script type="text/javascript">
#    $("#open-orbit-login").on("change",function(){
#     if($(this).is(":checked")){
#       $("#user_user_id").focus();
#     }
#   })
#   $(".login-body form").on("submit",function(){
#     $(this).append("<input type='hidden' name='referer_url' value='http://www.nd.ntu.edu.tw/'/>");
#   })
#   var I18n = {
#     get locale(){ return "zh_tw"},
#     get validLocales(){return ["zh_tw","en","zh_cn"]},
#     set locale(v){return false},
#     set validLocales(v){return false}
#   };
#   </script>
#   <div class="body">
#    <div class="wrap">
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <script>
#      !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="https://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#     </script>
#     <header class="header">
#      <div id="button">
#      </div>
#      <div class="header-nav">
#      </div>
#      <div class="header_branding">
#       <h1 class="header_title">
#        <a class="header-home" href="/">
#         <img class="site-logo" src="/uploads/site/site_logo/54db068a7470001bc5180000/Facebook-20150416-023619.jpg"/>
#         國立臺灣大學國家發展研究所
#        </a>
#       </h1>
#      </div>
#      <nav class="menu">
#       <div class="menu2">
#        <ul class="page_menu level_1" data-menu-level="0">
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/announcement" target="_self">
#           公告
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/news" target="_self">
#             最新消息
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/seminar_lecture" target="_self">
#             學術活動
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/scholarships" target="_self">
#             獎學金資訊
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/conference" target="_self">
#             研討會
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/ndf" target="_self">
#             國家發展論壇
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/about" target="_self">
#           本所簡介
#          </a>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/member" target="_self">
#           本所成員
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/director" target="_self">
#             所長專區
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/teacher" target="_self">
#             師資陣容
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/staff" target="_self">
#             行政人員
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/phd" target="_self">
#           博士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/calendar" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/entry" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/attendance" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/phd_thesis" target="_self">
#             博士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/forms" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/qa_phd" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/master" target="_self">
#           碩士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/calendar_m" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/entry_m" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/attendance_m" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/m_thesis" target="_self">
#             碩士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/form_m" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/qa_m" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/emba" target="_self">
#           碩士在職專班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/programs" target="_self">
#             特色課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/calendar_e" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/entry_e" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/attendance_e" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/e_thesis" target="_self">
#             在職專班論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/form_e" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/qa_e" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/speaking_corner" target="_self">
#           口試專區
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral" target="_self">
#             論文研究計畫口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_papers" target="_self">
#             論文口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_form" target="_self">
#             口試表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/qa_o" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/course" target="_self">
#           課程
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_p_m" target="_self">
#             博碩士班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/Course_em" target="_self">
#             碩專班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_calendar" target="_self">
#             歷年課程
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/alumni" target="_self">
#           所友會
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/history" target="_self">
#             歷史沿革
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/framework" target="_self">
#             組織架構
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/notes" target="_self">
#             會議資料
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/status" target="_self">
#             所友動態
#            </a>
#            <ul class="page_menu level_3" data-menu-level="2">
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_001" target="_self">
#               所友動態_001
#              </a>
#             </li>
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_002" target="_self">
#               所友動態_002
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="http://www.ntu.edu.tw" target="_blank">
#           臺大首頁
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <div class="banner">
#       <div class="banner_slide" data-pp="310">
#        <div class="w-ad-banner ad-banner-widget-3" data-subpart-id="54e18eaa747000394d5d0000">
#         <div class="w-ad-banner__wrap cycle-slideshow" data-cycle-log="false" data-cycle-slides=".w-ad-banner__slide" data-level="0" data-list="images" data-pager=".w-ad-banner__pager" data-pager-active-class="active-slide" data-pager-template="&lt;li&gt;&lt;a href='#'&gt;&lt;/a&gt;&lt;/li&gt;">
#          <div class="w-ad-banner__slide active" data-link="http://www.rulingcom.com">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e24747000394d2e0000/01.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e2d747000394d320000/02.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e38747000394d360000/03.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e40747000394d3a0000/04.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e49747000394d3e0000/05.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e54747000394d420000/06.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e68747000394d470000/07.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e71747000394d4b0000/08.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e7b747000394d4f0000/09.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e83747000394d530000/10.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e8e747000394d570000/12.jpg"/>
#          </div>
#         </div>
#         <ul class="w-ad-banner__pager">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class="main">
#      <div class="home">
#       <div class="left_column news">
#        <div class="page_content" data-pp="1">
#         <div class="w-annc widget-announcement-13" data-subpart-id="54e2af0874700073d72b0000">
#          <h3 class="w-annc__widget-title">
#           <span>
#           </span>
#          </h3>
#          <div class="w-annc__inner">
#           <ul class="w-annc__list" data-level="0" data-list="announcements">
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-11-06
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/108-11-07-%E5%9B%9B-%E6%89%80%E9%95%B7%E6%99%82%E9%96%93%E6%94%B9%E6%96%BC%E4%B8%8B%E5%8D%882%E6%99%82%E8%87%B33%E6%99%82-21571357">
#                108/11/07 (四)所長時間改於下午2時至3時
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-11-01
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%94%84%E8%A9%A6%E7%AC%A6%E5%90%88%E5%8F%A3%E8%A9%A6%E8%B3%87%E6%A0%BC%E5%90%8D%E5%96%AE%E6%9A%A8%E5%8F%A3%E8%A9%A6%E5%A0%B4%E6%AC%A1%E8%A1%A8-13985054">
#                109學年度碩士班甄試符合口試資格名單暨口試場次表
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-28
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/-%E7%95%A2%E6%A5%AD%E5%9C%98%E6%8B%8D-107%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%95%A2%E6%A5%AD%E5%9C%98%E6%8B%8D%E8%AA%BF%E6%9F%A5%E8%A1%A8%E5%96%AE%E5%A1%AB%E5%A0%B1-%E8%87%B3108-10-30%E6%97%A5%E6%AD%A2-44296179">
#                【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-28
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/-%E5%85%AC%E5%91%8A-109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E6%8B%9B%E7%94%9F%E7%B0%A1%E7%AB%A0%E8%80%83%E7%A7%91%E7%95%B0%E5%8B%95-71061959">
#                【公告】109學年度碩士班招生簡章考科異動
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-18
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/108-10-26-%E5%85%AD-109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%94%84%E8%A9%A6%E6%8B%9B%E7%94%9F%E7%AD%86%E8%A9%A6%E8%A9%A6%E5%A0%B4-%E5%9C%8B%E7%99%BC%E6%89%80206%E6%95%99%E5%AE%A4-71326222">
#                108/10/26(六)109學年度碩士班甄試招生筆試試場：國發所206教室
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-01
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/%E6%9C%AC%E6%A0%A1%E5%AD%B8%E5%8B%99%E8%99%95%E5%85%AC%E5%91%8A%E7%9B%B8%E9%97%9C%E8%A8%8A%E6%81%AF-26367168">
#                本校學務處公告相關訊息
#               </a>
#              </h4>
#             </div>
#            </li>
#           </ul>
#          </div>
#          <div class="w-annc__more">
#           <a href="/zh_tw/announcement">
#            Read more
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="en_left_column" data-pp="8">
#       </div>
#       <div class="main_column">
#        <div class="summit-wrap">
#         <div class="page_content" data-pp="2">
#          <div class="w-annc widget-announcement-13" data-subpart-id="54e2af4474700073d7310000">
#           <h3 class="w-annc__widget-title">
#            <span>
#
">
#           <h3 class="w-annc__widget-title">
#            <span>
#             獎助學金資訊
#            </span>
#           </h3>
#           <div class="w-annc__inner">
#            <ul class="w-annc__list" data-level="0" data-list="announcements">
#             <li class="w-annc__item">
#              <div class="w-annc__content">
#               <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#                <span class="w-annc__postdate">
#                 2019-10-22
#                </span>
#               </span>
#               <h4 class="w-annc__entry-title">
#                <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#                </span>
#                <a class="w-annc__title" href="/zh_tw/announcement/108%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%AC%AC1%E5%AD%B8%E6%9C%9F%E7%94%9F%E6%B4%BB%E5%AD%B8%E7%BF%92%E5%8A%A9%E5%AD%B8%E9%87%91%E5%AF%A9%E6%A0%B8%E7%B5%90%E6%9E%9C%E5%85%AC%E5%91%8A-4586872">
#                 108學年度第1學期生活學習助學金審核結果公告
#                </a>
#               </h4>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="w-annc__more">
#            <a href="/zh_tw/announcement">
#             Read more
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="right_column">
#        <div class="user_modify">
#         <div class="page_content" data-pp="44">
#          <div class="w-annc widget-announcement-5" data-subpart-id="556ec13c6e74755528720000">
#           <h3 class="w-annc__widget-title">
#            <span>
#             國家發展論壇
#            </span>
#           </h3>
#           <ul class="w-annc__list row" data-level="0" data-list="announcements">
#           </ul>
#           <div class="w-annc__more">
#            <a href="/zh_tw/summit_news_all">
#             Read more
#            </a>
#           </div>
#          </div>
#          <table border="0" cellpadding="1" cellspacing="1" style="width:240px;">
#           <tbody>
#            <tr>
#             <td>
#              <h2>
#               <br/>
#               <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#                國家發展研究期刊
#               </a>
#              </h2>
#              <a href="www.nd.ntu.edu.tw/zh_tw/nds" style="font-family: arial; font-size: 18px; line-height: 21.6px;">
#               National Development Studie
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <div>
#           <table>
#            <tbody>
#             <tr>
#              <td class="title">
#               <span style="font-size:16px;">
#                研究中心群
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td class="info">
#               <p>
#                <span style="font-size:9px;">
#                 <a href="/zh_tw/CSR">
#                  兩岸關係中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SES">
#                  國家經濟安全研究中心
#                 </a>
#                 <br/>
#                 <a href="http://140.112.176.185/spatial/excel2earth.html">
#                  空間分析工作室
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/marinepolicy">
#                  海洋政策研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/Law_Socio">
#                  法律與文化研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SR">
#                  科技政策與全球化風險治理中心
#                 </a>
#                </span>
#                <br/>
#                <a href="https://sites.google.com/view/ntundcrcc/">
#                 <span style="font-size: 12px;">
#                  區域合作暨競爭力研究中心
#                 </span>
#                </a>
#               </p>
#               <h4>
#               </h4>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#         </div>
#        </div>
#        <div class="publication hide">
#         <div class="page_content" data-pp="4">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               國家發展研究期刊
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               National Development Studies
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="institute hide">
#         <div class="page_content" data-pp="5">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              研究中心群
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="/zh_tw/CSR">
#               兩岸關係
#              </a>
#              <a href="/zh_tw/SES">
#               國家經濟安全研究
#              </a>
#              <a href="https://www.facebook.com/pages/Excel2Earth/383852245125712?fref=ts">
#               空間分析
#              </a>
#              <a href="/zh_tw/marinepolicy">
#               海洋政策研究
#              </a>
#              <a href="/zh_tw/Hakka">
#               客家研究
#              </a>
#              <a href="/zh_tw/Law_Socio">
#               法律與社會研究
#              </a>
#              <a href="/zh_tw/SR">
#               科技政策與全球化風險治理
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="event hide">
#         <div class="page_content" data-pp="6">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               國家發展論壇
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               Forum of National Developments
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="mailbox hide">
#         <div class="page_content" data-pp="7">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <footer class="footer">
#      <div class="footer-inner">
#       <div class="footer_address">
#        Copyright © 2014 國立臺灣大學國家發展研究所 Graduate Institute of National Development, National Taiwan University
#        <br/>
#        10617 臺北市大安區羅斯福路四段1號 （辛亥復興路口側門進入） No. 1, Sec. 4, Roosevelt Road, Taipei, 10617 Taiwan(R.O.C)
#        <br/>
#        電話 (Phone)：+886-2-3366-3333  傳真 (Fax)：+886-2-2367-6176  E-mail：ndintu@ntu.edu.tw
#       </div>
#       <div class="footer-site-counter">
#        造訪人次 : 727510
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## 方法二：使用 requests.get()
# * 可處理 get, post 兩種模式，前者直接請求，後者要附加引數才能請求。
# * 在網頁上按左鍵，inspection, network, reflesh, 選擇網頁，Herders 可查得 request method
# * post 要有 form data 才能 request，form data 可從網頁上查得。

# %%
import requests
from bs4 import BeautifulSoup
url="http://www.nd.ntu.edu.tw/"
# 有 get 與 post 兩種模式，要從網頁上 inspect，本範例為 get
response = requests.get (url)
# 用 BeatifulSoup 解析 HTML 並把結果回傳 soup
soup = BeautifulSoup (response.text, "lxml") #lxml?
#lxml 套件: lxml 套件是用來作為 BeautifulSoup 的解析器（Parser），BeautifulSoup 可以支援的解析器其實不只一種，還有 html.parser（Python 內建）與 html5lib，根據官方文件的推薦，我們使用解析速度最快的 lxml。
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="orbit" lang="zh_tw">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/uploads/site/favicon/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    國立臺灣大學國家發展研究所
#   </title>
#   <link href="/assets/fontawesome/font-awesome-25cef4302d1b8fc05d28ac847626ecf3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/bootstrap/bootstrap-c07da65a73e80a09cabdf7a174a0635e.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/template/template-371b47ba8210ddd35fbd86df9516c51f.css" media="screen" rel="stylesheet"/>
#   <script src="/assets/lib/jquery-1.11.0.min-2cf9b70a257975f2833f682170097171.js">
#   </script>
#   <script src="/assets/bootstrap-c33cd72c8e754f012f5a68e0da4ad2db.js">
#   </script>
#   <script src="/assets/plugin/modernizr-b53b2a89dfd7a6d30aacfd4bd61ed506.js">
#   </script>
#   <script src="/assets/plugin/jquery-bullseye-min-695b302cc70f7f0277388c8759c2f01c.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.min-0181da5907c893e384e384f8ad2946de.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.video.min-8064c0652b44b69572d3ac653bedd6bd.js">
#   </script>
#   <script src="/assets/app-76e2704a8fa6c4fa895f3d420a243c56.js">
#   </script>
#   <script src="/assets/frontend-8338adc0c5e32b6d28215ca591059bb9.js">
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/assets/plugin/html5shiv-f1c171a5086388761a3fb837a304070b.js"></script>
#     <script src="/assets/plugin/response.min-ba150f83ff9f8a3cf90f406ddbaecef7.js"></script>
#   <![endif]-->
#   <link href="/assets/basic/icon" media="screen" rel="stylesheet"/>
#   <link href="/assets/lib/orbit_bar/orbit-bar" media="screen" rel="stylesheet"/>
#  </head>
#  <body class="page-home" data-module="home">
#   <div id="orbit-bar">
#    <input id="open-orbit-login" type="checkbox"/>
#    <label class="cover" for="open-orbit-login">
#    </label>
#    <div class="login-window">
#     <div class="login-header">
#      <label class="close" for="open-orbit-login">
#       ×
#      </label>
#      <h3>
#       登入 Orbit
#      </h3>
#     </div>
#     <div class="login-body">
#      <form accept-charset="UTF-8" action="/sessions?locale=zh_tw" class="container" method="post">
#       <div style="display:none">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="QzFcNTaNkZesYCYxD4y7k3woDP9K8Vnz2eQOxJ0zgzQ="/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-user">
#         </i>
#        </span>
#        <input class="input" id="user_user_id" name="user_name" placeholder="使用者帳號" size="30" title="username" type="text"/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-lock">
#         </i>
#        </span>
#        <input class="input" id="user_password" name="password" placeholder="密碼" size="30" type="password"/>
#       </div>
#       <div class="login-submit-wrap">
#        <div class="submit">
#         <button class="login-btn" type="submit">
#          登入
#         </button>
#        </div>
#       </div>
#       <div class="login-sign-up-btn">
#        <a href="/users/new" rel="nofollow">
#         Sign up now
#        </a>
#       </div>
#      </form>
#     </div>
#    </div>
#    <input id="open-orbit-nav" type="checkbox"/>
#    <div class="orbit-bar-inner">
#     <label for="open-orbit-nav">
#      <i class="icons-list-2">
#      </i>
#     </label>
#     <h2 class="orbit-bar-title">
#      <a href="/">
#       Orbit
#      </a>
#     </h2>
#     <ul class="orbit-bar-menu">
#      <li>
#       <span class="orbit-bar-logo">
#        <img alt="Orbit Bar Logo" src="/uploads/site/default_image/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg"/>
#       </span>
#      </li>
#      <li>
#       <a class="orbit-bar-home" href="/">
#        <i class="icons-house">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <ul class="orbit-bar-search-sign-language">
#      <li>
#       <form action="http://www.google.com/custom" id="search" method="get" target="_blank">
#        <input name="client" type="hidden" value="pub-&amp;amp"/>
#        <input id="ie" name="ie" type="hidden" value="utf-8"/>
#        <input id="oe" name="oe" type="hidden" value="utf-8"/>
#        <input id="cof" name="cof" type="hidden" value="AH:center;AWFID:03de271f1940eea3;"/>
#        <input name="domains" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input name="sitesearch" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input id="q" name="q" placeholder="全站搜尋" type="search" value="" x-webkit-speech=""/>
#       </form>
#      </li>
#      <li>
#       <span id="language">
#        <i class="icons-earth orbit-bar-language-icon">
#        </i>
#        <span class="orbit-bar-language-text">
#         Language
#        </span>
#       </span>
#       <ul>
#        <li class="active">
#         繁體中文
#        </li>
#        <li>
#         <a accesskey="s" href="/?locale=zh_cn">
#          简体中文
#         </a>
#        </li>
#        <li class="">
#         <a accesskey="e" href="/?locale=en">
#          English
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a accesskey="L" class="sr-only" href="/zh_tw/accesskey" id="accesskey_login" title="Login">
#        :::
#       </a>
#       <label for="open-orbit-login">
#        <i class="icons-login">
#        </i>
#       </label>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <script type="text/javascript">
#    $("#open-orbit-login").on("change",function(){
#     if($(this).is(":checked")){
#       $("#user_user_id").focus();
#     }
#   })
#   $(".login-body form").on("submit",function(){
#     $(this).append("<input type='hidden' name='referer_url' value='http://www.nd.ntu.edu.tw/'/>");
#   })
#   var I18n = {
#     get locale(){ return "zh_tw"},
#     get validLocales(){return ["zh_tw","en","zh_cn"]},
#     set locale(v){return false},
#     set validLocales(v){return false}
#   };
#   </script>
#   <div class="body">
#    <div class="wrap">
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <script>
#      !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="https://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#     </script>
#     <header class="header">
#      <div id="button">
#      </div>
#      <div class="header-nav">
#      </div>
#      <div class="header_branding">
#       <h1 class="header_title">
#        <a class="header-home" href="/">
#         <img class="site-logo" src="/uploads/site/site_logo/54db068a7470001bc5180000/Facebook-20150416-023619.jpg"/>
#         國立臺灣大學國家發展研究所
#        </a>
#       </h1>
#      </div>
#      <nav class="menu">
#       <div class="menu2">
#        <ul class="page_menu level_1" data-menu-level="0">
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/announcement" target="_self">
#           公告
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/news" target="_self">
#             最新消息
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/seminar_lecture" target="_self">
#             學術活動
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/scholarships" target="_self">
#             獎學金資訊
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/conference" target="_self">
#             研討會
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/ndf" target="_self">
#             國家發展論壇
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/about" target="_self">
#           本所簡介
#          </a>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/member" target="_self">
#           本所成員
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/director" target="_self">
#             所長專區
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/teacher" target="_self">
#             師資陣容
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/staff" target="_self">
#             行政人員
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/phd" target="_self">
#           博士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/calendar" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/entry" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/attendance" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/phd_thesis" target="_self">
#             博士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/forms" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/qa_phd" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/master" target="_self">
#           碩士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/calendar_m" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/entry_m" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/attendance_m" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/m_thesis" target="_self">
#             碩士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/form_m" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/qa_m" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/emba" target="_self">
#           碩士在職專班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/programs" target="_self">
#             特色課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/calendar_e" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/entry_e" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/attendance_e" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/e_thesis" target="_self">
#             在職專班論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/form_e" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/qa_e" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/speaking_corner" target="_self">
#           口試專區
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral" target="_self">
#             論文研究計畫口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_papers" target="_self">
#             論文口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_form" target="_self">
#             口試表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/qa_o" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/course" target="_self">
#           課程
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_p_m" target="_self">
#             博碩士班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/Course_em" target="_self">
#             碩專班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_calendar" target="_self">
#             歷年課程
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/alumni" target="_self">
#           所友會
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/history" target="_self">
#             歷史沿革
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/framework" target="_self">
#             組織架構
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/notes" target="_self">
#             會議資料
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/status" target="_self">
#             所友動態
#            </a>
#            <ul class="page_menu level_3" data-menu-level="2">
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_001" target="_self">
#               所友動態_001
#              </a>
#             </li>
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_002" target="_self">
#               所友動態_002
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="http://www.ntu.edu.tw" target="_blank">
#           臺大首頁
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <div class="banner">
#       <div class="banner_slide" data-pp="310">
#        <div class="w-ad-banner ad-banner-widget-3" data-subpart-id="54e18eaa747000394d5d0000">
#         <div class="w-ad-banner__wrap cycle-slideshow" data-cycle-log="false" data-cycle-slides=".w-ad-banner__slide" data-level="0" data-list="images" data-pager=".w-ad-banner__pager" data-pager-active-class="active-slide" data-pager-template="&lt;li&gt;&lt;a href='#'&gt;&lt;/a&gt;&lt;/li&gt;">
#          <div class="w-ad-banner__slide active" data-link="http://www.rulingcom.com">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e24747000394d2e0000/01.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e2d747000394d320000/02.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e38747000394d360000/03.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e40747000394d3a0000/04.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e49747000394d3e0000/05.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e54747000394d420000/06.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e68747000394d470000/07.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e71747000394d4b0000/08.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e7b747000394d4f0000/09.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e83747000394d530000/10.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e8e747000394d570000/12.jpg"/>
#          </div>
#         </div>
#         <ul class="w-ad-banner__pager">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class
a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#                國家發展研究期刊
#               </a>
#              </h2>
#              <a href="www.nd.ntu.edu.tw/zh_tw/nds" style="font-family: arial; font-size: 18px; line-height: 21.6px;">
#               National Development Studie
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <div>
#           <table>
#            <tbody>
#             <tr>
#              <td class="title">
#               <span style="font-size:16px;">
#                研究中心群
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td class="info">
#               <p>
#                <span style="font-size:9px;">
#                 <a href="/zh_tw/CSR">
#                  兩岸關係中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SES">
#                  國家經濟安全研究中心
#                 </a>
#                 <br/>
#                 <a href="http://140.112.176.185/spatial/excel2earth.html">
#                  空間分析工作室
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/marinepolicy">
#                  海洋政策研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/Law_Socio">
#                  法律與文化研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SR">
#                  科技政策與全球化風險治理中心
#                 </a>
#                </span>
#                <br/>
#                <a href="https://sites.google.com/view/ntundcrcc/">
#                 <span style="font-size: 12px;">
#                  區域合作暨競爭力研究中心
#                 </span>
#                </a>
#               </p>
#               <h4>
#               </h4>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#         </div>
#        </div>
#        <div class="publication hide">
#         <div class="page_content" data-pp="4">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               國家發展研究期刊
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               National Development Studies
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="institute hide">
#         <div class="page_content" data-pp="5">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              研究中心群
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="/zh_tw/CSR">
#               兩岸關係
#              </a>
#              <a href="/zh_tw/SES">
#               國家經濟安全研究
#              </a>
#              <a href="https://www.facebook.com/pages/Excel2Earth/383852245125712?fref=ts">
#               空間分析
#              </a>
#              <a href="/zh_tw/marinepolicy">
#               海洋政策研究
#              </a>
#              <a href="/zh_tw/Hakka">
#               客家研究
#              </a>
#              <a href="/zh_tw/Law_Socio">
#               法律與社會研究
#              </a>
#              <a href="/zh_tw/SR">
#               科技政策與全球化風險治理
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="event hide">
#         <div class="page_content" data-pp="6">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               國家發展論壇
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               Forum of National Developments
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="mailbox hide">
#         <div class="page_content" data-pp="7">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <footer class="footer">
#      <div class="footer-inner">
#       <div class="footer_address">
#        Copyright © 2014 國立臺灣大學國家發展研究所 Graduate Institute of National Development, National Taiwan University
#        <br/>
#        10617 臺北市大安區羅斯福路四段1號 （辛亥復興路口側門進入） No. 1, Sec. 4, Roosevelt Road, Taipei, 10617 Taiwan(R.O.C)
#        <br/>
#        電話 (Phone)：+886-2-3366-3333  傳真 (Fax)：+886-2-2367-6176  E-mail：ndintu@ntu.edu.tw
#       </div>
#       <div class="footer-site-counter">
#        造訪人次 : 727512
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## 把所有的公告，時間與內容抓出來。

# %%
# 網頁位於 "http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1&"
url="http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1&"
# 有 get 與 post 兩種模式，要從網頁上 inspect，本範例為 get
response = requests.get (url)
# 用 BeatifulSoup 解析 HTML 並把結果回傳 soup
soup = BeautifulSoup (response.text, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="orbit" lang="zh_tw">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/uploads/site/favicon/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    國立臺灣大學國家發展研究所
#   </title>
#   <link href="/assets/fontawesome/font-awesome-25cef4302d1b8fc05d28ac847626ecf3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/bootstrap/bootstrap-c07da65a73e80a09cabdf7a174a0635e.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/template/template-371b47ba8210ddd35fbd86df9516c51f.css" media="screen" rel="stylesheet"/>
#   <script src="/assets/lib/jquery-1.11.0.min-2cf9b70a257975f2833f682170097171.js">
#   </script>
#   <script src="/assets/bootstrap-c33cd72c8e754f012f5a68e0da4ad2db.js">
#   </script>
#   <script src="/assets/plugin/modernizr-b53b2a89dfd7a6d30aacfd4bd61ed506.js">
#   </script>
#   <script src="/assets/plugin/jquery-bullseye-min-695b302cc70f7f0277388c8759c2f01c.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.min-0181da5907c893e384e384f8ad2946de.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.video.min-8064c0652b44b69572d3ac653bedd6bd.js">
#   </script>
#   <script src="/assets/app-76e2704a8fa6c4fa895f3d420a243c56.js">
#   </script>
#   <script src="/assets/frontend-8338adc0c5e32b6d28215ca591059bb9.js">
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/assets/plugin/html5shiv-f1c171a5086388761a3fb837a304070b.js"></script>
#     <script src="/assets/plugin/response.min-ba150f83ff9f8a3cf90f406ddbaecef7.js"></script>
#   <![endif]-->
#   <link href="/assets/basic/icon" media="screen" rel="stylesheet"/>
#   <link href="/assets/lib/orbit_bar/orbit-bar" media="screen" rel="stylesheet"/>
#  </head>
#  <body class="page-internal" data-module="announcement">
#   <div id="orbit-bar">
#    <input id="open-orbit-login" type="checkbox"/>
#    <label class="cover" for="open-orbit-login">
#    </label>
#    <div class="login-window">
#     <div class="login-header">
#      <label class="close" for="open-orbit-login">
#       ×
#      </label>
#      <h3>
#       登入 Orbit
#      </h3>
#     </div>
#     <div class="login-body">
#      <form accept-charset="UTF-8" action="/sessions?locale=zh_tw" class="container" method="post">
#       <div style="display:none">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="WEZw04lm0sqghRsNlmwySyQ2RZ9LX2AqlYj1fRtjAJU="/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-user">
#         </i>
#        </span>
#        <input class="input" id="user_user_id" name="user_name" placeholder="使用者帳號" size="30" title="username" type="text"/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-lock">
#         </i>
#        </span>
#        <input class="input" id="user_password" name="password" placeholder="密碼" size="30" type="password"/>
#       </div>
#       <div class="login-submit-wrap">
#        <div class="submit">
#         <button class="login-btn" type="submit">
#          登入
#         </button>
#        </div>
#       </div>
#       <div class="login-sign-up-btn">
#        <a href="/users/new" rel="nofollow">
#         Sign up now
#        </a>
#       </div>
#      </form>
#     </div>
#    </div>
#    <input id="open-orbit-nav" type="checkbox"/>
#    <div class="orbit-bar-inner">
#     <label for="open-orbit-nav">
#      <i class="icons-list-2">
#      </i>
#     </label>
#     <h2 class="orbit-bar-title">
#      <a href="/">
#       Orbit
#      </a>
#     </h2>
#     <ul class="orbit-bar-menu">
#      <li>
#       <span class="orbit-bar-logo">
#        <img alt="Orbit Bar Logo" src="/uploads/site/default_image/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg"/>
#       </span>
#      </li>
#      <li>
#       <a class="orbit-bar-home" href="/">
#        <i class="icons-house">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <ul class="orbit-bar-search-sign-language">
#      <li>
#       <form action="http://www.google.com/custom" id="search" method="get" target="_blank">
#        <input name="client" type="hidden" value="pub-&amp;amp"/>
#        <input id="ie" name="ie" type="hidden" value="utf-8"/>
#        <input id="oe" name="oe" type="hidden" value="utf-8"/>
#        <input id="cof" name="cof" type="hidden" value="AH:center;AWFID:03de271f1940eea3;"/>
#        <input name="domains" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input name="sitesearch" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input id="q" name="q" placeholder="全站搜尋" type="search" value="" x-webkit-speech=""/>
#       </form>
#      </li>
#      <li>
#       <span id="language">
#        <i class="icons-earth orbit-bar-language-icon">
#        </i>
#        <span class="orbit-bar-language-text">
#         Language
#        </span>
#       </span>
#       <ul>
#        <li class="active">
#         繁體中文
#        </li>
#        <li>
#         <a accesskey="s" href="/zh_cn/announcement?page_no=1&amp;">
#          简体中文
#         </a>
#        </li>
#        <li class="">
#         <a accesskey="e" href="/en/announcement?page_no=1&amp;">
#          English
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a accesskey="L" class="sr-only" href="/zh_tw/accesskey" id="accesskey_login" title="Login">
#        :::
#       </a>
#       <label for="open-orbit-login">
#        <i class="icons-login">
#        </i>
#       </label>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <script type="text/javascript">
#    $("#open-orbit-login").on("change",function(){
#     if($(this).is(":checked")){
#       $("#user_user_id").focus();
#     }
#   })
#   $(".login-body form").on("submit",function(){
#     $(this).append("<input type='hidden' name='referer_url' value='http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1&amp;'/>");
#   })
#   var I18n = {
#     get locale(){ return "zh_tw"},
#     get validLocales(){return ["zh_tw","en","zh_cn"]},
#     set locale(v){return false},
#     set validLocales(v){return false}
#   };
#   </script>
#   <div class="body">
#    <div class="wrap">
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <script>
#      !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="https://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#     </script>
#     <header class="header">
#      <div id="button">
#      </div>
#      <div class="header-nav">
#      </div>
#      <div class="header_branding">
#       <h1 class="header_title">
#        <a class="header-home" href="/">
#         <img class="site-logo" src="/uploads/site/site_logo/54db068a7470001bc5180000/Facebook-20150416-023619.jpg"/>
#         國立臺灣大學國家發展研究所
#        </a>
#       </h1>
#      </div>
#      <nav class="menu">
#       <div class="menu2">
#        <ul class="page_menu level_1" data-menu-level="0">
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/announcement" target="_self">
#           公告
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/news" target="_self">
#             最新消息
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/seminar_lecture" target="_self">
#             學術活動
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/scholarships" target="_self">
#             獎學金資訊
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/conference" target="_self">
#             研討會
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/ndf" target="_self">
#             國家發展論壇
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/about" target="_self">
#           本所簡介
#          </a>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/member" target="_self">
#           本所成員
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/director" target="_self">
#             所長專區
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/teacher" target="_self">
#             師資陣容
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/staff" target="_self">
#             行政人員
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/phd" target="_self">
#           博士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/calendar" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/entry" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/attendance" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/phd_thesis" target="_self">
#             博士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/forms" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/qa_phd" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/master" target="_self">
#           碩士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/calendar_m" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/entry_m" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/attendance_m" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/m_thesis" target="_self">
#             碩士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/form_m" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/qa_m" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/emba" target="_self">
#           碩士在職專班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/programs" target="_self">
#             特色課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/calendar_e" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/entry_e" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/attendance_e" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/e_thesis" target="_self">
#             在職專班論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/form_e" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/qa_e" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/speaking_corner" target="_self">
#           口試專區
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral" target="_self">
#             論文研究計畫口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_papers" target="_self">
#             論文口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_form" target="_self">
#             口試表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/qa_o" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/course" target="_self">
#           課程
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_p_m" target="_self">
#             博碩士班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/Course_em" target="_self">
#             碩專班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_calendar" target="_self">
#             歷年課程
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/alumni" target="_self">
#           所友會
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/history" target="_self">
#             歷史沿革
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/framework" target="_self">
#             組織架構
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/notes" target="_self">
#             會議資料
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/status" target="_self">
#             所友動態
#            </a>
#            <ul class="page_menu level_3" data-menu-level="2">
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_001" target="_self">
#               所友動態_001
#              </a>
#             </li>
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_002" target="_self">
#               所友動態_002
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="http://www.ntu.edu.tw" target="_blank">
#           臺大首頁
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <div class="banner">
#       <div class="banner_slide" data-pp="310">
#        <div class="w-ad-banner ad-banner-widget-3" data-subpart-id="54e190e5747000394d780000">
#         <div class="w-ad-banner__wrap cycle-slideshow" data-cycle-log="false" data-cycle-slides=".w-ad-banner__slide" data-level="0" data-list="images" data-pager=".w-ad-banner__pager" data-pager-active-class="active-slide" data-pager-template="&lt;li&gt;&lt;a href='#'&gt;&lt;/a&gt;&lt;/li&gt;">
#          <div class="w-ad-banner__slide active" data-link="http://www.rulingcom.com">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e24747000394d2e0000/01.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e2d747000394d320000/02.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e38747000394d360000/03.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e40747000394d3a0000/04.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e49747000394d3e0000/05.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e54747000394d420000/06.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e68747000394d470000/07.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e71747000394d4b0000/08.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e7b747000394d4f0000/09.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e83747000394d530000/10.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide" data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e8e747000394d570000/12.jpg"/>
#          </div>
#         </div>
#         <ul class="w-ad-banner__pager">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class="main">
#      <div class="internal">
#       <div class="breadcrumb1" data-pp="11">
#        <div class="widget-breadcrumb widget1" data-subpart-id="54e19704747000394dae0000">
#         <ul class="breadcrumb" data-level="0" data-list="crumbs">
#          <li>
#           <a href="/zh_tw/">
#            首頁
#           </a>
#          </li>
#          <li>
#           <a href="/zh_tw/announcement">
#            公告
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <main data-content="true" id="main-content">
#        <div class="i-annc index-announcement-1">
#         <h3 class="i-annc__page-title">
#          公告
#         </h3>
#         <table class="i-annc__table table table-striped">
#          <thead>
#           <tr>
#            <th class="i-annc__th i-annc__th--date">
#             張貼日期
#            </th>
#            <th class="i-annc__th i-annc__th--title">
#             標題
#            </th>
#           </tr>
#          </thead>
#          <tbody data-level="0" data-list="announcements">
#           <tr>
#            <td>
#             <span class="i-annc__postdate" date-format="%Y-%m-%d">
#              2019-11-06
#             </span>
#            </td>
#            <td>
#             <a class="i-annc__title" href="/zh_tw/announcement/108-11-07-%E5%9B%9B-%E6%89%80%E9%95%B7%E6%99%82%E9%96%93%E6%94%B9%E6%96%BC%E4%B8%8B%E5%8D%882%E6%99%82%E8%87%B33%E6%99%82-21571357">
#              108/11/07 (四)所長時間改於下午2時至3時
#             </a>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <span class="i-annc__postdate" date-format="%Y-%m-%d">
#              2019-11-01
#             </span>
#            </td>
#            <td>
#             <a class="i-annc__title" href="/zh_tw/announcement/109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%94%84%E8%A9%A6%E7%AC%A6%E5%90%88%E5%8F%A3%E8%A9%A6%E8%B3%87%E6%A0%BC%E5%90%8D%E5%96%AE%E6%9A%A8%E5%8F%A3%E8%A9%A6%E5%A0%B4%E6%AC%A1%E8%A1%A8-13985054">
#              109學年度碩士班甄試符合口試資格名單暨口試場次表
#             </a>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <span class="i-annc__postdate" date-format="%Y-%m-%d">
#              2019-10-30
#             </span>
#            </td>
#            <td>
#             <a class="i-annc__title" href="/zh_tw/announcement/108-11-12-%E4%BA%8C-%E9%A2%A8%E9%9A%AA%E4%B8%AD%E5%BF%83%E8%88%89%E8%BE%A6%E4%B9%8B-%E9%89%85%E8%AE%8A%E8%87%BA%E7%81%A3-%E5%95%9F%E5%8B%95%E8%87%BA%E7%81%A3%E9%95%B7%E6%9C%9F%E8%83%BD%E6%BA%90%E8%BD%89%E5%9E%8B-%E8%AB%96%E5%A3%87%E6%B4%BB%E5%8B%95-%E6%AD%A1%E8%BF%8E%E5%90%8C%E5%AD%B8%E5%A0%B1%E5%90%8D%E5%8F%83%E5%8A%A0-%E8%A8%88%E5%85%A5%E5%AD%B8%E7%BF%92%E5%8D%A1

#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </div>
#        <ul class="pagination pagination-sm" data-pagination="true">
#         <li class="active">
#          <a href="?page_no=1&amp;">
#           1
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=2&amp;">
#           2
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=3&amp;">
#           3
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=2&amp;">
#           »
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=3&amp;">
#           最後
#          </a>
#         </li>
#        </ul>
#       </main>
#      </div>
#     </div>
#     <footer class="footer">
#      <div class="footer-inner">
#       <div class="footer_address">
#        Copyright © 2014 國立臺灣大學國家發展研究所 Graduate Institute of National Development, National Taiwan University
#        <br/>
#        10617 臺北市大安區羅斯福路四段1號 （辛亥復興路口側門進入） No. 1, Sec. 4, Roosevelt Road, Taipei, 10617 Taiwan(R.O.C)
#        <br/>
#        電話 (Phone)：+886-2-3366-3333  傳真 (Fax)：+886-2-2367-6176  E-mail：ndintu@ntu.edu.tw
#       </div>
#       <div class="footer-site-counter">
#        造訪人次 : 727512
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## 公告的時間

# %%
# 公告的時間位於 <span class="i-annc__postdate" date-format="%Y-%m-%d"> ......</span>
list_t=soup.find_all("span", {'class':"i-annc__postdate"})
time=[]
for t in list_t:
    time.append(t.text)
print (time)
# Out:
# [' 2019-11-06', ' 2019-11-01', ' 2019-10-30', ' 2019-10-28', ' 2019-10-28', ' 2019-10-22', ' 2019-10-18', ' 2019-10-01', ' 2019-09-18', ' 2019-08-21']

# %% [markdown]
# ## 公告的標題

# %%
# 經檢查，公告的標題位於 <a class="i-annc__title" href="...">......</a>
list_a=soup.find_all("a", {'class':"i-annc__title"})
title=[]
for a in list_a:
    title.append(a.text)
print (title)
# Out:
# ['108/11/07 (四)所長時間改於下午2時至3時', '109學年度碩士班甄試符合口試資格名單暨口試場次表', '108/11/12(二)風險中心舉辦之【鉅變臺灣：啟動臺灣長期能源轉型】論壇活動，歡迎同學報名參加！ (計入學習卡)', '【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)', '【公告】109學年度碩士班招生簡章考科異動', '108學年度第1學期生活學習助學金審核結果公告', '108/10/26(六)109學年度碩士班甄試招生筆試試場：國發所206教室', '本校學務處公告相關訊息', '[所辦公告] 所辦公室不代收同學私人信件或包裹', '【恭賀】本校特聘講座教授暨本所「中國大陸與東亞研究」學組師資黃俊傑老師獲選為歐洲科學院院士（Member of the Academia Europaea）']

# %%
# 接下來，我們要公告的內容。它是放在聯結裡。先做一個聯結的清單。
list_a=soup.find_all("a", {'class':"i-annc__title"})
# 注意有一個共同的網址頭
h='http://www.nd.ntu.edu.tw'
list_l=[]
for a in list_a:
    list_l.append(h+a['href'])    
print(list_l)
# Out:
# ['http://www.nd.ntu.edu.tw/zh_tw/announcement/108-11-07-%E5%9B%9B-%E6%89%80%E9%95%B7%E6%99%82%E9%96%93%E6%94%B9%E6%96%BC%E4%B8%8B%E5%8D%882%E6%99%82%E8%87%B33%E6%99%82-21571357', 'http://www.nd.ntu.edu.tw/zh_tw/announcement/109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%94%84%E8%A9%A6%E7%AC%A6%E5%90%88%E5%8F%A3%E8%A9%A6%E8%B3%87%E6%A0%BC%E5%90%8D%E5%96%AE%E6%9A%A8%E5%8F%A3%E8%A9%A6%E5%A0%B4%E6%AC%A1%E8%A1%A8-13985054', 'http://www.nd.ntu.edu.tw/zh_tw/announcement/108-11-12-%E4%BA%8C-%E9%A2%A8%E9%9A%AA%E4%B8%AD%E5%BF%83%E8%88%89%E8%BE%A6%E4%B9%8B-%E9%89%85%E8%AE%8A%E8%87%BA%E7%81%A3-%E5%95%9F%E5%8B%95%E8%87%BA%E7%81%A3%E9%95%B7%E6%9C%9F%E8%83%BD%E6%BA%90%E8%BD%89%E5%9E%8B-%E8%AB%96%E5%A3%87%E6%B4%BB%E5%8B%95-%E6%AD%A1%E8%BF%8E%E5%90%8C%E5%AD%B8%E5%A0%B1%E5%90%8D%E5%8F%83%E5%8A%A0-%E8%A8%88%E5%85%A5%E5%AD%B8%E7%BF%92%E5%8D%A1
小時，核撥助學金：6,000元。\n5.期末進行考核，作為次學期是否繼續服務學習及核發助學金之依據。\n6.未盡事項依本校學生生活學習助學金設置要點規定辦理。\n7.生活學習作業不得缺交且評量分數總分60分以上始為通過。\n8.如有下列情事者，次月起不予核發：\r\n\xa0\xa0 \xa0(1)因特殊事故或疾病不克繼續參與生活學習者。\n\xa0\xa0\xa0 (2)休學或退學者。\n\xa0\xa0\xa0 (3)當月完全未參與生活學習活動者。\n',
#  '\n國立臺灣大學國家發展研究所109學年度碩士班甄試招生\n\n筆試日期：108年10月26日(星期六)\n筆試時間：10:00~11:40\n筆試地點：台大國發所206教室\n台灣大學校總區地址：台北市羅斯福路四段1號(近台灣大學辛亥路與復興南路交叉口警衛室後門入口右手邊第二棟樓)\n連絡電話：02-33663333\n\n筆試試場資訊：\n\n\n\n從台灣大學校總區後門進入：可搭乘捷運文湖線：於捷運科技大樓站下車，沿復興南路往辛亥路方向步行，從辛亥路與復興南路交叉口警衛亭後門進入右邊第二棟樓，步程約10分鐘。\n\n\n從台灣大學校總區正門進入：步程約需20~30分鐘。\n\n\n開車前來者，進入台大校園時需抽取停車卡，於考試完畢後交試務人員核章， 20~30元不等。(依個別停車場標準計算)\n\n\r\n\xa0\n注意事項：\xa0考生請攜帶准考證、身分證、第2階段報名費繳費證明準時到場應試。\n',
#  '\n大家好：\r\n\xa0\n學務處辦理多項優質活動，歡迎您踴躍參加。\n\n\n\n\n學務處每週公告\n\n\n單位\n主旨\n聯絡人\n\n\n保健中心\n「提升身體優勢力:伸展與肌力運動」講座\xa0\n廖芃慈\r\n\t\t\t33662175\n\n\n保健中心\n\n「遠離菸害、健康無礙」講座\xa0\n\n詹千慧\r\n\t\t\t33662168\n\n\n校安中心\n\n提供反偷拍偵測器供住宿及賃居在外學生借用\xa0\n\n王潤身\r\n\t\t\t33662056\n\n\n生輔組\n\n108學年度優秀青年10月1日截止受理申請\xa0\n\n林奕延\r\n\t\t\t33662050#221\n\n\n\r\n\xa0\n學務處關心您\n',
#  '\n所辦公室不代收同學私人信件或包裹，請同學留意勿將私人信件或包裹寄至所辦公室。謝謝配合。\n',
#  '\n恭賀本校特聘講座教授暨本所「中國大陸與東亞研究」學組師資，黃俊傑老師獲選為歐洲科學院院士（Member of the Academia Europaea），安排至「古典與東方研究」（Classics & Oriental Studies）學部。\r\n詳細內容請見：https://www.ae-info.org/ae/Member/Huang_Chun-Chieh\r\n\xa0\n']

# %%
import pandas as pd
data=list(zip(time, title, string))
df=pd.DataFrame(data, columns=['time ','title','content'])
df
# Out:
#          time                                               title  \
# 0   2019-11-06                         108/11/07 (四)所長時間改於下午2時至3時
# 1   2019-11-01                          109學年度碩士班甄試符合口試資格名單暨口試場次表
# 2   2019-10-30  108/11/12(二)風險中心舉辦之【鉅變臺灣：啟動臺灣長期能源轉型】論壇活動，歡迎同學報...
# 3   2019-10-28            【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)
# 4   2019-10-28                              【公告】109學年度碩士班招生簡章考科異動
# 5   2019-10-22                            108學年度第1學期生活學習助學金審核結果公告
# 6   2019-10-18             108/10/26(六)109學年度碩士班甄試招生筆試試場：國發所206教室
# 7   2019-10-01                                        本校學務處公告相關訊息
# 8   2019-09-18                            [所辦公告] 所辦公室不代收同學私人信件或包裹
# 9   2019-08-21  【恭賀】本校特聘講座教授暨本所「中國大陸與東亞研究」學組師資黃俊傑老師獲選為歐洲科學院院士（...
#
#                                              content
# 0                                               \n\n
# 1  \n國立臺灣大學國家發展研究所109學年度碩士班甄試口試場次表\n口試日期：108.11.0...
# 2  \n\n\r\n【鉅變臺灣：啟動臺灣長期能源轉型】論壇\n\r\n時間：11月12日(二)0...
# 3  \n國發所畢業團拍（107碩士班）\r\n \n大家好，我們是107級的畢代皓瑋和玥岑，時光...
# 4  \n\n公告\n\n109學學年度碩士班招生簡章考科異動：乙組(主修中國大陸與東亞研究)選考...
# 5  \n台灣大學國家發展所108學年度第1學期生活學習助學金審核結果公告\n\n通過名單：蔡振輝...
# 6  \n國立臺灣大學國家發展研究所109學年度碩士班甄試招生\n\n筆試日期：108年10月26...
# 7  \n大家好：\r\n \n學務處辦理多項優質活動，歡迎您踴躍參加。\n\n\n\n\n學務處...
# 8    \n所辦公室不代收同學私人信件或包裹，請同學留意勿將私人信件或包裹寄至所辦公室。謝謝配合。\n
# 9  \n恭賀本校特聘講座教授暨本所「中國大陸與東亞研究」學組師資，黃俊傑老師獲選為歐洲科學院院士...

# %% [markdown]
# ## 但是我們有好幾頁

# %%
# 檢查每頁的網址結構相似，http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1& 
# 製作每頁的聯結
time=[]
title=[]
string=[]
for n in range(5):
    #  共有五頁
    url='http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=' + str(n+1) + '&'     
    response = requests.get (url)
    soup = BeautifulSoup (response.text, "lxml")
    # 時間
    list_t=soup.find_all("span", {'class':"i-annc__postdate"})    
    for t in list_t:
        time.append(t.text)
    # 標題    
    list_a=soup.find_all("a", {'class':"i-annc__title"})
    for a in list_a:
        title.append(a.text)        
    # 內容聯結
    list_a=soup.find_all("a", {'class':"i-annc__title"})
    h='http://www.nd.ntu.edu.tw'
    list_l=[]
    for a in list_a:
        list_l.append(h+a['href'])    
    # 內容
    for l in list_l:
        response = requests.get (l)
        soup_tem = BeautifulSoup (response.text, "lxml")
        add_string=soup_tem.find_all('section',{'class':"s-annc__post-wrap"})[0].text    
        string.append(add_string)
# 統整
data=list(zip(time, title, string))
df=pd.DataFrame(data, columns=['time ','title','content'])
print(df)
# Out:
#           time                                               title  \
# 0    2019-11-06                         108/11/07 (四)所長時間改於下午2時至3時
# 1    2019-11-01                          109學年度碩士班甄試符合口試資格名單暨口試場次表
# 2    2019-10-30  108/11/12(二)風險中心舉辦之【鉅變臺灣：啟動臺灣長期能源轉型】論壇活動，歡迎同學報...
# 3    2019-10-28            【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)
# 4    2019-10-28                              【公告】109學年度碩士班招生簡章考科異動
# 5    2019-10-22                            108學年度第1學期生活學習助學金審核結果公告
# 6    2019-10-18             108/10/26(六)109學年度碩士班甄試招生筆試試場：國發所206教室
# 7    2019-10-01                                        本校學務處公告相關訊息
# 8    2019-09-18                            [所辦公告] 所辦公室不代收同學私人信件或包裹
# 9    2019-08-21  【恭賀】本校特聘講座教授暨本所「中國大陸與東亞研究」學組師
://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1& 
# 製作每頁的聯結
time=[]
title=[]
string=[]
for n in range(5):
    #  共有五頁
    url='http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=' + str(n+1) + '&'     
    response = requests.get (url)
    soup = BeautifulSoup (response.text, "lxml")
    # 時間
    list_t=soup.find_all("span", {'class':"i-annc__postdate"})    
    for t in list_t:
        time.append(t.text)
    # 標題    
    list_a=soup.find_all("a", {'class':"i-annc__title"})
    for a in list_a:
        title.append(a.text)        
    # 內容聯結
    list_a=soup.find_all("a", {'class':"i-annc__title"})
    h='http://www.nd.ntu.edu.tw'
    list_l=[]
    for a in list_a:
        list_l.append(h+a['href'])    
    # 內容
    for l in list_l:
        response = requests.get (l)
        soup_tem = BeautifulSoup (response.text, "lxml")
        add_string=soup_tem.find_all('section',{'class':"s-annc__post-wrap"})[0].text    
        string.append(add_string)
# 統整
data=list(zip(time, title, string))
df=pd.DataFrame(data, columns=['time ','title','content'])
df
# Out:
#           time                                               title  \
# 0    2019-11-06                         108/11/07 (四)所長時間改於下午2時至3時
# 1    2019-11-01                          109學年度碩士班甄試符合口試資格名單暨口試場次表
# 2    2019-10-30  108/11/12(二)風險中心舉辦之【鉅變臺灣：啟動臺灣長期能源轉型】論壇活動，歡迎同學報...
# 3    2019-10-28            【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)
# 4    2019-10-28                              【公告】109學年度碩士班招生簡章考科異動
# 5    2019-10-22                            108學年度第1學期生活學習助學金審核結果公告
# 6    2019-10-18             108/10/26(六)109學年度碩士班甄試招生筆試試場：國發所206教室
# 7    2019-10-01                                        本校學務處公告相關訊息
# 8    2019-09-18                            [所辦公告] 所辦公室不代收同學私人信件或包裹
# 9    2019-08-21  【恭賀】本校特聘講座教授暨本所「中國大陸與東亞研究」學組師資黃俊傑老師獲選為歐洲科學院院士（...
# 10   2019-06-06        【施工通知】玉衡能源-國發所屋頂防水施工今天仍會有工程廢棄物吊運,另會有單側沒水的情形
# 11   2019-06-04  【施工通知】玉衡能源-國發所防水施工預計今天(6/4)上午10點起前門上方吊運工程廢棄物,請...
# 12   2019-06-02       本所屋頂太陽能發電設備設置暨防水工程預計自108/6/2(日)起至108/8/1進行施工
# 13   2019-05-23      [演講訊息] 5/30(星期四) 10:20-13:10  全球化的逆襲：反建制主義的興起
# 14   2019-01-03  財團法人中華經濟研究院與德國基爾世界經濟研究院（Kiel Institute for the...
# 15   2018-10-15              臺灣大學國家發展研究所108學年度碩士班甄試招生筆試試場：新聞所203教室
# 16   2018-05-11                 [演講訊息] 5/17(星期四) 10:20-13:10 未竟的奇蹟
# 17   2016-12-09                     恭賀本所與中央研究院合聘之李明輝教授獲得教育部第60屆學術獎
# 18   2016-10-20                   2017/2018 (106學年度)社會科學院出國交換學生說明會
# 19   2016-09-14                      2016社科院國際學位生獎學金9/19至10/14受理申請
# 20   2016-09-07                           2017/2018年度出國交換學生甄選簡章說明會
# 21   2016-08-26                                  105年度博士班研究室分配結果公告
# 22   2015-09-24              本所非學校所規劃吸菸區，請大家遵守本校校園菸害防制管理要點勿於所內違規吸菸
#
#                                               content
# 0                                                \n\n
# 1   \n國立臺灣大學國家發展研究所109學年度碩士班甄試口試場次表\n口試日期：108.11.0...
# 2   \n\n\r\n【鉅變臺灣：啟動臺灣長期能源轉型】論壇\n\r\n時間：11月12日(二)0...
# 3   \n國發所畢業團拍（107碩士班）\r\n \n大家好，我們是107級的畢代皓瑋和玥岑，時光...
# 4   \n\n公告\n\n109學學年度碩士班招生簡章考科異動：乙組(主修中國大陸與東亞研究)選考...
# 5   \n台灣大學國家發展所108學年度第1學期生活學習助學金審核結果公告\n\n通過名單：蔡振輝...
# 6   \n國立臺灣大學國家發展研究所109學年度碩士班甄試招生\n\n筆試日期：108年10月26...
# 7   \n大家好：\r\n \n學務處辦理多項優質活動，歡迎您踴躍參加。\n\n\n\n\n學務處...
# 8     \n所辦公室不代收同學私人信件或包裹，請同學留意勿將私人信件或包裹寄至所辦公室。謝謝配合。\n
# 9   \n恭賀本校特聘講座教授暨本所「中國大陸與東亞研究」學組師資，黃俊傑老師獲選為歐洲科學院院士...
# 10  \n屋頂的防水工程今天仍會有工程廢棄物吊運,出入請小心\n\n另外為了清除消防水管及供水管下...
# 11  \n廠商通知今天(6/4)上午10點起前門上方吊運工程廢棄物，為避免吊運碎片掉落造成傷害，請...
# 12  \n廠商於108年5月27日發送防水施工期程及太陽光電發電設備的施工期程如附件，預計於108...
# 13  \n\n講題：全球化的逆襲：反建制主義的興起\n講者：台大政治系黃旻華教授\n時間：5月30...
# 14  \n財團法人中華經濟研究院 與德國基爾世界經濟研究院（Kiel Institute for ...
# 15  \n臺灣大學國家發展研究所108學年度碩士班甄試招生\n\n筆試日期：107年10月27日(...
# 16  \n時間：107年5月17日(週四)早上10:20-13:10\r\n地點：國發所R206\...
# 17  \n教育部105年10月19日公布第60屆學術獎及第20屆國家講座得獎名單。本所與中央研究院...
# 18  \n社科院將於以下時間、地點舉行2017/2018 (106學年度) 院級出國交換學生說明會...
# 19  \n社會科學院--國際學位生獎助學金自2016年9月19日起至2016年10月14日止受理申...
# 20  \n\n        為了鼓勵臺大學生善用各項海外教育計畫資源、積極參與出國交換學生計畫，...
# 21  \n\n\n105年度博士班研究室分配結果公告\r\n \n一、【研究室使用期間】：105學...
# 22  \n校方依據菸害防制法第十五條及第十六條規定及大學校園自治規範，規定本校除局部室外場所得設置...

# %% [markdown]
# # 作業

# %% [markdown]
# * 請進入你的標的網頁，檢查網頁的結構，回答以下問題:
# * 1 網址是? 簡單介紹這個網頁。
# * 2 你想下載網頁中的什麼資訊？
# * 3 這些資訊是放在哪個 tag(標籤)，那個attribute(屬性)下面？如果找不到，表示為動態網頁或加密，請換一個簡單的網頁。
# * 4 是否要進去聯結，才可以找到你要的東西?
# * 5 是否有多個分頁，分頁的網址規則是什麼?
# * 6 依上課教的方法，下載資料，整理成 DataFrame 方便閱讀。有碰到什麼困難嗎?
# * 7 記錄你探索過的失敗、無法下載網頁，列出 1,2,3 項。也許其他同學可以幫你解決。
# * 8 交作業時，除了回答上問題，要交 .ipynb 以及下載的資料檔。

# %%
# 作業內容: 爬取台積電公司專業技術介紹頁面文字
# 網址: 
#主頁_Index: https://www.tsmc.com/chinese/dedicatedFoundry/technology/index.htm
#分頁_logic: https://www.tsmc.com/chinese/dedicatedFoundry/technology/logic.htm
#分頁_specialty: https://www.tsmc.com/chinese/dedicatedFoundry/technology/specialty.htm
#分頁_WLSI: https://www.tsmc.com/chinese/dedicatedFoundry/technology/WLSI.htm
#分頁_platform: https://www.tsmc.com/chinese/dedicatedFoundry/technology/platform.htm
#分頁_fiture_rd: https://www.tsmc.com/chinese/dedicatedFoundry/technology/future_rd.htm

#目標: 爬取台積電公司的所有技術和產品介紹，並整理成dataframe

# %%
#載入相關套件
# beautiful soup
import urllib
import urllib.request
from bs4 import BeautifulSoup
import io
import os
import json
import re
import pandas as pd

title_list = ['index', 'logic', 'specialty', 'WLSI', 'platform', 'future_rd']
title =[]
string = []

for ti in title_list:
    #抓取網址&煮湯
    url='https://www.tsmc.com/chinese/dedicatedFoundry/technology/' + ti + '.htm'     
    response = requests.get (url)
    response.encoding='UTF-8' #遇到網頁編碼不同之問題，透過這行程式碼得以解決
    soup = BeautifulSoup (response.text, "lxml")
    #print(soup.prettify())

    #抓取各分頁title
    list_t = soup.find_all('div', {'class':'d-inline-block'})
    for t in list_t:
#         print(type(t))
#         t = re.sub('\r\n', '', t)
        title.append(t.text)
        
    for t in title:
        t.strip()
        t.replace('\n', '')
        t.replace('\n      ', '')
        
        
    #抓取各分頁內容
    list_s = soup.find_all('section', {'id':'pageIntroSection'})
    for s in list_s:
        string_add = s.find_all('p')
        for s in string_add:
           #s = re.sub('\r\n', '', s)
            string.append(s.text)

#清除字符
title_1= []
for i in range(4):
    t = title[i].strip()
    title_1.append(t)
# print(title_1)


string_1 = []
for i in range(4):
    t = string[i].strip()
    string_1.append(t)
# print(string_1)

#製作表格
data=list(zip(title_1, string_1))
# print(data)
df=pd.DataFrame(data, columns=['title','content'])
print(df)

#存回excel檔
# import chardet
# print(chardet.detect(df))
# import codecs
path='C:/Users/HSIU/Desktop/108-1/python_ntu'
# fname ='/data/tcmc.csv'
# file_name = path + fname
# with open(unicode(file_name'.csv',  encoding='utf8'), 'w') as f:
#     f.write(codecs.BOM_UTF8)
#     f.write(df)
#     f.close() 
    
# import csv
# import codecs
# with open('tcmc.csv', 'wb') as csvfile:
#     csvfile.write(codecs.BOM_UTF8)   
#     dfwriter = csv.writer(csvfile, dialect='excel')


# df.to_csv(path+'/data/tcmc.csv',index=False,header=True, encoding = 'utf-8')
# # data.to_csv('XXXXX.csv',encoding='utf_8_sig')
import csv
import codecs

csvfile = file(path+'tcmc.csv', 'wb')
csvfile.write(codecs.BOM_UTF8)
writer = csv.writer(csvfile)
writer.write(df)
csvfile.close()

# import csv
# import codecs
# list=['a101','b101']
# sumlist=[]
# for str in list:
# templist=[]
# templist.append('a')
# templist.append('b')
# templist.append('c')
# sumlist.append(templist)
# csvfile = file('csv_test.csv', 'wb')
# csvfile.write(codecs.BOM_UTF8)
# writer = csv.writer(csvfile)
# writer.writerow(['姓名', '年龄', '电话'])

#data = [
# ('小河', '25', '1234567'),
# ('小芳', '18', '789456')
# #]
# writer.writerows(sumlist)

# csvfile.close()
# ————————————————
# 版权声明：本文为CSDN博主「hurt--」的原创文章，遵循 CC 4.0 BY-SA 版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/weixin_40907382/article/details/80245541
# # import csv
# import codecs
# with open('test.csv', 'wb') as csvfile:  
#     csvfile.write(codecs.BOM_UTF8)   
# #     spamwriter = csv.writer(csvfile, dialect='excel')

# 作者：知乎用户
# 链接：https://www.zhihu.com/question/34201726/answer/150221584
# 来源：知乎
# 著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。

# fname= '/corpus/president/蔡英文第十四任.txt'
# file_name=path+fname
# # content 為前面產生的文字檔
# with open(file_name, 'w', encoding='utf8') as f:
#     f.write(content)
#     f.close() 
    
# import codecs
# f = open(**unicode(df'.csv','utf-8')**,'w') # 檔名不亂碼
# **f.write(codecs.BOM_UTF8) # excel開啟內容不亂碼的核心語句**
# f.write('tcmc')
# f.close()

# fname=path+'/data/tcmc/csv'
# df1 = pd.read_csv(fname, encoding='utf-8')
# df1
# df.to_csv(path+'data/station.csv',index=False,header=True,encoding='utf-8')
# Out:
#      title                                            content
# 0     專業技術  技術是台積公司的基石之一，我們提供專業積體電路製造服務領域中最完備的技術與服務，為全球半導體...
# 1     邏輯製程  With the proliferation of AI and 5G from cloud...
# 2     特殊製程  TSMC Wafer Level System Integration (WLSI) is ...
# 3  晶圓級系統整合  In light of the rapid growth in four major mar...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-70445db284fe> in <module>
#      87 import codecs
#      88
# ---> 89 csvfile = file(path+'tcmc.csv', 'wb')
#      90 csvfile.write(codecs.BOM_UTF8)
#      91 writer = csv.writer(csvfile)
#
# NameError: name 'file' is not defined

# %%
#     # 時間
#     list_t=soup.find_all("span", {'class':"i-annc__postdate"})    
#     for t in list_t:
#         time.append(t.text)
#     # 標題    
#     list_a=soup.find_all("a", {'class':"i-annc__title"})
#     for a in list_a:
#         title.append(a.text)        
#     # 內容聯結
#     list_a=soup.find_all("a", {'class':"i-annc__title"})
#     h='http://www.nd.ntu.edu.tw'
#     list_l=[]
#     for a in list_a:
#         list_l.append(h+a['href'])    
#     # 內容
#     for l in list_l:
#         response = requests.get (l)
#         soup_tem = BeautifulSoup (response.text, "lxml")
#         add_string=soup_tem.find_all('section',{'class':"s-annc__post-wrap"})[0].text    
#         string.append(add_string)
# # 統整
# data=list(zip(title, string))
# print(data)
# df=pd.DataFrame(data, columns=['title','content'])
# print(df)
# Out:
# []
# Empty DataFrame
# Columns: [title, content]
# Index: []

# %%
# # 接續上例，印出 < p> 內的文字，存成 list
# paragraph=[]
# # 找出所有合於條件的 <div>
# list_div=soup.find_all("div", {'class':"second"})
# # 如果有找到的話
# if len(list_div)>0:
#     for li in list_div:    
#         # 找出所有的 <p>
#         list_p=li.find_all("p")
#         for p in list_p:
#             # 加入 list
#             paragraph.append(p.text)
#     print (paragraph)
