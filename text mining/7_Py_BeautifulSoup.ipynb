# %% [markdown]
# # html 語言與 Beautiful Soup

# %% [markdown]
# * 本週開始，我們要介紹網路爬蟲基本方法與技巧。
# * 今天討論 request 與 beautiful soup 的用法，下過討論 regular expression, 是字串處理的進階工具，第三週討論幾個綜合的爬蟲案例。
# * 由於網頁多半以html 語言撰寫，BeuatifulSoup4 是解析html檔案非常好用的工具。因此，值得好好學學。
# * 安裝 python, Anaconda 之後，會自動安裝 BeuatifulSoup4，不須另外安裝。

# %% [markdown]
# #  html file
# * html 是網頁最常見的編寫工具，它的基本特徵是以__成對的tag(標記)__。
# * 這是一個層次井然的語言結構，每個 tag 都有特定的意義，tag 裡面有tag，可以有許多層。
# * 我們的任務是從別人寫好的html網頁中，截取我們要的資料，通常是網址，或文字、數字資料。

# %% [markdown]
# ## 一個很簡單的範例
# * 請檢查各__標記__夾的__內容__是什麼？中間是否有夾著__字串__？是否有定義__屬性__？標記共有幾層？
# * 重要的_標記_有 < TITLE> </TITLE>, < div> </div>, < a> </a>, < p> </p>都是成對顯示。
# * _屬性_ <> 為標記內宣告的變數，例如 < a href="http://somegreatsite1.com">, < P align=justify>, < div class="first">
# * _字串_ 為啟始標記與結束標記內所夾的文字，例如  < a>.....</a>, < p> ..... < /p>

# %%
# html的基本範例，html_doc 是個字串 string, ''' 表長字串
# 注意，成對的 tag，每個tag 都有不同的意義
html_doc='''
<HTML>
    <HEAD><TITLE>標題在這裡</TITLE></HEAD>
    <div class="first">
        <a href="http://somegreatsite1.com" id="link1">Link1</a>關於這個聯結的文字說明
        <a href="http://somegreatsite2.com" id="link2">Link2</a>關於這個聯結的文字說明
        <P align=justify> 這是段落文字，可以很長! </P> 
    </div>
</HTML> 
'''

# %% [markdown]
# ### 稍微複雜一點，真正的網頁遠比這個複雜得多

# %%
# html的基本範例，html_doc 是個字串 string, ''' 表長字串
html_doc='''
<HTML>
<HEAD><TITLE>標題在這裡</TITLE></HEAD>
<BODY BGCOLOR="FFFFFF">
<div class="first">
<a href="http://somegreatsite1.com" id="link1">Link Name1</a>is the first link to another web site
<a href="http://somegreatsite2.com" id="link2">Link Name2</a>is the second link to another web site
<a href="http://somegreatsite3.com" id="link3">Link Name3</a>is the third link to another web site
<P  align=justify> This is a paragraph 1! </P> 
<P  align=justify> This is a paragraph 2! </P> 
</div>    
<div class="second">
Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
<P  align=justify> This is a paragraph 1! </P> 
<P  align=justify> This is a paragraph 2! </P> 
<P> This is a paragraph 3! </P> 
<P> This is a paragraph 4! </P> 
<P> This is a paragraph 5! </p>
</div>  
</BODY>
</HTML> 
'''

# %% [markdown]
# # 借助 BeuautifulSoup 進行資料的剖析與選取

# %% [markdown]
# ## 呼叫 BeautifulSoup 模組 (要注意大小寫)

# %%
from bs4 import BeautifulSoup
import re

# %%
# 讀取 string，產生一個 soup object，
# html_doc 是前面我們定義的 string, "html.parser" 告訴 BeautifulSoup 我們要解析 html 文件。
# 煮湯
soup = BeautifulSoup(html_doc,"html.parser")
# 列印 soup object，看起來與前面的string無異，但已被加料了，可以進行許多後續的處理。
print (soup)
# Out:
# <html>
# <head><title>標題在這裡</title></head>
# <body bgcolor="FFFFFF">
# <div class="first">
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>is the first link to another web site
# <a href="http://somegreatsite2.com" id="link2">Link Name2</a>is the second link to another web site
# <a href="http://somegreatsite3.com" id="link3">Link Name3</a>is the third link to another web site
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# </div>
# <div class="second">
# Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# <p> This is a paragraph 3! </p>
# <p> This is a paragraph 4! </p>
# <p> This is a paragraph 5! </p>
# </div>
# </body>
# </html>

# %% [markdown]
# ## .prettify() 顯示成對的層次結構

# %%
# 顯示層次，但還不是看得很清楚。
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    標題在這裡
#   </title>
#  </head>
#  <body bgcolor="FFFFFF">
#   <div class="first">
#    <a href="http://somegreatsite1.com" id="link1">
#     Link Name1
#    </a>
#    is the first link to another web site
#    <a href="http://somegreatsite2.com" id="link2">
#     Link Name2
#    </a>
#    is the second link to another web site
#    <a href="http://somegreatsite3.com" id="link3">
#     Link Name3
#    </a>
#    is the third link to another web site
#    <p align="justify">
#     This is a paragraph 1!
#    </p>
#    <p align="justify">
#     This is a paragraph 2!
#    </p>
#   </div>
#   <div class="second">
#    Send me mail at
#    <a href="mailto:support@yourcompany.com">
#     support@yourcompany.com
#    </a>
#    <p align="justify">
#     This is a paragraph 1!
#    </p>
#    <p align="justify">
#     This is a paragraph 2!
#    </p>
#    <p>
#     This is a paragraph 3!
#    </p>
#    <p>
#     This is a paragraph 4!
#    </p>
#    <p>
#     This is a paragraph 5!
#    </p>
#   </div>
#  </body>
# </html>

# %% [markdown]
# # 重點是要截取資訊

# %% [markdown]
# ## 尋找標記.tag
# * 例如 .a，表示尋找 < a> 標記，並列出其內容。
# * 注意：只顯示找到的第一個的內容

# %%
# 尋找第一個 <a> tag
soup.a
# Out:
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>

# %%
# 用 find 指今亦可，結果一樣, 顯示找到的第一個 tag 
soup.find('a')
# Out:
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>

# %% [markdown]
# ##  標記內的屬性，href=, id=

# %%
# <a> 內的屬性 href，亦即網址聯結，注意要用中括弧。
soup.a['href']
# Out:
# 'http://somegreatsite1.com'

# %%
#  <a> 內的屬性 id
soup.a['id']
# Out:
# 'link1'

# %% [markdown]
# ## 標記內的字串
# ### 找出 < a>..... < /a>包含的字串，三種方法 .contents,  .string, .text

# %%
# <a> 包夾的字串, list 格式
soup.a.contents
# Out:
# ['Link Name1']

# %%
# <a> 包夾的字串，string 格式
soup.a.string
# Out:
# 'Link Name1'

# %%
# 效果一樣，string 格式
soup.a.text
# Out:
# 'Link Name1'

# %% [markdown]
# ## < div> 標記的內容

# %%
soup.div
# Out:
# <div class="first">
# <a href="http://somegreatsite1.com" id="link1">Link Name1</a>is the first link to another web site
# <a href="http://somegreatsite2.com" id="link2">Link Name2</a>is the second link to another web site
# <a href="http://somegreatsite3.com" id="link3">Link Name3</a>is the third link to another web site
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# </div>

# %%
# 第一個 div 內夾的 string。\n 表跳行符號
soup.div.text
# Out:
# '\nLink Name1is the first link to another web site\nLink Name2is the second link to another web site\nLink Name3is the third link to another web site\n This is a paragraph 1! \n This is a paragraph 2! \n'

# %%
# 取消跳行符號，直接跳行
print (soup.div.text)
# Out:
# Link Name1is the first link to another web site
# Link Name2is the second link to another web site
# Link Name3is the third link to another web site
#  This is a paragraph 1!
#  This is a paragraph 2!

# %% [markdown]
# ## < p> 標記的內容

# %%
# <p> 內有一個屬性 align, 其值為 justify
soup.p
# Out:
# <p align="justify"> This is a paragraph 1! </p>

# %%
# 只顯示包含的 string
soup.p.text
# Out:
# ' This is a paragraph 1! '

# %% [markdown]
# # 找出符合條件的所有內容

# %% [markdown]
# # .find_all() 指令
# * 找出所有合於條件的所有內容，存成 list。

# %% [markdown]
# ##  列出所有的 < a> 的內容，存成 list

# %%
# list
list_a=soup.find_all("a")
print (len(list_a))
print (list_a)
# Out:
# 4
# [<a href="http://somegreatsite1.com" id="link1">Link Name1</a>, <a href="http://somegreatsite2.com" id="link2">Link Name2</a>, <a href="http://somegreatsite3.com" id="link3">Link Name3</a>, <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>]

# %%
# 印出找到的第一個聯結
print (list_a[0]['href'])
# Out:
# http://somegreatsite1.com

# %%
# 所有的聯結都印出來
for a in list_a:
    print (a['href'])
# Out:
# http://somegreatsite1.com
# http://somegreatsite2.com
# http://somegreatsite3.com
# mailto:support@yourcompany.com

# %% [markdown]
# ## < p>  印出所有的段落文字

# %%
list_p=soup.find_all("p")
for p in list_p:
    print(p.text)
# Out:
#  This is a paragraph 1!
#  This is a paragraph 2!
#  This is a paragraph 1!
#  This is a paragraph 2!
#  This is a paragraph 3!
#  This is a paragraph 4!
#  This is a paragraph 5!

# %% [markdown]
# ## 尋找所有 < div> 下面屬性class為second的東東

# %%
# list
list_div=soup.find_all("div", {'class':"second"})
print (list_div)
# Out:
# [<div class="second">
# Send me mail at <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>
# <p align="justify"> This is a paragraph 1! </p>
# <p align="justify"> This is a paragraph 2! </p>
# <p> This is a paragraph 3! </p>
# <p> This is a paragraph 4! </p>
# <p> This is a paragraph 5! </p>
# </div>]

# %%
#從div層中再抓取p的資料
# 接續上例，印出 < p> 內的文字，存成 list
paragraph=[]
# 找出所有合於條件的 <div>
list_div=soup.find_all("div", {'class':"second"})
# 如果有找到的話
if len(list_div)>0:
    for li in list_div:    
        # 找出所有的 <p>
        list_p=li.find_all("p")
        for p in list_p:
            # 加入 list
            paragraph.append(p.text)
    print (paragraph)
# Out:
# [' This is a paragraph 1! ', ' This is a paragraph 2! ', ' This is a paragraph 3! ', ' This is a paragraph 4! ', ' This is a paragraph 5! ']

# %%
# 第一個 div 夾的的 string
list_div[0].text
# Out:
# '\nSend me mail at support@yourcompany.com\n This is a paragraph 1! \n This is a paragraph 2! \n This is a paragraph 3! \n This is a paragraph 4! \n This is a paragraph 5! \n'

# %%
# 比較 .text 與 .contents 的差異 (string 與 list 的差別)
list_div[0].contents #contents 中有個個list
# Out:
# ['\nSend me mail at ',
#  <a href="mailto:support@yourcompany.com">support@yourcompany.com</a>,
#  '\n',
#  <p align="justify"> This is a paragraph 1! </p>,
#  '\n',
#  <p align="justify"> This is a paragraph 2! </p>,
#  '\n',
#  <p> This is a paragraph 3! </p>,
#  '\n',
#  <p> This is a paragraph 4! </p>,
#  '\n',
#  <p> This is a paragraph 5! </p>,
#  '\n']

# %%
# 0 表示 list 裡面的第一個元素。
list_div[0].contents[0]
# Out:
# '\nSend me mail at '

# %% [markdown]
# # 真正的 html檔，手動下載某一篇文章，存成html格式
# * 範例檔 "d:/my python/_news/20180302_這裡要移除 蔣介石銅像變木乃伊.html

# %% [markdown]
# ## step 1 檢查 soup是否成功?

# %%
# 完整檔名，隨便找一個檔測試
path = ""
path="C:/Users/HSIU/Desktop/108-1/python_ntu"
file_name=path +'/news/'+'20180302_這裡要移除 蔣介石銅像變木乃伊.html'
# 讀取檔案，注意此檔格式為 'big5'，無須 encoding。*****
content = open(file_name,'r').read() 

# 若為 utf-8 則須 encoding
#content = open(file_name,'r',encoding='utf8').read()  

# 開始煮湯
soup = BeautifulSoup(content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!-- saved from url=(0228)https://d1b10bmlvqabco.cloudfront.net/attach/jlrqtgi8cpaej/i91z715dpjc6y0/k2dbnlk3scft/20180302_%E9%80%99%E8%A3%A1%E8%A6%81%E7%A7%BB%E9%99%A4_%E8%94%A3%E4%BB%8B%E7%9F%B3%E9%8A%85%E5%83%8F%E8%AE%8A%E6%9C%A8%E4%B9%83%E4%BC%8A.html -->
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title>聯合知識庫 - 全球最大的中文新聞資料庫平台</title>
# <link href="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/fontello.css" rel="stylesheet"/>
# <link href="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/font-awesome.min.css" rel="stylesheet"/>
# <!-- // masterslidercss 套件 -->
# <link href="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/masterslider.css" rel="stylesheet"/>
# <link href="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/style.css" rel="stylesheet"/>
# </head>
# <body>
# <div id="container">
# <!-- // 燈箱遮罩 -->
# <div class="overlay close"></div>
# <!-- // 手機左右側滑選單收合遮罩 -->
# <div class="mob-menu-overlay close"></div>
# <!-- // header+menu -->
# <!--#include virtual="inc/header.html" -->
# <header>
# <!-- // toprow menu -->
# <div class="toprow_bar mob-none">
# <div class="wrapper clearfix">
# <ul class="toprow">
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/udn">全文報紙</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/fullpage/">原版報紙</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/image/">新聞圖庫</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/bsw/">商業周刊</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/gvm/">遠見</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/brain/">動腦</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/video/">影音</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/faq/authority.html">授權</a></li>
# </ul>
# </div>
# </div>
# <div class="wrapper top clearfix">
# <!-- // mobile left+right icon -->
# <span class="button menu-button-left">
# <i aria-hidden="true" class="fa fa-reorder"></i>
# </span>
# <span class="button menu-button-right">
# <i aria-hidden="true" class="fa fa-user"></i>
# </span>
# <!-- // logo -->
# <div class="logo-group">
# <div class="logo">
# <div class="link clearfix">
# <a class="data-index" href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Index"></a>
# <a class="index" href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Index?cp=udn"></a>
# </div>
# <img alt="全文報紙資料庫" src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/logo.svg" title="全文報紙資料庫"/>
# </div>
# <div class="logo-ip">
# <img alt="定址會員" src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/logo-ip.svg" title="定址會員"/>
# </div>
# </div>
# <ul class="menu clearfix">
# <li>
# <a class="fa-user-times" href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Logout?toUrl=/udn">登出</a>
# </li>
# <li class="question-circle">
# <a class="fa-question-circle" href="https://d1b10bmlvqabco.cloudfront.net/faq/fulltext.html" target="_blank">常見問題</a>
# </li>
# <li class="web-none">
# <a class="fa-info-circle popup-btn pop-text" data-popup="聯合知識庫提供之線上資料庫查詢服務，僅供個人閱讀、瀏覽，禁止重製轉載、禁止以程式或機器讀取擷取或下載資料。若有研究分析及其他利用需求，請與我們聯繫授權事宜。" href="https://d1b10bmlvqabco.cloudfront.net/attach/jlrqtgi8cpaej/i91z715dpjc6y0/k2dbnlk3scft/20180302_%E9%80%99%E8%A3%A1%E8%A6%81%E7%A7%BB%E9%99%A4_%E8%94%A3%E4%BB%8B%E7%9F%B3%E9%8A%85%E5%83%8F%E8%AE%8A%E6%9C%A8%E4%B9%83%E4%BC%8A.html">著作權聲明</a>
# </li>
# </ul>
# </div>
# </header>
# <div class="print-header-control clearfix">
# <div class="logo-data">
# <img alt="聯合知識庫" src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/logo.svg" title="聯合知識庫"/>
# </div>
# <button class="friendlyPrint">
# <i aria-hidden="true" class="fa fa-print"></i>友善列印</button>
# </div>
# <main>
# <div class="wrapper clearfix">
# <!-- // mainbar -->
# <div class="clearfix" id="mainbar">
# <!-- // breadcrumb -->
# <div class="breadcrumb"><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Index">首頁</a><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Index?cp=udn">全文報紙資料庫</a><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Searchdec?SearchString=%A7%DC%AA%A7%2B%A4%E9%B4%C1%3E%3D20081005%2B%A4%E9%B4%C1%3C%3D20180913%2B%B3%F8%A7%4F%3D%C1%70%A6%58%B3%F8&amp;select=1&amp;sharepage=20&amp;kind=2&amp;page=10&amp;udndbid=udndata">標題頁</a><a>內文頁</a></div>
# <section class="story">
# <div class="story-btn-group">
# <button class="send" onclick="javascript:window.open('/ndapp/FwdArticle?id=8976034&amp;udndbid=udndata&amp;searchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D')"><i aria-hidden="true" class="fa fa-envelope-o"></i><span class="text">轉寄</span></button>
# <button class="mob-none contacts popup-btn pop-html-big-H" data-html="#print"> <i aria-hidden="true" class="fa fa-print"></i>列印</button>
# </div>
# <div class="story-content" id="print">
# <div class="story-title">
# <h2>全國警局唯一留存</h2>
# <h1>這裡要移除 蔣介石銅像變木乃伊</h1>
# </div>
# <span class="story-report">【記者吳淑君、游明煌╱基隆報導】</span>
# <article>
# <div class="ms-staff-carousel ms-filters-template pic">
# <div class="master-slider ms-skin-default" id="masterslider">
# <div class="ms-slide" data-delay="1" data-fill-mode="fit">
# <img alt="兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/blank.gif" title="兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。"/>
# <a class="popup-btn pop-img" data-src="/ndapp/ShowPhoto?BB1083C88EE533402335252BE66CC66A-n1graph_server=aHR0cDovLzE5Mi4xNjguNy4xNzQ=&amp;pic_path=LzIwMTgvMDMvMDIvMS8=&amp;pic_name=OTg2ODIxXzcwOTI3My5qcGc=" href="https://d1b10bmlvqabco.cloudfront.net/attach/jlrqtgi8cpaej/i91z715dpjc6y0/k2dbnlk3scft/20180302_%E9%80%99%E8%A3%A1%E8%A6%81%E7%A7%BB%E9%99%A4_%E8%94%A3%E4%BB%8B%E7%9F%B3%E9%8A%85%E5%83%8F%E8%AE%8A%E6%9C%A8%E4%B9%83%E4%BC%8A.html"></a>
# <div class="ms-layer description" data-duration="100">
# 	                       		兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。　記者游明煌╱攝影
# 	                      </div>
# </div>
# </div>
# </div>
# <div class="print-pic">
# <div class="print-pic-img">
# <img src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/ShowSmallPhoto"/>
# </div>
# <div class="print-pic-description">
#                   	  兩樣情
# 基隆市警局的蔣介石銅像昨天上午被抗議後，晚間包成木乃伊。
#
#                   </div>
# </div>
# <p>這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來<font color="RED">抗爭</font>。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。</p><p>
# 市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。</p><p>
# 游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。</p><p>
# 基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。</p><p>
# 基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。</p><p>
# </p>
# </article>
# <span class="story-source">【2018-03-02/聯合報/B2版/新北基隆要聞】</span>
# </div>
# </section>
# <button class="hide button-color popup-btn pop-html" data-html="#message-1" id="addAuSuccess">狀態一</button>
# <button class="hide button-color popup-btn pop-text" data-popup="&lt;p&gt;很抱歉！您加入的資料中含有不可授權的資料，無法加入文章線上授權中！&lt;/p&gt;" id="addAuFail">狀態三</button>
# </div>
# <!-- // sidebar -->
# <!-- // 會員資訊+會員服務+功能服務 -->
# <!--#include virtual="inc/sidebar-service.html" -->
# <aside class="service">
# <!-- // 會員資訊 -->
# <div class="info flex-space-between">
# </div>
# <!-- // 會員服務 -->
# <div class="member">
# <div class="title">會員服務</div>
# <a class="fa-unlock popup-btn pop-html-big" data-html="#authority" href="https://d1b10bmlvqabco.cloudfront.net/attach/jlrqtgi8cpaej/i91z715dpjc6y0/k2dbnlk3scft/20180302_%E9%80%99%E8%A3%A1%E8%A6%81%E7%A7%BB%E9%99%A4_%E8%94%A3%E4%BB%8B%E7%9F%B3%E9%8A%85%E5%83%8F%E8%AE%8A%E6%9C%A8%E4%B9%83%E4%BC%8A.html">我可使用的權限</a>
# <span>
# <i aria-hidden="true" class="fa fa-database"></i>我可使用的資料庫有
# 		  <ul>
# <li>全文報紙資料庫</li>
# </ul>
# </span>
# </div>
# </aside>
# <!-- // 我可使用的權限 -->
# <div class="hide" id="authority">
# <div class="authority-more">
# <div class="table-head left">您目前可使用的權限如下</div>
# <div class="table-border table-row list">
# <ul class="table-head-two three">
# <li class="center serve">付費商品</li>
# <li class="center points">可閱讀則數</li>
# <li class="center deadline">到期日</li>
# </ul>
# <ul class="authority-content">
# <li>
# <div class="serve">定址會員-不含圖庫.全頁</div>
# <div class="points">0</div>
# <div class="deadline">2018.12.31</div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <aside class="clearfix" id="sidebar">
# <hr class="space-5-15"/>
# <div class="other-news">
# <div class="title">其他新聞</div>
# <div class="detail">本頁為<span class="mark">199/6457</span>筆</div>
# <ul>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=200&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976038&amp;showUserSearch=&amp;firstFatherCateID=">馬頭山今環評 高市：絕不敷衍放水</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=201&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975999&amp;showUserSearch=&amp;firstFatherCateID=">航空城2512公頃 重納宏竹、兩河？</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=202&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8976184&amp;showUserSearch=&amp;firstFatherCateID=">把軍公教政治化，台灣只會更動盪</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=203&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975227&amp;showUserSearch=&amp;firstFatherCateID=">人人都可能成為上校</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=204&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8975217&amp;showUserSearch=&amp;firstFatherCateID=">意識形態治國 莫怪陳抗不斷</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=205&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974319&amp;showUserSearch=&amp;firstFatherCateID=">對軍、公教不同調 冒出矛盾</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=206&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974312&amp;showUserSearch=&amp;firstFatherCateID=">軍人年改最終版 待兩院討論</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=207&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974300&amp;showUserSearch=&amp;firstFatherCateID=">八百壯士3訴求：溝通、暫緩、釋憲</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=208&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974316&amp;showUserSearch=&amp;firstFatherCateID=">藍疾呼「別踐踏國軍尊嚴」</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=209&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974269&amp;showUserSearch=&amp;firstFatherCateID=">「維安不力」 質疑聲起</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=210&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974272&amp;showUserSearch=&amp;firstFatherCateID=">維安署長面臨考驗</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=211&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974278&amp;showUserSearch=&amp;firstFatherCateID=">國安問題 軍人年改不可不慎</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=212&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974369&amp;showUserSearch=&amp;firstFatherCateID=">濕地，你們還好嗎？</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=213&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8974090&amp;showUserSearch=&amp;firstFatherCateID=">亞泥釋善意 經部促3方會商</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=214&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973396&amp;showUserSearch=&amp;firstFatherCateID=">原保地不拆屋就撤租 承租人抗議</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=215&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8973409&amp;showUserSearch=&amp;firstFatherCateID=">加國回補老兵福利 軍改想過嗎</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=216&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971715&amp;showUserSearch=&amp;firstFatherCateID=">說文解字看新聞</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=217&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8971916&amp;showUserSearch=&amp;firstFatherCateID=">藍轉戰公投 聚焦反核食、空汙</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=218&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8968607&amp;showUserSearch=&amp;firstFatherCateID=">卡管…卡掉台大多元色彩</a></li>
# <li><a href="https://d1b10bmlvqabco.cloudfront.net/ndapp/Story?no=219&amp;page=10&amp;udndbid=udndata&amp;SearchString=p9yqpyuk6bTBPj0yMDA4MTAwNSuk6bTBPD0yMDE4MDkxMyuz%2BKdPPcFwpliz%2BA%3D%3D&amp;sharepage=20&amp;select=1&amp;kind=2&amp;article_date=2018-03-02&amp;news_id=8963320&amp;showUserSearch=&amp;firstFatherCateID=">等了20年 北大安置住宅入厝</a></li>
# </ul>
# </div>
# </aside>
# </div>
# </main>
# <!-- // 版權聲明 -->
# <!--#include virtual="inc/footer.html" -->
# <footer>
# <div class="footer-menu mob-none clearfix">
# <!--
#     <a href="http://co.udn.com/co/index">關於我們</a>
#     <a href="/faq/authority.html">圖文轉載授權</a>
#     <a href="/faq/marketing.html">行銷業務</a>
#     <a href="https://udn.com/page/topic/495">著作權聲明</a>
#     <a href="http://www.udngroup.com/information/privacy">隱私權聲明</a>
#     <a href="https://udn.com/page/topic/185">服務條款</a>
#     <a href="/aboutus.html">udndata介紹</a>
#     <a href="/faq/service.html">客服</a>
# 	-->
# <script async="" src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/beacon.js.下載"></script><script async="" src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/analytics.js.下載"></script><script src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/footer_data_b.js.下載"></script>
# <script>ft_t5()</script>
# </div>
# <div class="copyright">聯合線上公司 著作權所有 © udn.com All Rights Reserved.</div>
# <!-- google analytics -->
# <script>
#
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-19660006-1', 'auto');
#
# 	ga('create', 'UA-20357535-1', 'auto', {'name': 'udndata'});
#
# 	ga('send', 'pageview');
#
# 	ga('udndata.send', 'pageview');
#
# 	</script>
# <!-- google analytics -->
# <!-- TEK1110B0001 -->
# <!-- Begin comScore Tag -->
# <script>
#
# 	  var _comscore = _comscore || [];
#
# 	  _comscore.push({ c1: "2", c2: "7390954" });
#
# 	  (function() {
#
# 	    var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#
# 	    s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#
# 	    el.parentNode.insertBefore(s, el);
#
# 	  })();
#
# 	</script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=7390954&amp;cv=2.0&amp;cj=1">
# </img></noscript>
# <!-- End comScore Tag -->
# </footer>
# <!-- // gotop -->
# <a href="https://d1b10bmlvqabco.cloudfront.net/attach/jlrqtgi8cpaej/i91z715dpjc6y0/k2dbnlk3scft/20180302_%E9%80%99%E8%A3%A1%E8%A6%81%E7%A7%BB%E9%99%A4_%E8%94%A3%E4%BB%8B%E7%9F%B3%E9%8A%85%E5%83%8F%E8%AE%8A%E6%9C%A8%E4%B9%83%E4%BC%8A.html#top" id="gotop">Top</a>
# <!-- // 公版 -->
# <div class="popup close">
# <div class="close-btn btn-right"><i class="i-close"></i></div>
# <div class="popup-content"></div>
# <div class="btn-group-setup center"></div>
# </div>
# <!-- // 訊息狀態 demo -->
# <div class="hide" id="message-1">
# <div class="message-1">
# <p class="center">您勾選的資料已成功加入「文章線上授權」！！</p>
# <div class="btn-group center">
# <button class="button-close" onclick="javascript: window.location.href='/ndapp/authority/AuIndex'">查看「文章線上授權」</button><button class="button-close">繼續查詢</button>
# </div>
# </div>
# </div>
# </div>
# <!-- jquery 主程式 -->
# <script src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/jquery-1.11.1.min.js.下載"></script>
# <!-- masterslider 主程式 + 設定檔 -->
# <script src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/masterslider.js.下載"></script>
# <script src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/masterslider-setup.js.下載"></script>
# <!-- jquery 其他程式    -->
# <script src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/openBox.js.下載"></script>
# <script src="./聯合知識庫 - 全球最大的中文新聞資料庫平台_files/function.js.下載"></script>
# <script>
#     $(function() {
# /*
# 		$('.add').on('mouseenter mouseleave', function(e) {
#         // console.log(e.target.classList[1]);
#         var event = e.type;
#         // var test = e.target.classList[1]
#
#         if (e.target.classList.contains('select-clipping')) {
#           return false;
#         }
#         // console.log('continue');
#         $('.clipping-pop').hide();
#
#         if (event === 'mouseenter') {
#           $(this).children('.clipping-pop').show();
#           $('.overlay').addClass('opacity');
#           $('.overlay').removeClass('close');
#         } else {
#           $(this).children('.clipping-pop').hide();
#           $('.overlay').removeClass('opacity');
#           $('.overlay').addClass('close');
#         }
#
#       });
#
#       $('.overlay').on('mouseover', function() {
#         // $('.overlay').addClass('close');
#         $('.clipping-pop').hide();
#       });
# */
#      $('.add').on('click', function (e) {
#         var chkThis = e.target === this;
#         var chkSpan = e.target.nodeName.toLowerCase() === 'span';
# 		console.log( e.target.nodeName);
#         var chkFa = e.target.classList.contains('fa-plus-square');
#
#         if (chkThis || chkSpan || chkFa) {
#           $(this).toggleClass('active');
#         }
#       });
#
#       $('.add-clipping, .select-clipping').on('focus', function() {
#         $(this).prev(":radio").prop('checked', true);
#       });
#
#
#
#
#
#
#
#     });
#
# 	//文庫內文頁觀看全頁報紙影像
# 	function checkfull( id, check ) {
# 		if(check=="yes"){
# 			//var ans = window.confirm( "觀看全頁報紙影像需扣儲值點數一點，您要觀看嗎?\n全頁報紙影像僅供觀看，不提供下載功能。\n影像檔輸出速度較慢，請稍待。" );
# 			var ans = window.confirm( "觀看全頁報紙影像需扣可閱讀則數一則，您要觀看嗎?\n全頁報紙影像僅供觀看，不提供下載功能。\n影像檔輸出速度較慢，請稍待。" );
# 			if( ans ) {
# 				window.open( '/ndapp/ShowFullPaper?id=' + id ,'check','scrollbars,resizable=yes,width='+screen.width+','+'height='+screen.height);
# 			}
# 			return false;
# 		}else if(check=="no"){
# 			window.open( '/ndapp/ShowFullPaper?id=' + id ,'check','scrollbars,resizable=yes,width='+screen.width+','+'height='+screen.height);
# 		}
# 	}
#
#
#
#
#     $('.contacts').on('click', function () {
#       $('.popup-content').before("<div class='print-header clearfix'><div class='logo-data'><img src='/images/newdata/images_2017/logo-data.svg' alt='聯合資料庫' title='聯合資料庫'></div><button class='friendlyPrint'><i class='fa fa-print' aria-hidden='true'></i>友善列印</button></div>");
#       $('.pic').hide();
#       $('.print-pic').show();
#     });
#
#     $('body').on('click', '.friendlyPrint', function (e) {
#       $('.print-header').remove();
#       $('.popup, .overlay').addClass('close');
#       $('.popup').removeAttr('style');
#       $('.popup-content, .btn-group-setup').empty();
#       window.print();
#       $('.pic').show();
#       $('.print-pic').hide();
#       $('.friendlyPrint').remove();
#     });
#
#     var printPicW = $('.print-pic-img img').width();
#     var printPicH = $('.print-pic-img img').height();
#     var imgScale = printPicW / printPicH;
#     var originalScale = $('.print-pic-img').width() / $('.print-pic-img img').height();
#
#     if (printPicW > printPicH && imgScale < originalScale) {
#       $('.print-pic-img img').css({ 'width': '100%', 'height': 'auto' });
#     } else {
#       $('.print-pic-img img').css({ 'width': 'auto', 'height': '100%' });
#     }
#
#
#
#
#
#
#
#
#
#   </script>
# </body></html>

# %% [markdown]
# ## 先想想要讀取什麼資料？

# %%
# 讀取標題，h1,h2,h3,h4
# 在 tag "div", 屬性 class = story-title
list_div=soup.find_all("div", {'class':"story-title"})
if len(list_div)>0:
    for div in list_div:
        try:
            h1=div.h1.text
        except:
            h1=''
        try:
            h2=div.h2.text
        except:    
            h2=''
        try:    
            h3=div.h3.text
        except:
            h3=''
        try:    
            h4=div.h4.text
        except:
            h4=''        
print (h1)
print (h2)
print (h3)
print (h4)

# 讀取作者
# 在 tab "span", 屬性 class = story-title
list_span=soup.find_all("span", {'class':"story-report"})
if len(list_span)>0:
    author=list_span[0].text
print (author)

# 讀取時間及版次    
# 在 tab "span", 屬性 class = story-source
list_span=soup.find_all("span", {'class':"story-source"})
if len(list_span)>0:
    time=list_span[0].text
print (time)

# 讀取內文
# 在 tab "p"
list_p=soup.find_all("p")
for p in list_p:
    print(p.text)
# Out:
# 這裡要移除 蔣介石銅像變木乃伊
# 全國警局唯一留存
#
#
# 【記者吳淑君、游明煌╱基隆報導】
# 【2018-03-02/聯合報/B2版/新北基隆要聞】
# 這幾年每到二二八，基隆市就不平靜，市議員游祥耀昨天上午點名市警局，要求移除全國警局唯一留存的蔣介石銅像，以免引來抗爭。市警局昨天下午就用帆布把銅像打包得密不透風；警方表示，這是為了避免被噴漆、破壞，將擇日移置。
#
# 市警局員警、員工昨晚下班看到樓梯間的銅像被包起來都很錯愕，有人說，大門有員警廿四小時站崗，還怕被噴漆破壞嗎？有員警忍不住說，「被包成像木乃伊，好可憐」。
#
# 游祥耀指出，基隆在二二八發生這麼大的傷害和屠殺，但蔣介石銅像一直沒動，警察局是保護人民的治安單位，擺一個威權塑像很不洽當；他督促市府在兩個月內趕快處理掉，否則抗議者會不會用激烈手段破壞，他不敢保證。
#
# 基隆市警局主秘廖誌銘表示，根據調查，各縣市警察局內部，已經沒有類似的銅像，基隆市警局會盡快地移置銅像，正與桃園兩蔣文化園區協調存放和保存地點。
#
# 基隆市政府表示，任何政治塑像都不應該存在於公共空間、機關以及教育場所內，警察是人民的保母，警察局更不應留有威權時代的政治塑像，有違民主時代的潮流。
#
#
# 您勾選的資料已成功加入「文章線上授權」！！

# %% [markdown]
# ## 多個 html 檔
# * 這是聯合報有關抗爭的文章，92篇。都放在 d:/My python/_news/ 下面

# %%
import os
import re
path='C:/Users/HSIU/Desktop/108-1/python_ntu'
# List 記錄所有的檔名
doc_list = []
# 指定資料夾
os.chdir(path+'/news/')
# 找出所有.html 檔
for f in os.listdir("."):
    # 檔案篩選
     if f.endswith(".html"):
        # 第一個字母會是亂碼，先去除    
        f=re.sub("\ufeff","",f)        
        doc_list.append(f)       
print (len(doc_list))
doc_list
# Out:
# 92
# ['20180101_許悔之、許含光 父子的咖啡對談.html',
#  '20180102_港萬人遊行 反高鐵一地兩檢.html',
#  '20180103_臨會審總預算 藍擬提200 刪減凍結案.html',
#  '20180103_遭點名換將 六部全否認.html',
#  '20180104_北檢潑髒水 把證人當犯人.html',
#  '20180104_徵農地建滯洪池 農民嘉縣府前抗議.html',
#  '20180104_監院糾正政院、勞動部.html',
#  '20180105_下周一 夜宿立院 勞團不排除激烈行動.html',
#  '20180106_時力鏈鎖議場 民進黨破門反制.html',
#  '20180106_盟友反目 朝野還有協商空間？.html',
#  '20180107_濕地立法三年 基金沒編半毛.html',
#  '20180107_立委上街 警柔性勸導.html',
#  '20180108_勞基法再戰府院堅持「往前走」.html',
#  '20180108_勞基鬥法 立院臨會延燒.html',
#  '20180108_國民黨攜時力 聯合作戰？.html',
#  '20180108_封鎖國會大戲：一面權力的照妖鏡.html',
#  '20180108_綠委守大門「身心俱疲」.html',
#  '20180108_蔡籲協商 時力拒絕.html',
#  '20180109_別低估「政治危機」.html',
#  '20180109_勞基法今強行表決？藍準備武鬥.html',
#  '20180109_勞基鬥法 今拚3讀.html',
#  '20180109_勞工抗議史第3度臥軌.html',
#  '20180109_時力被帶離 柯Ｐ：SOP會更多.html',
#  '20180110_7休1改為14休4 拍板.html',
#  '20180110_勞團喊：我們心沉痛.html',
#  '20180110_抗爭博版面 手腳被看破！.html',
#  '20180110_抗爭為勞工 算計又如何？.html',
#  '20180110_綠奇招 擋藍案海戰術.html',
#  '20180110_豪氣的悲歌.html',
#  '20180111_因為憤怒，所以棄守？.html',
#  '20180228_維安署長面臨考驗.html',
#  '20180228_藍疾呼「別踐踏國軍尊嚴」.html',
#  '20180228_軍人年改最終版 待兩院討論.html',
#  '20180301_人人都可能成為上校.html',
#  '20180301_意識形態治國 莫怪陳抗不斷.html',
#  '20180302_把軍公教政治化，台灣只會更動盪.html',
#  '20180302_航空城2512公頃 重納宏竹、兩河？.html',
#  '20180302_這裡要移除 蔣介石銅像變木乃伊.html',
#  '20180302_馬頭山今環評 高市：絕不敷衍放水.html']

# %% [markdown]
#   # 測試成功，讀取多篇文章

# %%
head=[]
author=[]
time=[]
texts=[]
i=0
h1=[]
h2=[]
h3=[]
h4=[]
# 讀取各篇文章，成為一個 list
for f in doc_list: 
    i+=1
    # 完整檔名，隨便找一個檔測試
    file_name=path +'/news/'+ f
    # 讀取檔案，注意格式為 'big5'，無毋 encoding。*****
    content = open(file_name,'r').read()  
    # 煮湯
    soup = BeautifulSoup(content,"html.parser")

    # 讀取標題，h1,h2,h3,h4
    list_div=soup.find_all("div", {'class':"story-title"})
    if len(list_div)>0:
        for div in list_div:
            try:
                h1=div.h1.text
            except:
                h1=''
            try:
                 h2=div.h2.text
            except:    
                h2=''
            try:    
                 h3=div.h3.text
            except:
                h3=''
            try:    
                 h4=div.h4.text
            except:
                h4=''   
                
        head.append(h1+h2+h3+h4)
        # 讀取作者
        list_span=soup.find_all("span", {'class':"story-report"})
        if len(list_span)>0:
            string=list_span[0].text
            # 去掉特殊符號
            string=re.sub("【","",string)
            string=re.sub("】","",string)  
            author.append(string)
        else:
            author.append('')

        # 讀取時間及版次    
        list_span=soup.find_all("span", {'class':"story-source"})
        if len(list_span)>0:
            string=list_span[0].text
            # 去掉特殊符號
            string=re.sub("【","",string)
            string=re.sub("】","",string)  
            time.append(string)
        else:
            time.append('')

        # 讀取內文
        string=''
        list_p=soup.find_all("p")
        for p in list_p:
            string=string+p.text
            
        # 異體字轉換
        string=re.sub("台","臺",string)         
        # 刪除中文的空格符號，這些看起來像是亂碼先刪除
        string=re.sub("\ufeff","",string)
        string=re.sub("\u3000","",string)            
            
        texts.append(string)    
    # 每處理完10篇文章，報告進度。******    
    if i%10==0:
        print (i, 'done')
    elif i==len(doc_list):
        print ('finished')
# Out:
# 10 done
# 20 done
# 30 done
# 40 done
# 50 done
# 60 done
# 70 done
# 80 done
# 90 done
# finished

# %%
import pandas as pd   
data=list(zip(head,author,time,texts))
df=pd.DataFrame(data,columns=['title','author','time','text'])
df
# Out:
#                                                   title              author  \
# 0                                    77年十大消費新聞 房價發燒排名第一                 台北訊
# 1                勞動黨昨天宣布建黨傾向採議會與街頭路線交叉運作 民進黨與工黨表示願與公平競爭          記者林念平╱台北報導
# 2                              向世界天才挑戰!《克博士專案》送戈巴契夫一頂假髮               鄭麗園/輯
# 3     微妙關係 休戚與共!?立委吳勇雄抨擊利用慈善捐款出國事,引發.....集思會與民進黨團之間 ...            記者黃清龍/特稿
# 4                  揮不去的吳鳳神話 寫下句點!?擾攘多年情緒不見排解 北迴歸線標竿如何重建            記者郭勝恩/特稿
# 6184  行政院長賴清德昨天主持治安會報時表示，九合一選舉選務及維安工作的困難度高，中選會與內政部警政...
# 6185  機師罷工危機暫時解除，讓新任交長吳宏謀拔除了上任以來的第一顆炸彈。\n前年四月間，華航機師就...
# 6186  以無黨參選臺南市長的蘇煥智、陳永和昨完成登記，被問及泛綠整合問題，蘇煥智表示，「民進黨要整合...
# 6187  最近一兩年，幾個常接觸移工的團體，像是燦爛時光東南亞主題書店、One-Forty、臺中109...
# 6188  嘉義縣布袋鎮岑海里823水災自救會百餘名受災戶，昨天上午在布袋港入口處，與臺灣港務公司布袋管...
# 6189  屏東市公勇路反拆遷戶向高雄高等行政法院提出聲請停止執行拆除案，法官裁定聲請駁回，屏東縣議員蔣...
# 6190  工業革命2.0、3.0喊得震天價響，真褻瀆了「工業革命」這樁獨一無二、無與倫比的大事。\n一...
# 6191  環保署反對各縣市都蓋焚化爐，南投縣納入雲林縣林內區域爐，唯因雲林民眾抗爭，林內焚化爐無法啟用...
# 6192  被譽為「臺灣政壇四公子」之一的清華大學前校長、知名物理學家沈君山，三度中風長期臥病，日前發燒...
# 6193  在美國大陸留學生與學人的中國共產黨黨員昨天發表集體退黨聲明，中國國民黨海工會主任鄭心雄取得了...
#
# [6194 rows x 4 columns]

# %% [markdown]
# ## pickle

# %%
import pickle
with open(path+"_news/news.pkl", "wb") as fp:   #Pickling
     pickle.dump(df, fp)

with open(path+"_news/news.pkl", "rb") as fp:   # Unpickling
     df1=pickle.load(fp)

# %%
df1==df
# Out:
#       title  author  time  text
# 0      True    True  True  True
# 1      True    True  True  True
# 2      True    True  True  True
# 3      True    True  True  True
# 4      True    True  True  True
# 5      True    True  True  True
# 6      True    True  True  True
# 7      True    True  True  True
# 8      True    True  True  True
# 9      True    True  True  True
# 10     True    True  True  True
# 11     True    True  True  True
# 12     True    True  True  True
# 13     True    True  True  True
# 14     True    True  True  True
# 15     True    True  True  True
# 16     True    True  True  True
# 17     True    True  True  True
# 18     True    True  True  True
# 19     True    True  True  True
# 20     True    True  True  True
# 21     True    True  True  True
# 22     True    True  True  True
# 23     True    True  True  True
# 24     True    True  True  True
# 25     True    True  True  True
# 26     True    True  True  True
# 27     True    True  True  True
# 28     True    True  True  True
# 29     True    True  True  True
# ...     ...     ...   ...   ...
# 6164   True    True  True  True
# 6165   True    True  True  True
# 6166   True    True  True  True
# 6167   True    True  True  True
# 6168   True    True  True  True
# 6169   True    True  True  True
# 6170   True    True  True  True
# 6171   True    True  True  True
# 6172   True    True  True  True
# 6173   True    True  True  True
# 6174   True    True  True  True
# 6175   True    True  True  True
# 6176   True    True  True  True
# 6177   True    True  True  True
# 6178   True    True  True  True
# 6179   True    True  True  True
# 6180   True    True  True  True
# 6181   True    True  True  True
# 6182   True    True  True  True
# 6183   True    True  True  True
# 6184   True    True  True  True
# 6185   True    True  True  True
# 6186   True    True  True  True
# 6187   True    True  True  True
# 6188   True    True  True  True
# 6189   True    True  True  True
# 6190   True    True  True  True
# 6191   True    True  True  True
# 6192   True    True  True  True
# 6193   True    True  True  True
#
# [6194 rows x 4 columns]

# %% [markdown]
# # 下載一個真正的網頁 html

# %% [markdown]
# ## 觀察網頁的程式碼

# %% [markdown]
# ### 現在的流覽器都有提供網頁原始碼檢查工具。以下，我們就用 Crome 簡單解說。
# * 首先，找到目標網頁，開啟網頁。
# * 第二，流覽網頁，看看它有什麼內容，每個聯結按一按，確定你定要擷取的資訊位置在哪裡。
# * 第三，在你要的資訊上面，滑鼠右鍵，選擇 [檢查網頁原始碼]，或[檢查] (inspection), 兩者都試試看，比較其差異。這個時候你會看到網頁的原始碼，找到目標資訊出現的位置。特別注意你要下載的資料前面的標記(tag)是什麼？其前後的標記是什麼？
# * 第四，每行程式左邊的「三角形」鍵頭，可開啟、縮合，便於顯示不同的層級。
# * 第五，左側頁面與右側程式相互對應，滑鼠移至左側圖面上的任何元件，滑鼠右鍵[檢查]，可看到相應的程式碼。滑鼠移至左側程式碼，相應的網頁畫面在右側會以色塊標示。
# * 第六，選按[network], 再 refresh 網頁，可以看到網頁登載的元件，以及各個子聯結的清單，按 [headers], [preview], [rsponse] 可以檢查各個聯結的內容。這可以幫助我們判斷我們要的資訊是位於哪個子聯結。這些子聯結都可以複製，便於進一步的分析。
# * 第七、很多網頁因為資訊太多，都有分頁的設計，點選 [下一頁] 看看網頁的結構是否有變化，變化的規則是什麼。
# * 第八、如果你要一次擷取多個網頁的資料，要注意各網頁的格式是否統一，如果不統一，就要撰寫適用各種情況的程式，否則會讀取錯誤。你會發現，資料格式不統一，通常是網路爬蟲很大的困擾。
# * 第九、Beautiful Soup 通常要配合 Regular Expression 一起使用，下一個講次，我們會討論， Regular Expression。

# %% [markdown]
# ## 先進去網頁，檢查網頁的結構
# * 資料在哪一個 tag 下面？
# * 是否必須到下一個聯結？
# * 聯結命名的規則？
# * 下一頁的網址命名規則？
# * get or post ? 本週我們只介紹 get
# * 動態或靜態 ? 本週只介紹靜態網頁。

# %% [markdown]
# * 現在我們要試試真正的網頁，咱們台大的首頁 http://www.nd.ntu.edu.tw/
# * 裡面有許許多多的資料，我們要選擇自己要的東西。

# %% [markdown]
# ## 方法一：使用 urllib.request.urlopen()

# %%
# beautiful soup
import urllib
import urllib.request
from bs4 import BeautifulSoup
import io
import os
import json
import re

# %%
# 國發所首頁
url='http://www.nd.ntu.edu.tw/'
# request.urlopen()提出進入網頁的要求
thepage=urllib.request.urlopen(url)
# 產生一個 soup object
soup=BeautifulSoup(thepage,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="orbit" lang="zh_tw">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/uploads/site/favicon/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    國立臺灣大學國家發展研究所
#   </title>
#   <link href="/assets/fontawesome/font-awesome-25cef4302d1b8fc05d28ac847626ecf3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/bootstrap/bootstrap-c07da65a73e80a09cabdf7a174a0635e.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/template/template-371b47ba8210ddd35fbd86df9516c51f.css" media="screen" rel="stylesheet"/>
#   <script src="/assets/lib/jquery-1.11.0.min-2cf9b70a257975f2833f682170097171.js">
#   </script>
#   <script src="/assets/bootstrap-c33cd72c8e754f012f5a68e0da4ad2db.js">
#   </script>
#   <script src="/assets/plugin/modernizr-b53b2a89dfd7a6d30aacfd4bd61ed506.js">
#   </script>
#   <script src="/assets/plugin/jquery-bullseye-min-695b302cc70f7f0277388c8759c2f01c.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.min-0181da5907c893e384e384f8ad2946de.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.video.min-8064c0652b44b69572d3ac653bedd6bd.js">
#   </script>
#   <script src="/assets/app-76e2704a8fa6c4fa895f3d420a243c56.js">
#   </script>
#   <script src="/assets/frontend-8338adc0c5e32b6d28215ca591059bb9.js">
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/assets/plugin/html5shiv-f1c171a5086388761a3fb837a304070b.js"></script>
#     <script src="/assets/plugin/response.min-ba150f83ff9f8a3cf90f406ddbaecef7.js"></script>
#   <![endif]-->
#   <link href="/assets/basic/icon" media="screen" rel="stylesheet"/>
#   <link href="/assets/lib/orbit_bar/orbit-bar" media="screen" rel="stylesheet"/>
#  </head>
#  <body class="page-home" data-module="home">
#   <div id="orbit-bar">
#    <input id="open-orbit-login" type="checkbox"/>
#    <label class="cover" for="open-orbit-login">
#    </label>
#    <div class="login-window">
#     <div class="login-header">
#      <label class="close" for="open-orbit-login">
#       ×
#      </label>
#      <h3>
#       登入 Orbit
#      </h3>
#     </div>
#     <div class="login-body">
#      <form accept-charset="UTF-8" action="/sessions?locale=zh_tw" class="container" method="post">
#       <div style="display:none">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="ABdWoj77L7N6i4WdewmZx8njfI9woDYy0kNuTsaO5UM="/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-user">
#         </i>
#        </span>
#        <input class="input" id="user_user_id" name="user_name" placeholder="使用者帳號" size="30" title="username" type="text"/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-lock">
#         </i>
#        </span>
#        <input class="input" id="user_password" name="password" placeholder="密碼" size="30" type="password"/>
#       </div>
#       <div class="login-submit-wrap">
#        <div class="submit">
#         <button class="login-btn" type="submit">
#          登入
#         </button>
#        </div>
#       </div>
#       <div class="login-sign-up-btn">
#        <a href="/users/new" rel="nofollow">
#         Sign up now
#        </a>
#       </div>
#      </form>
#     </div>
#    </div>
#    <input id="open-orbit-nav" type="checkbox"/>
#    <div class="orbit-bar-inner">
#     <label for="open-orbit-nav">
#      <i class="icons-list-2">
#      </i>
#     </label>
#     <h2 class="orbit-bar-title">
#      <a href="/">
#       Orbit
#      </a>
#     </h2>
#     <ul class="orbit-bar-menu">
#      <li>
#       <span class="orbit-bar-logo">
#        <img alt="Orbit Bar Logo" src="/uploads/site/default_image/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg"/>
#       </span>
#      </li>
#      <li>
#       <a class="orbit-bar-home" href="/">
#        <i class="icons-house">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <ul class="orbit-bar-search-sign-language">
#      <li>
#       <form action="http://www.google.com/custom" id="search" method="get" target="_blank">
#        <input name="client" type="hidden" value="pub-&amp;amp"/>
#        <input id="ie" name="ie" type="hidden" value="utf-8"/>
#        <input id="oe" name="oe" type="hidden" value="utf-8"/>
#        <input id="cof" name="cof" type="hidden" value="AH:center;AWFID:03de271f1940eea3;"/>
#        <input name="domains" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input name="sitesearch" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input id="q" name="q" placeholder="全站搜尋" type="search" value="" x-webkit-speech=""/>
#       </form>
#      </li>
#      <li>
#       <span id="language">
#        <i class="icons-earth orbit-bar-language-icon">
#        </i>
#        <span class="orbit-bar-language-text">
#         Language
#        </span>
#       </span>
#       <ul>
#        <li class="active">
#         繁體中文
#        </li>
#        <li>
#         <a accesskey="s" href="/?locale=zh_cn">
#          简体中文
#         </a>
#        </li>
#        <li class="">
#         <a accesskey="e" href="/?locale=en">
#          English
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a accesskey="L" class="sr-only" href="/zh_tw/accesskey" id="accesskey_login" title="Login">
#        :::
#       </a>
#       <label for="open-orbit-login">
#        <i class="icons-login">
#        </i>
#       </label>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <script type="text/javascript">
#    $("#open-orbit-login").on("change",function(){
#     if($(this).is(":checked")){
#       $("#user_user_id").focus();
#     }
#   })
#   $(".login-body form").on("submit",function(){
#     $(this).append("<input type='hidden' name='referer_url' value='http://www.nd.ntu.edu.tw/'/>");
#   })
#   var I18n = {
#     get locale(){ return "zh_tw"},
#     get validLocales(){return ["zh_tw","en","zh_cn"]},
#     set locale(v){return false},
#     set validLocales(v){return false}
#   };
#   </script>
#   <div class="body">
#    <div class="wrap">
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <script>
#      !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="https://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#     </script>
#     <header class="header">
#      <div id="button">
#      </div>
#      <div class="header-nav">
#      </div>
#      <div class="header_branding">
#       <h1 class="header_title">
#        <a class="header-home" href="/">
#         <img class="site-logo" src="/uploads/site/site_logo/54db068a7470001bc5180000/Facebook-20150416-023619.jpg"/>
#         國立臺灣大學國家發展研究所
#        </a>
#       </h1>
#      </div>
#      <nav class="menu">
#       <div class="menu2">
#        <ul class="page_menu level_1" data-menu-level="0">
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/announcement" target="_self">
#           公告
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/news" target="_self">
#             最新消息
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/seminar_lecture" target="_self">
#             學術活動
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/scholarships" target="_self">
#             獎學金資訊
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/conference" target="_self">
#             研討會
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/ndf" target="_self">
#             國家發展論壇
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/about" target="_self">
#           本所簡介
#          </a>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/member" target="_self">
#           本所成員
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/director" target="_self">
#             所長專區
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/teacher" target="_self">
#             師資陣容
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/staff" target="_self">
#             行政人員
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/phd" target="_self">
#           博士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/calendar" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/entry" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/attendance" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/phd_thesis" target="_self">
#             博士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/forms" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/qa_phd" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/master" target="_self">
#           碩士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/calendar_m" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/entry_m" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/attendance_m" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/m_thesis" target="_self">
#             碩士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/form_m" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/qa_m" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/emba" target="_self">
#           碩士在職專班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/programs" target="_self">
#             特色課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/calendar_e" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/entry_e" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/attendance_e" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/e_thesis" target="_self">
#             在職專班論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/form_e" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/qa_e" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/speaking_corner" target="_self">
#           口試專區
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral" target="_self">
#             論文研究計畫口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_papers" target="_self">
#             論文口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_form" target="_self">
#             口試表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/qa_o" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/course" target="_self">
#           課程
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_p_m" target="_self">
#             博碩士班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/Course_em" target="_self">
#             碩專班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_calendar" target="_self">
#             歷年課程
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/alumni" target="_self">
#           所友會
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/history" target="_self">
#             歷史沿革
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/framework" target="_self">
#             組織架構
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/notes" target="_self">
#             會議資料
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/status" target="_self">
#             所友動態
#            </a>
#            <ul class="page_menu level_3" data-menu-level="2">
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_001" target="_self">
#               所友動態_001
#              </a>
#             </li>
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_002" target="_self">
#               所友動態_002
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="http://www.ntu.edu.tw" target="_blank">
#           臺大首頁
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <div class="banner">
#       <div class="banner_slide" data-pp="310">
#        <div class="w-ad-banner ad-banner-widget-3" data-subpart-id="54e18eaa747000394d5d0000">
#         <div class="w-ad-banner__wrap cycle-slideshow" data-cycle-log="false" data-cycle-slides=".w-ad-banner__slide" data-level="0" data-list="images" data-pager=".w-ad-banner__pager" data-pager-active-class="active-slide" data-pager-template="&lt;li&gt;&lt;a href='#'&gt;&lt;/a&gt;&lt;/li&gt;">
#          <div class="w-ad-banner__slide active" data-link="http://www.rulingcom.com">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e24747000394d2e0000/01.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e2d747000394d320000/02.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e38747000394d360000/03.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e40747000394d3a0000/04.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e49747000394d3e0000/05.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e54747000394d420000/06.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e68747000394d470000/07.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e71747000394d4b0000/08.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e7b747000394d4f0000/09.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e83747000394d530000/10.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e8e747000394d570000/12.jpg"/>
#          </div>
#         </div>
#         <ul class="w-ad-banner__pager">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class="main">
#      <div class="home">
#       <div class="left_column news">
#        <div class="page_content" data-pp="1">
#         <div class="w-annc widget-announcement-13" data-subpart-id="54e2af0874700073d72b0000">
#          <h3 class="w-annc__widget-title">
#           <span>
#           </span>
#          </h3>
#          <div class="w-annc__inner">
#           <ul class="w-annc__list" data-level="0" data-list="announcements">
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-28
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/-%E7%95%A2%E6%A5%AD%E5%9C%98%E6%8B%8D-107%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%95%A2%E6%A5%AD%E5%9C%98%E6%8B%8D%E8%AA%BF%E6%9F%A5%E8%A1%A8%E5%96%AE%E5%A1%AB%E5%A0%B1-%E8%87%B3108-10-30%E6%97%A5%E6%AD%A2-44296179">
#                【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-28
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/-%E5%85%AC%E5%91%8A-109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E6%8B%9B%E7%94%9F%E7%B0%A1%E7%AB%A0%E8%80%83%E7%A7%91%E7%95%B0%E5%8B%95-71061959">
#                【公告】109學年度碩士班招生簡章考科異動
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-18
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/108-10-26-%E5%85%AD-109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%94%84%E8%A9%A6%E6%8B%9B%E7%94%9F%E7%AD%86%E8%A9%A6%E8%A9%A6%E5%A0%B4-%E5%9C%8B%E7%99%BC%E6%89%80206%E6%95%99%E5%AE%A4-71326222">
#                108/10/26(六)109學年度碩士班甄試招生筆試試場：國發所206教室
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-01
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/%E6%9C%AC%E6%A0%A1%E5%AD%B8%E5%8B%99%E8%99%95%E5%85%AC%E5%91%8A%E7%9B%B8%E9%97%9C%E8%A8%8A%E6%81%AF-26367168">
#                本校學務處公告相關訊息
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-09-18
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/%5B%E6%89%80%E8%BE%A6%E5%85%AC%E5%91%8A%5D-%E6%89%80%E8%BE%A6%E5%85%AC%E5%AE%A4%E4%B8%8D%E4%BB%A3%E6%94%B6%E5%90%8C%E5%AD%B8%E7%A7%81%E4%BA%BA%E4%BF%A1%E4%BB%B6%E6%88%96%E5%8C%85%E8%A3%B9-99580499">
#                [所辦公告] 所辦公室不代收同學私人信件或包裹
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-09-06
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/108%E5%AD%B8%E5%B9%B4%E5%BA%A6-%E6%8A%B5%E5%85%8D%E5%AD%B8%E5%88%86%E6%A0%B8%E5%AE%9A%E6%9B%B8-%E5%B7%B2%E9%80%81%E9%81%94%E6%89%80%E8%BE%A6-%E8%AB%8B%E5%90%8C%E5%AD%B8%E8%87%B3%E6%89%80%E8%BE%A6%E9%A0%98%E5%8F%96-5046010">
#                108學年度「抵免學分核定書」已送達所辦，請同學至所辦領取。
#               </a>
#              </h4>
#             </div>
#            </li>
#           </ul>
#          </div>
#          <div class="w-annc__more">
#           <a href="/zh_tw/announcement">
#            Read more
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="en_left_column" data-pp="8">
#       </div>
#       <div class="main_column">
#        <div class="summit-wrap">
#         <div class="page_content" data-pp="2">
#          <div class="w-annc widget-announcement-13" data-subpart-id="54e2af4474700073d7310000">
#           <h3 class="w-annc__widget-title">
#            <span>
#
#                </span>
#               </span>
#               <h4 class="w-annc__entry-title">
#                <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#                </span>
#                <a class="w-annc__title" href="/zh_tw/announcement/108%E5%AD%B8%E5%B9%B4%E5%BA%A6-%E9%BB%83%E6%95%85%E6%95%99%E6%8E%88%E5%AD%A3%E9%99%B8%E5%85%88%E7%94%9F%E7%8D%8E%E5%AD%B8%E9%87%91-%E7%94%B3%E8%AB%8B%E8%87%B3108-10-1%E6%AD%A2-%E9%99%90%E6%9C%AC%E6%89%80%E6%9C%AC%E5%9C%8B%E7%B1%8D%E7%A2%A9%E5%A3%AB%E6%96%B0%E7%94%9F%E7%94%B3%E8%AB%8B-75669866">
#                 108學年度「黃故教授季陸先生獎學金」申請至108/10/1止 (限本所本國籍碩士新生申請)
#                </a>
#               </h4>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="w-annc__more">
#            <a href="/zh_tw/announcement">
#             Read more
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="right_column">
#        <div class="user_modify">
#         <div class="page_content" data-pp="44">
#          <div class="w-annc widget-announcement-5" data-subpart-id="556ec13c6e74755528720000">
#           <h3 class="w-annc__widget-title">
#            <span>
#             國家發展論壇
#            </span>
#           </h3>
#           <ul class="w-annc__list row" data-level="0" data-list="announcements">
#           </ul>
#           <div class="w-annc__more">
#            <a href="/zh_tw/summit_news_all">
#             Read more
#            </a>
#           </div>
#          </div>
#          <table border="0" cellpadding="1" cellspacing="1" style="width:240px;">
#           <tbody>
#            <tr>
#             <td>
#              <h2>
#               <br/>
#               <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#                國家發展研究期刊
#               </a>
#              </h2>
#              <a href="www.nd.ntu.edu.tw/zh_tw/nds" style="font-family: arial; font-size: 18px; line-height: 21.6px;">
#               National Development Studie
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <div>
#           <table>
#            <tbody>
#             <tr>
#              <td class="title">
#               <span style="font-size:16px;">
#                研究中心群
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td class="info">
#               <p>
#                <span style="font-size:9px;">
#                 <a href="/zh_tw/CSR">
#                  兩岸關係中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SES">
#                  國家經濟安全研究中心
#                 </a>
#                 <br/>
#                 <a href="http://140.112.176.185/spatial/excel2earth.html">
#                  空間分析工作室
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/marinepolicy">
#                  海洋政策研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/Law_Socio">
#                  法律與文化研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SR">
#                  科技政策與全球化風險治理中心
#                 </a>
#                </span>
#                <br/>
#                <a href="https://sites.google.com/view/ntundcrcc/">
#                 <span style="font-size: 12px;">
#                  區域合作暨競爭力研究中心
#                 </span>
#                </a>
#               </p>
#               <h4>
#               </h4>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#         </div>
#        </div>
#        <div class="publication hide">
#         <div class="page_content" data-pp="4">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               國家發展研究期刊
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               National Development Studies
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="institute hide">
#         <div class="page_content" data-pp="5">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              研究中心群
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="/zh_tw/CSR">
#               兩岸關係
#              </a>
#              <a href="/zh_tw/SES">
#               國家經濟安全研究
#              </a>
#              <a href="https://www.facebook.com/pages/Excel2Earth/383852245125712?fref=ts">
#               空間分析
#              </a>
#              <a href="/zh_tw/marinepolicy">
#               海洋政策研究
#              </a>
#              <a href="/zh_tw/Hakka">
#               客家研究
#              </a>
#              <a href="/zh_tw/Law_Socio">
#               法律與社會研究
#              </a>
#              <a href="/zh_tw/SR">
#               科技政策與全球化風險治理
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="event hide">
#         <div class="page_content" data-pp="6">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               國家發展論壇
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               Forum of National Developments
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="mailbox hide">
#         <div class="page_content" data-pp="7">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <footer class="footer">
#      <div class="footer-inner">
#       <div class="footer_address">
#        Copyright © 2014 國立臺灣大學國家發展研究所 Graduate Institute of National Development, National Taiwan University
#        <br/>
#        10617 臺北市大安區羅斯福路四段1號 （辛亥復興路口側門進入） No. 1, Sec. 4, Roosevelt Road, Taipei, 10617 Taiwan(R.O.C)
#        <br/>
#        電話 (Phone)：+886-2-3366-3333  傳真 (Fax)：+886-2-2367-6176  E-mail：ndintu@ntu.edu.tw
#       </div>
#       <div class="footer-site-counter">
#        造訪人次 : 722686
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## 方法二：使用 requests.get()
# * 可處理 get, post 兩種模式，前者直接請求，後者要附加引數才能請求。
# * 在網頁上按左鍵，inspection, network, reflesh, 選擇網頁，Herders 可查得 request method
# * post 要有 form data 才能 request，form data 可從網頁上查得。

# %%
import requests
from bs4 import BeautifulSoup
url="http://www.nd.ntu.edu.tw/"
# 有 get 與 post 兩種模式，要從網頁上 inspect，本範例為 get
response = requests.get (url)
# 用 BeatifulSoup 解析 HTML 並把結果回傳 soup
soup = BeautifulSoup (response.text, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="orbit" lang="zh_tw">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/uploads/site/favicon/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    國立臺灣大學國家發展研究所
#   </title>
#   <link href="/assets/fontawesome/font-awesome-25cef4302d1b8fc05d28ac847626ecf3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/bootstrap/bootstrap-c07da65a73e80a09cabdf7a174a0635e.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/template/template-371b47ba8210ddd35fbd86df9516c51f.css" media="screen" rel="stylesheet"/>
#   <script src="/assets/lib/jquery-1.11.0.min-2cf9b70a257975f2833f682170097171.js">
#   </script>
#   <script src="/assets/bootstrap-c33cd72c8e754f012f5a68e0da4ad2db.js">
#   </script>
#   <script src="/assets/plugin/modernizr-b53b2a89dfd7a6d30aacfd4bd61ed506.js">
#   </script>
#   <script src="/assets/plugin/jquery-bullseye-min-695b302cc70f7f0277388c8759c2f01c.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.min-0181da5907c893e384e384f8ad2946de.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.video.min-8064c0652b44b69572d3ac653bedd6bd.js">
#   </script>
#   <script src="/assets/app-76e2704a8fa6c4fa895f3d420a243c56.js">
#   </script>
#   <script src="/assets/frontend-8338adc0c5e32b6d28215ca591059bb9.js">
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/assets/plugin/html5shiv-f1c171a5086388761a3fb837a304070b.js"></script>
#     <script src="/assets/plugin/response.min-ba150f83ff9f8a3cf90f406ddbaecef7.js"></script>
#   <![endif]-->
#   <link href="/assets/basic/icon" media="screen" rel="stylesheet"/>
#   <link href="/assets/lib/orbit_bar/orbit-bar" media="screen" rel="stylesheet"/>
#  </head>
#  <body class="page-home" data-module="home">
#   <div id="orbit-bar">
#    <input id="open-orbit-login" type="checkbox"/>
#    <label class="cover" for="open-orbit-login">
#    </label>
#    <div class="login-window">
#     <div class="login-header">
#      <label class="close" for="open-orbit-login">
#       ×
#      </label>
#      <h3>
#       登入 Orbit
#      </h3>
#     </div>
#     <div class="login-body">
#      <form accept-charset="UTF-8" action="/sessions?locale=zh_tw" class="container" method="post">
#       <div style="display:none">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="SdEJs21uyXSNq8tCfF+RpjeXPpWvGnZ8M+PL1FlekEc="/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-user">
#         </i>
#        </span>
#        <input class="input" id="user_user_id" name="user_name" placeholder="使用者帳號" size="30" title="username" type="text"/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-lock">
#         </i>
#        </span>
#        <input class="input" id="user_password" name="password" placeholder="密碼" size="30" type="password"/>
#       </div>
#       <div class="login-submit-wrap">
#        <div class="submit">
#         <button class="login-btn" type="submit">
#          登入
#         </button>
#        </div>
#       </div>
#       <div class="login-sign-up-btn">
#        <a href="/users/new" rel="nofollow">
#         Sign up now
#        </a>
#       </div>
#      </form>
#     </div>
#    </div>
#    <input id="open-orbit-nav" type="checkbox"/>
#    <div class="orbit-bar-inner">
#     <label for="open-orbit-nav">
#      <i class="icons-list-2">
#      </i>
#     </label>
#     <h2 class="orbit-bar-title">
#      <a href="/">
#       Orbit
#      </a>
#     </h2>
#     <ul class="orbit-bar-menu">
#      <li>
#       <span class="orbit-bar-logo">
#        <img alt="Orbit Bar Logo" src="/uploads/site/default_image/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg"/>
#       </span>
#      </li>
#      <li>
#       <a class="orbit-bar-home" href="/">
#        <i class="icons-house">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <ul class="orbit-bar-search-sign-language">
#      <li>
#       <form action="http://www.google.com/custom" id="search" method="get" target="_blank">
#        <input name="client" type="hidden" value="pub-&amp;amp"/>
#        <input id="ie" name="ie" type="hidden" value="utf-8"/>
#        <input id="oe" name="oe" type="hidden" value="utf-8"/>
#        <input id="cof" name="cof" type="hidden" value="AH:center;AWFID:03de271f1940eea3;"/>
#        <input name="domains" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input name="sitesearch" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input id="q" name="q" placeholder="全站搜尋" type="search" value="" x-webkit-speech=""/>
#       </form>
#      </li>
#      <li>
#       <span id="language">
#        <i class="icons-earth orbit-bar-language-icon">
#        </i>
#        <span class="orbit-bar-language-text">
#         Language
#        </span>
#       </span>
#       <ul>
#        <li class="active">
#         繁體中文
#        </li>
#        <li>
#         <a accesskey="s" href="/?locale=zh_cn">
#          简体中文
#         </a>
#        </li>
#        <li class="">
#         <a accesskey="e" href="/?locale=en">
#          English
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a accesskey="L" class="sr-only" href="/zh_tw/accesskey" id="accesskey_login" title="Login">
#        :::
#       </a>
#       <label for="open-orbit-login">
#        <i class="icons-login">
#        </i>
#       </label>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <script type="text/javascript">
#    $("#open-orbit-login").on("change",function(){
#     if($(this).is(":checked")){
#       $("#user_user_id").focus();
#     }
#   })
#   $(".login-body form").on("submit",function(){
#     $(this).append("<input type='hidden' name='referer_url' value='http://www.nd.ntu.edu.tw/'/>");
#   })
#   var I18n = {
#     get locale(){ return "zh_tw"},
#     get validLocales(){return ["zh_tw","en","zh_cn"]},
#     set locale(v){return false},
#     set validLocales(v){return false}
#   };
#   </script>
#   <div class="body">
#    <div class="wrap">
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <script>
#      !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="https://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#     </script>
#     <header class="header">
#      <div id="button">
#      </div>
#      <div class="header-nav">
#      </div>
#      <div class="header_branding">
#       <h1 class="header_title">
#        <a class="header-home" href="/">
#         <img class="site-logo" src="/uploads/site/site_logo/54db068a7470001bc5180000/Facebook-20150416-023619.jpg"/>
#         國立臺灣大學國家發展研究所
#        </a>
#       </h1>
#      </div>
#      <nav class="menu">
#       <div class="menu2">
#        <ul class="page_menu level_1" data-menu-level="0">
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/announcement" target="_self">
#           公告
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/news" target="_self">
#             最新消息
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/seminar_lecture" target="_self">
#             學術活動
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/scholarships" target="_self">
#             獎學金資訊
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/conference" target="_self">
#             研討會
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/ndf" target="_self">
#             國家發展論壇
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/about" target="_self">
#           本所簡介
#          </a>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/member" target="_self">
#           本所成員
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/director" target="_self">
#             所長專區
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/teacher" target="_self">
#             師資陣容
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/staff" target="_self">
#             行政人員
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/phd" target="_self">
#           博士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/calendar" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/entry" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/attendance" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/phd_thesis" target="_self">
#             博士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/forms" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/qa_phd" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/master" target="_self">
#           碩士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/calendar_m" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/entry_m" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/attendance_m" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/m_thesis" target="_self">
#             碩士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/form_m" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/qa_m" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/emba" target="_self">
#           碩士在職專班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/programs" target="_self">
#             特色課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/calendar_e" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/entry_e" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/attendance_e" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/e_thesis" target="_self">
#             在職專班論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/form_e" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/qa_e" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/speaking_corner" target="_self">
#           口試專區
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral" target="_self">
#             論文研究計畫口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_papers" target="_self">
#             論文口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_form" target="_self">
#             口試表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/qa_o" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/course" target="_self">
#           課程
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_p_m" target="_self">
#             博碩士班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/Course_em" target="_self">
#             碩專班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_calendar" target="_self">
#             歷年課程
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/alumni" target="_self">
#           所友會
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/history" target="_self">
#             歷史沿革
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/framework" target="_self">
#             組織架構
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/notes" target="_self">
#             會議資料
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/status" target="_self">
#             所友動態
#            </a>
#            <ul class="page_menu level_3" data-menu-level="2">
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_001" target="_self">
#               所友動態_001
#              </a>
#             </li>
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_002" target="_self">
#               所友動態_002
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="http://www.ntu.edu.tw" target="_blank">
#           臺大首頁
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <div class="banner">
#       <div class="banner_slide" data-pp="310">
#        <div class="w-ad-banner ad-banner-widget-3" data-subpart-id="54e18eaa747000394d5d0000">
#         <div class="w-ad-banner__wrap cycle-slideshow" data-cycle-log="false" data-cycle-slides=".w-ad-banner__slide" data-level="0" data-list="images" data-pager=".w-ad-banner__pager" data-pager-active-class="active-slide" data-pager-template="&lt;li&gt;&lt;a href='#'&gt;&lt;/a&gt;&lt;/li&gt;">
#          <div class="w-ad-banner__slide active" data-link="http://www.rulingcom.com">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e24747000394d2e0000/01.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e2d747000394d320000/02.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e38747000394d360000/03.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e40747000394d3a0000/04.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e49747000394d3e0000/05.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e54747000394d420000/06.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e68747000394d470000/07.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e71747000394d4b0000/08.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e7b747000394d4f0000/09.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e83747000394d530000/10.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e8e747000394d570000/12.jpg"/>
#          </div>
#         </div>
#         <ul class="w-ad-banner__pager">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class="main">
#      <div class="home">
#       <div class="left_column news">
#        <div class="page_content" data-pp="1">
#         <div class="w-annc widget-announcement-13" data-subpart-id="54e2af0874700073d72b0000">
#          <h3 class="w-annc__widget-title">
#           <span>
#           </span>
#          </h3>
#          <div class="w-annc__inner">
#           <ul class="w-annc__list" data-level="0" data-list="announcements">
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-28
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/-%E7%95%A2%E6%A5%AD%E5%9C%98%E6%8B%8D-107%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E7%95%A2%E6%A5%AD%E5%9C%98%E6%8B%8D%E8%AA%BF%E6%9F%A5%E8%A1%A8%E5%96%AE%E5%A1%AB%E5%A0%B1-%E8%87%B3108-10-30%E6%97%A5%E6%AD%A2-44296179">
#                【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10-28
#               </span>
#              </span>
#              <h4 class="w-annc__entry-title">
#               <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#               </span>
#               <a class="w-annc__title" href="/zh_tw/announcement/-%E5%85%AC%E5%91%8A-109%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%A2%A9%E5%A3%AB%E7%8F%AD%E6%8B%9B%E7%94%9F%E7%B0%A1%E7%AB%A0%E8%80%83%E7%A7%91%E7%95%B0%E5%8B%95-71061959">
#                【公告】109學年度碩士班招生簡章考科異動
#               </a>
#              </h4>
#             </div>
#            </li>
#            <li class="w-annc__item">
#             <div class="w-annc__content">
#              <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#               <span class="w-annc__postdate">
#                2019-10
#                </a>
#               </h4>
#              </div>
#             </li>
#             <li class="w-annc__item">
#              <div class="w-annc__content">
#               <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#                <span class="w-annc__postdate">
#                 2019-10-15
#                </span>
#               </span>
#               <h4 class="w-annc__entry-title">
#                <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#                </span>
#                <a class="w-annc__title" href="/zh_tw/announcement/108-10-17%E6%89%80%E9%95%B7%E6%99%82%E9%96%93%E6%9A%AB%E5%81%9C%E4%B9%99%E6%AC%A1-108-10-21-10-25%E6%89%80%E9%95%B7%E5%B0%87%E5%87%BA%E5%B8%AD%E5%9C%8B%E9%9A%9B%E6%9C%83%E8%AD%B0%E6%9A%A8%E6%B4%BD%E8%AB%87%E6%9C%AC%E6%89%80%E8%88%87%E9%A6%99%E6%B8%AF%E5%B6%BA%E5%8D%97%E5%A4%A7%E5%AD%B8%E5%9C%8B%E9%9A%9B%E5%AD%B8%E8%A1%93%E4%BA%A4%E6%B5%81%E7%9B%B8%E9%97%9C%E4%BA%8B%E5%AE%9C-%E6%95%85%E8%A9%B2%E9%80%B1%E6%89%80%E9%95%B7%E6%99%82%E9%96%93%E6%9A%AB%E5%81%9C-87856037">
#                 108/10/17所長時間暫停乙次，108/10/21~10/25所長將出席國際會議暨洽談本所與香港嶺南大學國際學術交流相關事宜，故該週所長時間暫停。
#                </a>
#               </h4>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="w-annc__more">
#            <a href="/zh_tw/announcement">
#             Read more
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="conference-wrap">
#         <div class="page_content" data-pp="3">
#          <div class="w-annc widget-announcement-13" data-subpart-id="54e2b00774700073d7360000">
#           <h3 class="w-annc__widget-title">
#            <span>
#             獎助學金資訊
#            </span>
#           </h3>
#           <div class="w-annc__inner">
#            <ul class="w-annc__list" data-level="0" data-list="announcements">
#             <li class="w-annc__item">
#              <div class="w-annc__content">
#               <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#                <span class="w-annc__postdate">
#                 2019-10-22
#                </span>
#               </span>
#               <h4 class="w-annc__entry-title">
#                <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#                </span>
#                <a class="w-annc__title" href="/zh_tw/announcement/108%E5%AD%B8%E5%B9%B4%E5%BA%A6%E7%AC%AC1%E5%AD%B8%E6%9C%9F%E7%94%9F%E6%B4%BB%E5%AD%B8%E7%BF%92%E5%8A%A9%E5%AD%B8%E9%87%91%E5%AF%A9%E6%A0%B8%E7%B5%90%E6%9E%9C%E5%85%AC%E5%91%8A-4586872">
#                 108學年度第1學期生活學習助學金審核結果公告
#                </a>
#               </h4>
#              </div>
#             </li>
#             <li class="w-annc__item">
#              <div class="w-annc__content">
#               <span class="w-annc__postdate-wrap" date-format="%Y-%m-%d">
#                <span class="w-annc__postdate">
#                 2019-08-14
#                </span>
#               </span>
#               <h4 class="w-annc__entry-title">
#                <span class="w-annc__status-wrap" data-level="1" data-list="statuses">
#                </span>
#                <a class="w-annc__title" href="/zh_tw/announcement/108%E5%AD%B8%E5%B9%B4%E5%BA%A6-%E9%BB%83%E6%95%85%E6%95%99%E6%8E%88%E5%AD%A3%E9%99%B8%E5%85%88%E7%94%9F%E7%8D%8E%E5%AD%B8%E9%87%91-%E7%94%B3%E8%AB%8B%E8%87%B3108-10-1%E6%AD%A2-%E9%99%90%E6%9C%AC%E6%89%80%E6%9C%AC%E5%9C%8B%E7%B1%8D%E7%A2%A9%E5%A3%AB%E6%96%B0%E7%94%9F%E7%94%B3%E8%AB%8B-75669866">
#                 108學年度「黃故教授季陸先生獎學金」申請至108/10/1止 (限本所本國籍碩士新生申請)
#                </a>
#               </h4>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="w-annc__more">
#            <a href="/zh_tw/announcement">
#             Read more
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="right_column">
#        <div class="user_modify">
#         <div class="page_content" data-pp="44">
#          <div class="w-annc widget-announcement-5" data-subpart-id="556ec13c6e74755528720000">
#           <h3 class="w-annc__widget-title">
#            <span>
#             國家發展論壇
#            </span>
#           </h3>
#           <ul class="w-annc__list row" data-level="0" data-list="announcements">
#           </ul>
#           <div class="w-annc__more">
#            <a href="/zh_tw/summit_news_all">
#             Read more
#            </a>
#           </div>
#          </div>
#          <table border="0" cellpadding="1" cellspacing="1" style="width:240px;">
#           <tbody>
#            <tr>
#             <td>
#              <h2>
#               <br/>
#               <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#                國家發展研究期刊
#               </a>
#              </h2>
#              <a href="www.nd.ntu.edu.tw/zh_tw/nds" style="font-family: arial; font-size: 18px; line-height: 21.6px;">
#               National Development Studie
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <div>
#           <table>
#            <tbody>
#             <tr>
#              <td class="title">
#               <span style="font-size:16px;">
#                研究中心群
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td class="info">
#               <p>
#                <span style="font-size:9px;">
#                 <a href="/zh_tw/CSR">
#                  兩岸關係中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SES">
#                  國家經濟安全研究中心
#                 </a>
#                 <br/>
#                 <a href="http://140.112.176.185/spatial/excel2earth.html">
#                  空間分析工作室
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/marinepolicy">
#                  海洋政策研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/Law_Socio">
#                  法律與文化研究中心
#                 </a>
#                 <br/>
#                 <a href="/zh_tw/SR">
#                  科技政策與全球化風險治理中心
#                 </a>
#                </span>
#                <br/>
#                <a href="https://sites.google.com/view/ntundcrcc/">
#                 <span style="font-size: 12px;">
#                  區域合作暨競爭力研究中心
#                 </span>
#                </a>
#               </p>
#               <h4>
#               </h4>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#         </div>
#        </div>
#        <div class="publication hide">
#         <div class="page_content" data-pp="4">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               國家發展研究期刊
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/zh_tw/nds">
#               National Development Studies
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="institute hide">
#         <div class="page_content" data-pp="5">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              研究中心群
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="/zh_tw/CSR">
#               兩岸關係
#              </a>
#              <a href="/zh_tw/SES">
#               國家經濟安全研究
#              </a>
#              <a href="https://www.facebook.com/pages/Excel2Earth/383852245125712?fref=ts">
#               空間分析
#              </a>
#              <a href="/zh_tw/marinepolicy">
#               海洋政策研究
#              </a>
#              <a href="/zh_tw/Hakka">
#               客家研究
#              </a>
#              <a href="/zh_tw/Law_Socio">
#               法律與社會研究
#              </a>
#              <a href="/zh_tw/SR">
#               科技政策與全球化風險治理
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="event hide">
#         <div class="page_content" data-pp="6">
#          <table>
#           <tbody>
#            <tr>
#             <td class="title">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               國家發展論壇
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td class="info">
#              <a href="http://www.nd.ntu.edu.tw/announcement/ndf" target="_blank">
#               Forum of National Developments
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="mailbox hide">
#         <div class="page_content" data-pp="7">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <footer class="footer">
#      <div class="footer-inner">
#       <div class="footer_address">
#        Copyright © 2014 國立臺灣大學國家發展研究所 Graduate Institute of National Development, National Taiwan University
#        <br/>
#        10617 臺北市大安區羅斯福路四段1號 （辛亥復興路口側門進入） No. 1, Sec. 4, Roosevelt Road, Taipei, 10617 Taiwan(R.O.C)
#        <br/>
#        電話 (Phone)：+886-2-3366-3333  傳真 (Fax)：+886-2-2367-6176  E-mail：ndintu@ntu.edu.tw
#       </div>
#       <div class="footer-site-counter">
#        造訪人次 : 722687
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## 把所有的公告，時間與內容抓出來。

# %%
# 網頁位於 "http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1&"
url="http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1&"
# 有 get 與 post 兩種模式，要從網頁上 inspect，本範例為 get
response = requests.get (url)
# 用 BeatifulSoup 解析 HTML 並把結果回傳 soup
soup = BeautifulSoup (response.text, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="orbit" lang="zh_tw">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/uploads/site/favicon/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    國立臺灣大學國家發展研究所
#   </title>
#   <link href="/assets/fontawesome/font-awesome-25cef4302d1b8fc05d28ac847626ecf3.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/bootstrap/bootstrap-c07da65a73e80a09cabdf7a174a0635e.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/template/template-371b47ba8210ddd35fbd86df9516c51f.css" media="screen" rel="stylesheet"/>
#   <script src="/assets/lib/jquery-1.11.0.min-2cf9b70a257975f2833f682170097171.js">
#   </script>
#   <script src="/assets/bootstrap-c33cd72c8e754f012f5a68e0da4ad2db.js">
#   </script>
#   <script src="/assets/plugin/modernizr-b53b2a89dfd7a6d30aacfd4bd61ed506.js">
#   </script>
#   <script src="/assets/plugin/jquery-bullseye-min-695b302cc70f7f0277388c8759c2f01c.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.min-0181da5907c893e384e384f8ad2946de.js">
#   </script>
#   <script src="/assets/plugin/jquery.cycle2.video.min-8064c0652b44b69572d3ac653bedd6bd.js">
#   </script>
#   <script src="/assets/app-76e2704a8fa6c4fa895f3d420a243c56.js">
#   </script>
#   <script src="/assets/frontend-8338adc0c5e32b6d28215ca591059bb9.js">
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/assets/plugin/html5shiv-f1c171a5086388761a3fb837a304070b.js"></script>
#     <script src="/assets/plugin/response.min-ba150f83ff9f8a3cf90f406ddbaecef7.js"></script>
#   <![endif]-->
#   <link href="/assets/basic/icon" media="screen" rel="stylesheet"/>
#   <link href="/assets/lib/orbit_bar/orbit-bar" media="screen" rel="stylesheet"/>
#  </head>
#  <body class="page-internal" data-module="announcement">
#   <div id="orbit-bar">
#    <input id="open-orbit-login" type="checkbox"/>
#    <label class="cover" for="open-orbit-login">
#    </label>
#    <div class="login-window">
#     <div class="login-header">
#      <label class="close" for="open-orbit-login">
#       ×
#      </label>
#      <h3>
#       登入 Orbit
#      </h3>
#     </div>
#     <div class="login-body">
#      <form accept-charset="UTF-8" action="/sessions?locale=zh_tw" class="container" method="post">
#       <div style="display:none">
#        <input name="utf8" type="hidden" value="✓"/>
#        <input name="authenticity_token" type="hidden" value="SFYHW+Aa0TimooftfQopi00bWPQaPf4ZiH2HdkZZSmc="/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-user">
#         </i>
#        </span>
#        <input class="input" id="user_user_id" name="user_name" placeholder="使用者帳號" size="30" title="username" type="text"/>
#       </div>
#       <div class="prepend input-group">
#        <span class="add input-group-addon">
#         <i class="icon-lock">
#         </i>
#        </span>
#        <input class="input" id="user_password" name="password" placeholder="密碼" size="30" type="password"/>
#       </div>
#       <div class="login-submit-wrap">
#        <div class="submit">
#         <button class="login-btn" type="submit">
#          登入
#         </button>
#        </div>
#       </div>
#       <div class="login-sign-up-btn">
#        <a href="/users/new" rel="nofollow">
#         Sign up now
#        </a>
#       </div>
#      </form>
#     </div>
#    </div>
#    <input id="open-orbit-nav" type="checkbox"/>
#    <div class="orbit-bar-inner">
#     <label for="open-orbit-nav">
#      <i class="icons-list-2">
#      </i>
#     </label>
#     <h2 class="orbit-bar-title">
#      <a href="/">
#       Orbit
#      </a>
#     </h2>
#     <ul class="orbit-bar-menu">
#      <li>
#       <span class="orbit-bar-logo">
#        <img alt="Orbit Bar Logo" src="/uploads/site/default_image/54db068a7470001bc5180000/Facebook-20150416-023619__2_.jpg"/>
#       </span>
#      </li>
#      <li>
#       <a class="orbit-bar-home" href="/">
#        <i class="icons-house">
#        </i>
#       </a>
#      </li>
#     </ul>
#     <ul class="orbit-bar-search-sign-language">
#      <li>
#       <form action="http://www.google.com/custom" id="search" method="get" target="_blank">
#        <input name="client" type="hidden" value="pub-&amp;amp"/>
#        <input id="ie" name="ie" type="hidden" value="utf-8"/>
#        <input id="oe" name="oe" type="hidden" value="utf-8"/>
#        <input id="cof" name="cof" type="hidden" value="AH:center;AWFID:03de271f1940eea3;"/>
#        <input name="domains" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input name="sitesearch" type="hidden" value="www.nd.ntu.edu.tw"/>
#        <input id="q" name="q" placeholder="全站搜尋" type="search" value="" x-webkit-speech=""/>
#       </form>
#      </li>
#      <li>
#       <span id="language">
#        <i class="icons-earth orbit-bar-language-icon">
#        </i>
#        <span class="orbit-bar-language-text">
#         Language
#        </span>
#       </span>
#       <ul>
#        <li class="active">
#         繁體中文
#        </li>
#        <li>
#         <a accesskey="s" href="/zh_cn/announcement?page_no=1&amp;">
#          简体中文
#         </a>
#        </li>
#        <li class="">
#         <a accesskey="e" href="/en/announcement?page_no=1&amp;">
#          English
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <a accesskey="L" class="sr-only" href="/zh_tw/accesskey" id="accesskey_login" title="Login">
#        :::
#       </a>
#       <label for="open-orbit-login">
#        <i class="icons-login">
#        </i>
#       </label>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <script type="text/javascript">
#    $("#open-orbit-login").on("change",function(){
#     if($(this).is(":checked")){
#       $("#user_user_id").focus();
#     }
#   })
#   $(".login-body form").on("submit",function(){
#     $(this).append("<input type='hidden' name='referer_url' value='http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1&amp;'/>");
#   })
#   var I18n = {
#     get locale(){ return "zh_tw"},
#     get validLocales(){return ["zh_tw","en","zh_cn"]},
#     set locale(v){return false},
#     set validLocales(v){return false}
#   };
#   </script>
#   <div class="body">
#    <div class="wrap">
#     <div id="fb-root">
#     </div>
#     <script>
#      (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#     </script>
#     <script>
#      !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="https://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#     </script>
#     <header class="header">
#      <div id="button">
#      </div>
#      <div class="header-nav">
#      </div>
#      <div class="header_branding">
#       <h1 class="header_title">
#        <a class="header-home" href="/">
#         <img class="site-logo" src="/uploads/site/site_logo/54db068a7470001bc5180000/Facebook-20150416-023619.jpg"/>
#         國立臺灣大學國家發展研究所
#        </a>
#       </h1>
#      </div>
#      <nav class="menu">
#       <div class="menu2">
#        <ul class="page_menu level_1" data-menu-level="0">
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/announcement" target="_self">
#           公告
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/news" target="_self">
#             最新消息
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/seminar_lecture" target="_self">
#             學術活動
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/scholarships" target="_self">
#             獎學金資訊
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/conference" target="_self">
#             研討會
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/announcement/ndf" target="_self">
#             國家發展論壇
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/about" target="_self">
#           本所簡介
#          </a>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/member" target="_self">
#           本所成員
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/director" target="_self">
#             所長專區
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/teacher" target="_self">
#             師資陣容
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/member/staff" target="_self">
#             行政人員
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/phd" target="_self">
#           博士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/calendar" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/entry" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/attendance" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/phd_thesis" target="_self">
#             博士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/forms" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/phd/qa_phd" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/master" target="_self">
#           碩士班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/calendar_m" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/entry_m" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/attendance_m" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/m_thesis" target="_self">
#             碩士論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/form_m" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/master/qa_m" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/emba" target="_self">
#           碩士在職專班
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/programs" target="_self">
#             特色課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/calendar_e" target="_self">
#             行事曆
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/entry_e" target="_self">
#             入學方法
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/attendance_e" target="_self">
#             修業規定
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/e_thesis" target="_self">
#             在職專班論文
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/form_e" target="_self">
#             常用表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/emba/qa_e" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/speaking_corner" target="_self">
#           口試專區
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral" target="_self">
#             論文研究計畫口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_papers" target="_self">
#             論文口試
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/oral_form" target="_self">
#             口試表格
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/speaking_corner/qa_o" target="_self">
#             Q&amp;A
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/course" target="_self">
#           課程
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_p_m" target="_self">
#             博碩士班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/Course_em" target="_self">
#             碩專班課程
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/course/course_calendar" target="_self">
#             歷年課程
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="/zh_tw/alumni" target="_self">
#           所友會
#          </a>
#          <ul class="page_menu level_2" data-menu-level="1">
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/history" target="_self">
#             歷史沿革
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/framework" target="_self">
#             組織架構
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/notes" target="_self">
#             會議資料
#            </a>
#           </li>
#           <li>
#            <a class="page_menu_link level_2" data-menu-link="true" href="/zh_tw/alumni/status" target="_self">
#             所友動態
#            </a>
#            <ul class="page_menu level_3" data-menu-level="2">
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_001" target="_self">
#               所友動態_001
#              </a>
#             </li>
#             <li>
#              <a class="page_menu_link level_3" data-menu-link="true" href="/zh_tw/alumni/status/alumni_002" target="_self">
#               所友動態_002
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="page_menu_link level_1" data-menu-link="true" href="http://www.ntu.edu.tw" target="_blank">
#           臺大首頁
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <div class="banner">
#       <div class="banner_slide" data-pp="310">
#        <div class="w-ad-banner ad-banner-widget-3" data-subpart-id="54e190e5747000394d780000">
#         <div class="w-ad-banner__wrap cycle-slideshow" data-cycle-log="false" data-cycle-slides=".w-ad-banner__slide" data-level="0" data-list="images" data-pager=".w-ad-banner__pager" data-pager-active-class="active-slide" data-pager-template="&lt;li&gt;&lt;a href='#'&gt;&lt;/a&gt;&lt;/li&gt;">
#          <div class="w-ad-banner__slide active" data-link="http://www.rulingcom.com">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e24747000394d2e0000/01.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e2d747000394d320000/02.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e38747000394d360000/03.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e40747000394d3a0000/04.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e49747000394d3e0000/05.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e54747000394d420000/06.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e68747000394d470000/07.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e71747000394d4b0000/08.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e7b747000394d4f0000/09.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e83747000394d530000/10.jpg"/>
#          </div>
#          <div class="w-ad-banner__slide " data-link="">
#           <img class="w-ad-banner__image" src="/uploads/ad_image/file/54e18e8e747000394d570000/12.jpg"/>
#          </div>
#         </div>
#         <ul class="w-ad-banner__pager">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class="main">
#      <div class="internal">
#       <div class="breadcrumb1" data-pp="11">
#        <div class="widget-breadcrumb widget1" data-subpart-id="54e19704747000394dae0000">
#         <ul class="breadcrumb" data-level="0" data-list="crumbs">
#          <li>
#           <a href="/zh_tw/">
#            首頁
#           </a>
#          </li>
#          <li>
#           <a href="/zh_tw/announcement">
#            公告
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <main data-content="true" id="main-content">
#        <div class="i-annc index-announcement-1">
#         <h3 class="i-annc__page-title">
#          公告
#         </h3>
#         <table class="i-annc__table table table-striped">
#          <thead>
#           <tr>
#            <th class="i-annc__th i-annc__th--date">
#             張貼日期
#            </th>
#            <th class="i-annc__th i-annc__th--title">
#             標題
#            </th>
#           </tr>
#          </thead>
#          <tbody data-level="0" data-list="announcements">
#           <tr>
#            <td>
#             <span class="i-annc__postdate" date-format="%Y-%m-%d">
#              2019-10
#             </a>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <span class="i-annc__postdate" date-format="%Y-%m-%d">
#              2019-10-01
#             </span>
#            </td>
#            <td>
#             <a class="i-annc__title" href="/zh_tw/announcement/%E6%9C%AC%E6%A0%A1%E5%AD%B8%E5%8B%99%E8%99%95%E5%85%AC%E5%91%8A%E7%9B%B8%E9%97%9C%E8%A8%8A%E6%81%AF-26367168">
#              本校學務處公告相關訊息
#             </a>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <span class="i-annc__postdate" date-format="%Y-%m-%d">
#              2019-09-18
#             </span>
#            </td>
#            <td>
#             <a class="i-annc__title" href="/zh_tw/announcement/%5B%E6%89%80%E8%BE%A6%E5%85%AC%E5%91%8A%5D-%E6%89%80%E8%BE%A6%E5%85%AC%E5%AE%A4%E4%B8%8D%E4%BB%A3%E6%94%B6%E5%90%8C%E5%AD%B8%E7%A7%81%E4%BA%BA%E4%BF%A1%E4%BB%B6%E6%88%96%E5%8C%85%E8%A3%B9-99580499">
#              [所辦公告] 所辦公室不代收同學私人信件或包裹
#             </a>
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <span class="i-annc__postdate" date-format="%Y-%m-%d">
#              2019-09-10
#             </span>
#            </td>
#            <td>
#             <a class="i-annc__title" href="/zh_tw/announcement/107%E5%AD%B8%E5%B9%B4%E5%BA%A6-%E5%90%AB-%E4%B9%8B%E5%89%8D%E5%BF%85%E4%BF%AE%E5%8F%8A%E5%BF%85%E9%81%B8%E8%AA%B2%E7%A8%8B%E5%B0%9A%E6%9C%AA%E4%BF%AE%E7%BF%92%E5%AE%8C%E6%88%90%E8%80%85-%E5%9B%A0%E6%87%89%E6%96%B0%E5%88%B6%E8%AA%B2%E7%A8%8B%E5%B0%8D%E6%87%89%E6%96%B9%E5%BC%8F-62905017">
#              107學年度(含)之前必修及必選課程尚未修習完成者，因應新制課程對應方式。
#             </a>
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </div>
#        <ul class="pagination pagination-sm" data-pagination="true">
#         <li class="active">
#          <a href="?page_no=1&amp;">
#           1
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=2&amp;">
#           2
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=3&amp;">
#           3
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=2&amp;">
#           »
#          </a>
#         </li>
#         <li class="">
#          <a href="?page_no=3&amp;">
#           最後
#          </a>
#         </li>
#        </ul>
#       </main>
#      </div>
#     </div>
#     <footer class="footer">
#      <div class="footer-inner">
#       <div class="footer_address">
#        Copyright © 2014 國立臺灣大學國家發展研究所 Graduate Institute of National Development, National Taiwan University
#        <br/>
#        10617 臺北市大安區羅斯福路四段1號 （辛亥復興路口側門進入） No. 1, Sec. 4, Roosevelt Road, Taipei, 10617 Taiwan(R.O.C)
#        <br/>
#        電話 (Phone)：+886-2-3366-3333  傳真 (Fax)：+886-2-2367-6176  E-mail：ndintu@ntu.edu.tw
#       </div>
#       <div class="footer-site-counter">
#        造訪人次 : 722687
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## 公告的時間

# %%
# 公告的時間位於 <span class="i-annc__postdate" date-format="%Y-%m-%d"> ......</span>
list_t=soup.find_all("span", {'class':"i-annc__postdate"})
time=[]
for t in list_t:
    time.append(t.text)
print (time)
# Out:
# [' 2019-10-30', ' 2019-10-28', ' 2019-10-28', ' 2019-10-22', ' 2019-10-18', ' 2019-10-18', ' 2019-10-15', ' 2019-10-01', ' 2019-09-18', ' 2019-09-10']

# %% [markdown]
# ## 公告的標題

# %%
# 經檢查，公告的標題位於 <a class="i-annc__title" href="...">......</a>
list_a=soup.find_all("a", {'class':"i-annc__title"})
title=[]
for a in list_a:
    title.append(a.text)
print (title)
# Out:
# ['108/11/12(二)風險中心舉辦之【鉅變臺灣：啟動臺灣長期能源轉型】論壇活動，歡迎同學
如何整合產、官、學界之資源，加速臺灣能源轉型之腳步。\n\r\n下午場次由風險社會與政策研究中心研究團隊分別就「能源治理革新」與「確立工業節能優先」兩主題進行發表，並邀請到產、官、學界先進與團隊進行與談，期望能就《鉅變臺灣：啟動長期能源轉型》之重點項目進行更多的對話與促進公民參與，研擬各利害相關人可採行的具體行動，共同推動臺灣長期能源轉型。\n\r\n\xa0\n\r\n※本活動提供公務人員學習時數上午場次2小時、下午場次3小時。\n',
#  '\n國發所畢業團拍（107碩士班）\r\n\xa0\n大家好，我們是107級的畢代皓瑋和玥岑，時光飛速，也到了我們107級拍畢業團拍的時間啦！無論大家是否論文有寫完（或有沒有找到老師?!），都先預祝福大家畢業快樂！\n時間上，我們僅統計到10/30午夜十二點哦 !\r\n\xa0\n調查表單：https://docs.google.com/forms/d/1P3AlVEfAihIXWnm2n0DoxzM5rHobpxDtF9J_1OKxoVE/edit\r\n\xa0\n簡單說明一下幾點注意事項：\n1.\u3000我們畢業團拍時間目前需要和其他系協商，畢代會目前給的時間都在六日，因此要麻煩大家勾選出幾個最方便的時間，我們會據此來和他系所協商時間！\n\n2.\u3000畢代會目前針對團拍給出三種方案（有買方案才能參加團拍喔，對方會算人頭）：\r\n\xa0\r\n\n\n\nonly 團拍入鏡 $220元/人\n\n\xa0\n\nB. 團拍入鏡+團照相片組 \xa0$270元/人\n\u3000（可得三張基本組實體相片＋六張照片電子檔）\nC. 團拍夾紀念套組\xa0 $445元/人\n\u3000（可得臺大專屬精緻團拍夾＋內含三張基本組實體相片＋六張數位相片畫面檔案）\n備註：以上方案已含60元行政費\u3000(袍子、領巾租用清洗費、場地費)\r\n\xa0\n詳情及照片請參見：https://docs.google.com/presentation/d/1LnsHOmUIOrwO_KySBW5pZDM6sU_FX3aAvYXiC3C2hmk/edit?copiedFromTrash#slide=id.p9\r\n\xa0\n3. 畢代會目前針對畢冊的購買給出兩種方案\r\n\xa0\r\n\n\n單買校畢冊或班畢冊 800元一本\n\n\n全套購買(校畢冊、班畢冊、專屬提袋、紀念品)\u30001150元\n\n\n\n4. 關於收費部分，我們會等到團拍日期確定後，再發詳細公告，目前暫定是在國發所學會辦公室現場收取現金。\r\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 有任何新訊息我會同時PO在FB的國發所社團中。\r\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 以下是我們的聯絡方式，有任何問題歡迎聯繫我們：\nFB：https://www.facebook.com/profile.php?id=100000104694349\u3000（陳皓瑋）\r\n\u3000\u3000https://www.facebook.com/profile.php?id=100006581208397\u3000（潘玥岑）\r\n\xa0\n  ',
#  '\n\n公告\n\n109學學年度碩士班招生簡章考科異動：乙組(主修中國大陸與東亞研究)選考科目第三科新增「統計學」\n\r\n\xa0\r\n\n\n\n系 所 別\n國家發展研究所碩士班\n國家發展研究所碩士班\n\n\n組\xa0\xa0\xa0 別\n甲組(主修全球化與科技治理)\n乙組(主修中國大陸與東亞研究)\n\n\n身 分 別\n一般生\n一般生\n\n\n招生名額\n正取：25\xa0\xa0\xa0\xa0備取：3\n正取：12\xa0\xa0備取：3\n\n\n考試項目\n筆試\n科目名稱\n一、英文\n二、政治學
#  '\n國立臺灣大學國家發展研究所109學年度碩士班甄試招生\n\n筆試日期：108年10月26日(星期六)\n筆試時間：10:00~11:40\n筆試地點：台大國發所206教室\n台灣大學校總區地址：台北市羅斯福路四段1號(近台灣大學辛亥路與復興南路交叉口警衛室後門入口右手邊第二棟樓)\n連絡電話：02-33663333\n\n筆試試場資訊：\n\n\n\n從台灣大學校總區後門進入：可搭乘捷運文湖線：於捷運科技大樓站下車，沿復興南路往辛亥路方向步行，從辛亥路與復興南路交叉口警衛亭後門進入右邊第二棟樓，步程約10分鐘。\n\n\n從台灣大學校總區正門進入：步程約需20~30分鐘。\n\n\n開車前來者，進入台大校園時需抽取停車卡，於考試完畢後交試務人員核章， 20~30元不等。(依個別停車場標準計算)\n\n\r\n\xa0\n注意事項：\xa0考生請攜帶准考證、身分證、第2階段報名費繳費證明準時到場應試。\n',
#  '\n演講題目：Long-Term Care Policy Development in Japan - Prospect and Challenge\n講者：Dr. Katsuhisa Kojima 小島克久 博士，Director of National Institute of Population and Social Security Research, Japan\n日期：2019年10月25日（星期五）\n時間：10:20-12:20\n地點：R302\n\r\n備註：修課同學不計入學習卡\n',
#  '\n1、108年10月17日(四)所長時間暫停乙次。\r\n2、108年10月21日(一)至10月25日(五)所長出席國際會議暨洽談本所與香港嶺南大學國際學術交流相關事宜，故該週所長時間暫停。\n',
#  '\n大家好：\r\n\xa0\n學務處辦理多項優質活動，歡迎您踴躍參加。\n\n\n\n\n學務處每週公告\n\n\n單位\n主旨\n聯絡人\n\n\n保健中心\n「提升身體優勢力:伸展與肌力運動」講座\xa0\n廖芃慈\r\n\t\t\t33662175\n\n\n保健中心\n\n「遠離菸害、健康無礙」講座\xa0\n\n詹千慧\r\n\t\t\t33662168\n\n\n校安中心\n\n提供反偷拍偵測器供住宿及賃居在外學生借用\xa0\n\n王潤身\r\n\t\t\t33662056\n\n\n生輔組\n\n108學年度優秀青年10月1日截止受理申請\xa0\n\n林奕延\r\n\t\t\t33662050#221\n\n\n\r\n\xa0\n學務處關心您\n',
#  '\n所辦公室不代收同學私人信件或包裹，請同學留意勿將私人信件或包裹寄至所辦公室。謝謝配合。\n',
#  '\n公\xa0 告\n因應本所自108學年度起組別整併為「全球化與科技治理」、「中國大陸與東亞研究」， 107學年度(含)之前必修及必選課程尚未修習完成者，因應新制對應如下：\n\n一、共同必俢課程：維持不變，另舊生可適用新制第二外文規定：「第二外文」(二學期)或「研究生線上英文三」二擇一 (○學分)\xa0\n備註：修習本校開授之第二外文共二學期六學分(不計入畢業學分，大學俢畢可申請學分抵免)。持下列英文測驗二年內成 績單正本至所辦公室辦理認證，通過者得免修「研究生線上英文三」。\r\n(1)多益800分、(2) IELTS 6級、(3) 劍橋大學中等英文認證(FCE)70分、(4)托福(TOEFL)IBT80分或CBT213分\n\n二、各學組必選課程：\r\n1、107學年度(含)之前各學組部份必選課程，自108學年度起調整為選修課程，此部分不適用於舊生。\r\n(舉例：「區域研究方法論專題」課程為107學年度(含)之前當代臺灣組必選課程，但此課程自108學年度起改列為選修課程，若107學年度(含)之前當代臺灣組學生修習此課，亦認列為該組必選課程。)\n\n2、尚未修完之必選課程，可由108學年度各學組開授之必選課程充抵，不限組別。\r\n(說明：舊生若尚有學組必選課程尚未修完，可修習新制兩學組所列必選課程，沒有強制規定必修那一組課程。)\n\n三、跨學組必選課程：跨組課程二門將從寬認定。\r\n\xa0\r\n國發所所辦公室 敬啟\r\n108年9月10日\n']

# %%
import pandas as pd
data=list(zip(time, title, string))
df=pd.DataFrame(data, columns=['time ','title','content'])
df
# Out:
#          time                                               title  \
# 0   2019-10-30  108/11/12(二)風險中心舉辦之【鉅變臺灣：啟動臺灣長期能源轉型】論壇活動，歡迎同學報...
# 1   2019-10-28            【畢業團拍】107學年度碩士班畢業團拍調查表單填報(至108/10/30日止)
# 2   2019-10-28                              【公告】109學年度碩士班招生簡章考科異動
# 3   2019-10-22                            108學年度第1學期生活學習助學金審核結果公告
# 4   2019-10-18             108/10/26(六)109學年度碩士班甄試招生筆試試場：國發所206教室
# 5   2019-10-18  108/10/25 10:20~12:20專題演講，講者：Dr. Katsuhisa Koj...
# 6   2019-10-15  108/10/17所長時間暫停乙次，108/10/21~10/25所長將出席國際會議暨洽談本...
# 7   2019-10-01                                        本校學務處公告相關訊息
# 8   2019-09-18                            [所辦公告] 所辦公室不代收同學私人信件或包裹
# 9   2019-09-10              107學年度(含)之前必修及必選課程尚未修習完成者，因應新制課程對應方式。
#
#                                              content
# 0  \n\n\r\n【鉅變臺灣：啟動臺灣長期能源轉型】論壇\n\r\n時間：11月12日(二)0...
# 1  \n國發所畢業團拍（107碩士班）\r\n \n大家好，我們是107級的畢代皓瑋和玥岑，時光...
# 2  \n\n公告\n\n109學學年度碩士班招生簡章考科異動：乙組(主修中國大陸與東亞研究)選考...
# 3  \n台灣大學國家發展所108學年度第1學期生活學習助學金審核結果公告\n\n通過名單：蔡振輝...
# 4  \n國立臺灣大學國家發展研究所109學年度碩士班甄試招生\n\n筆試日期：108年10月26...
# 5  \n演講題目：Long-Term Care Policy Development in Ja...
# 6  \n1、108年10月17日(四)所長時間暫停乙次。\r\n2、108年10月21日(一)至...
# 7  \n大家好：\r\n \n學務處辦理多項優質活動，歡迎您踴躍參加。\n\n\n\n\n學務處...
# 8    \n所辦公室不代收同學私人信件或包裹，請同學留意勿將私人信件或包裹寄至所辦公室。謝謝配合。\n
# 9  \n公  告\n因應本所自108學年度起組別整併為「全球化與科技治理」、「中國大陸與東亞研究...

# %% [markdown]
# ## 但是我們有好幾頁

# %%
# 檢查每頁的網址結構相似，http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=1& 
# 製作每頁的聯結
time=[]
title=[]
string=[]
for n in range(5):
    #  共有五頁
    url='http://www.nd.ntu.edu.tw/zh_tw/announcement?page_no=' + str(n+1) + '&'     
    response = requests.get (url)
    soup = BeautifulSoup (response.text, "lxml")
    # 時間
    list_t=soup.find_all("span", {'class':"i-annc__postdate"})    
    for t in list_t:
        time.append(t.text)
    # 標題    
    list_a=soup.find_all("a", {'class':"i-annc__title"})
    for a in list_a:
        title.append(a.text)        
    # 內容聯結
    list_a=soup.find_all("a", {'class':"i-annc__title"})
    h='http://www.nd.ntu.edu.tw'
    list_l=[]
    for a in list_a:
        list_l.append(h+a['href'])    
    # 內容
    for l in list_l:
        response = requests.get (l)
        soup_tem = BeautifulSoup (response.text, "lxml")
        add_string=soup_tem.find_all('section',{'class':"s-annc__post-wrap"})[0].text    
        string.append(add_string)
# 3   \n台灣大學國家發展所108學年度第1學期生活學習助學金審核結果公告\n\n通過名單：蔡振輝...
# 4   \n國立臺灣大學國家發展研究所109學年度碩士班甄試招生\n\n筆試日期：108年10月26...
# 5   \n演講題目：Long-Term Care Policy Development in Ja...
# 6   \n1、108年10月17日(四)所長時間暫停乙次。\r\n2、108年10月21日(一)至...
# 7   \n大家好：\r\n \n學務處辦理多項優質活動，歡迎您踴躍參加。\n\n\n\n\n學務處...
# 8     \n所辦公室不代收同學私人信件或包裹，請同學留意勿將私人信件或包裹寄至所辦公室。謝謝配合。\n
# 9   \n公  告\n因應本所自108學年度起組別整併為「全球化與科技治理」、「中國大陸與東亞研究...
# 10                                               \n\n
# 11  \n恭賀本校特聘講座教授暨本所「中國大陸與東亞研究」學組師資，黃俊傑老師獲選為歐洲科學院院士...
# 12  \n國立臺灣大學國家發展研究所  公 告\r\n \r\n \n主旨：公告「黃故教授季陸先生...
# 13                                            \n詳附件\n
# 14  \n屋頂的防水工程今天仍會有工程廢棄物吊運,出入請小心\n\n另外為了清除消防水管及供水管下...
# 15  \n廠商通知今天(6/4)上午10點起前門上方吊運工程廢棄物，為避免吊運碎片掉落造成傷害，請...
# 16  \n廠商於108年5月27日發送防水施工期程及太陽光電發電設備的施工期程如附件，預計於108...
# 17  \n\n講題：全球化的逆襲：反建制主義的興起\n講者：台大政治系黃旻華教授\n時間：5月30...
# 18  \n財團法人中華經濟研究院 與德國基爾世界經濟研究院（Kiel Institute for ...
# 19  \n臺灣大學國家發展研究所108學年度碩士班甄試招生\n\n筆試日期：107年10月27日(...
# 20  \n108學年度各項招生內容異動公告：\n\r\n一、碩士班甄試詳所網頁-碩士班-入學方法 ...
# 21  \n時間：107年5月17日(週四)早上10:20-13:10\r\n地點：國發所R206\...
# 22  \n教育部105年10月19日公布第60屆學術獎及第20屆國家講座得獎名單。本所與中央研究院...
# 23  \n社科院將於以下時間、地點舉行2017/2018 (106學年度) 院級出國交換學生說明會...
# 24  \n社會科學院--國際學位生獎助學金自2016年9月19日起至2016年10月14日止受理申...
# 25  \n\n        為了鼓勵臺大學生善用各項海外教育計畫資源、積極參與出國交換學生計畫，...
# 26  \n\n\n105年度博士班研究室分配結果公告\r\n \n一、【研究室使用期間】：105學...
# 27  \n校方依據菸害防制法第十五條及第十六條規定及大學校園自治規範，規定本校除局部室外場所得設置...

# %% [markdown]
# # 作業

# %% [markdown]
# * 請進入你的標的網頁，檢查網頁的結構，回答以下問題:
# * 1 網址是? 簡單介紹這個網頁。
# * 2 你想下載網頁中的什麼資訊？
# * 3 這些資訊是放在哪個 tag(標籤)，那個attribute(屬性)下面？如果找不到，表示為動態網頁或加密，請換一個簡單的網頁。
# * 4 是否要進去聯結，才可以找到你要的東西?
# * 5 是否有多個分頁，分頁的網址規則是什麼?
# * 6 依上課教的方法，下載資料，整理成 DataFrame 方便閱讀。有碰到什麼困難嗎?
# * 7 記錄你探索過的失敗、無法下載網頁，列出 1,2,3 項。也許其他同學可以幫你解決。
# * 8 交作業時，除了回答上問題，要交 .ipynb 以及下載的資料檔。
