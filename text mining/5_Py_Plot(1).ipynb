# %% [markdown]
# # plot 繪圖

# %% [markdown]
# * 繪圖模組 matplotlib 功能強大，隨anaconda 自動安裝，不需另行安裝。
# * 另外還有一些繪圖模組 seaborn, pygal 與 plotly 亦頗為常用，但需要另行安裝。請同學自行參考。本週我們不介紹。
# * google 均可查得各模組的官方網頁、使用說明、範例。

# %% [markdown]
# ## matplotlib

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib
# 直接繪圖，毋須 plot.show()
# %matplotlib inline  

# 資料夾設定路徑
path = 'C:/Users/HSIU/Desktop/108-1/python_ntu'

# %%
# 中文設定1: 楷體字
from matplotlib import rcParams
rcParams["font.sans-serif"] = ["kaiu"] 
rcParams["font.family"] ="DFKai-sb"

# %%
# 中文設定2: 點體字
from matplotlib import rcParams
rcParams['font.sans-serif'] = ['simhei'] 
rcParams['font.family'] ='sans-serif'

# %% [markdown]
# ## 中文測試，畫三個點，加註中文

# %%
# 三個點，連成線，注意先 X 座標，再 Y 座標
x=[1,2,4,3]
y=[4,3,2,1]

# 圖面大小
plt.figure(figsize=(8,6))

# 繪圖
plt.plot(x,y,'g', marker='o') 

# 加標題
plt.title("點連成線") 
plt.ylabel("縱軸") 
plt.xlabel("橫軸")  

# 座標刻度
plt.xticks([0,1,2,3,4])   # 注意等級數
plt.yticks(np.linspace(0,4,5))  # 與上同，從 0 到 4，取 5 個。 
# plt.yticks(np.arange(0,5,1))  # 亦可，與上同。從 0 到 5，間隔 1。

# 圖面加文字
text=['P1 點一','P2 點二','P3點三','P4點四']

# 加標籤
for i, txt in enumerate(text):
    plt.annotate(txt, [x[i],y[i]], size=15)

plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 40670 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32218 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27243 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 36600 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27243 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36600 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32305 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32305 missing from current font.
#   font.set_text(s, 0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 19968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 40670 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 19968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20108 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22235 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 36899 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\HSIU\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32218 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 如果測試失敗，手動設定
# * C:\Users\user\Anaconda3\Lib\site-packages\matplotlib\mpl-data 目錄，用記事本開啟matplotlibrc
# * 將font.family與font.serif註解(#)移除，約在程式196,207行。
# * font.family，將後面改為 DFKai-sb，
# * font.serif: 後增加 DFKai-sb Serif,
# * 存檔 重新執行python軟體
# * 如果還不行，請參考： https://medium.com/@aitmr1234567890/%E8%A7%A3%E6%B1%BApython-3-matplotlib%E8%88%87seaborn%E8%A6%96%E8%A6%BA%E5%8C%96%E5%A5%97%E4%BB%B6%E4%B8%AD%E6%96%87%E9%A1%AF%E7%A4%BA%E5%95%8F%E9%A1%8C-f7b3773a889b

# %% [markdown]
# ## 中文字型
# * matplotlib 中文字型放在 C:\Users\user\Anaconda3\Lib\site-packages\matplotlib\mpl-data\fonts\ttf
# * windows 系統的字型放在 c:\windows\fonts
# * 同學可打開資料夾，檢查字型。

# %% [markdown]
# # 產生變數供測試，DataFrame

# %%
import matplotlib.pyplot as plt 
# 用 numpy 隨機產生二維的 table
c1= np.sort(np.random.normal(60,10,20))
c2= np.sort(np.random.random(20))*50
c3= np.random.random(20)*10+10
b1 =c1/(c1+c2+c3)*100
b2 =c2/(c1+c2+c3)*100
b3 =c3/(c1+c2+c3)*100
data=list(zip(c1,c2,c3,b1,b2,b3))
# 轉成 DataFrame
df = pd.DataFrame(data, columns=['c1', 'c2','c3','b1','b2','b3']) 
df
# Out:
#            c1         c2         c3         b1         b2         b3
# 0   40.211565   1.658938  19.762289  65.243782   2.691649  32.064569
# 1   46.647668   5.862463  14.259181  69.863934   8.780175  21.355891
# 2   50.459561   8.307072  17.721569  65.970385  10.860592  23.169023
# 3   51.238336  11.046057  19.113519  62.947973  13.570443  23.481584
# 4   52.225867  18.988461  11.960029  62.790828  22.829705  14.379467
# 5   53.680553  23.745379  19.656202  55.293956  24.459061  20.246982
# 6   55.247097  23.960572  14.800313  58.768517  25.487806  15.743677
# 7   56.999656  24.443935  12.465271  60.696781  26.029424  13.273796
# 8   57.112853  26.983142  14.321413  58.031252  27.417042  14.551707
# 9   57.282636  27.636200  19.100549  55.069193  26.568317  18.362490
# 10  58.579288  30.043777  19.333192  54.262059  27.829584  17.908357
# 11  58.829659  30.774560  13.720896  56.936456  29.784201  13.279343
# 12  59.289777  31.206598  14.507662  56.464283  29.719427  13.816290
# 13  60.185730  36.156605  14.975253  54.066685  32.480586  13.452729
# 14  60.548007  36.169640  15.256514  54.073196  32.301773  13.625031
# 15  62.002383  39.354040  11.777303  54.804509  34.785418  10.410073
# 16  62.228276  43.232844  17.224119  50.721893  35.238831  14.039276
# 17  68.069659  46.097012  11.746234  54.060907  36.610236   9.328857
# 18  68.147170  46.396756  16.369920  52.054975  35.440679  12.504346
# 19  71.684948  49.290290  14.910849  52.753707  36.273243  10.973050

# %% [markdown]
# # matplotlib 模組

# %%
import numpy as np
import matplotlib.pyplot as plt
# 中文設定
from matplotlib import rcParams
rcParams['font.sans-serif'] = ['simhei'] 
rcParams['font.family'] ='sans-serif'

# %% [markdown]
# ## 長條圖 .bar()
# ### 三個變數疊加

# %%
N = len(c1)           # 柱子的個數
ind = np.arange(N)    # 柱子的中心點位置
width = 0.8           # 柱子的寬度

plt.figure(figsize=(8,6))    # 圖區大小
# c1, c2 c3 為變數值，前已設定，alpha為透明度，color 為顏色，bottom 為柱子的啟始點
p1 = plt.bar(ind, c1, width, alpha=0.3, color='blue' )   # p1 最下面
p2 = plt.bar(ind, c2, width, bottom=c1, alpha=0.5,color='yellow' )   # 在 c1 值上面疊加
p3 = plt.bar(ind, c3, width, bottom=c1+c2, alpha=0.5,color='green' )  # 在 c1+c2 值上面疊加

plt.ylabel('變數大小')    # 縱軸文字
plt.title('長條圖疊加')   # 標題
plt.xticks(range(0,20))    # 橫軸刻度標籤
plt.yticks(np.arange(0, max(c1)+max(c2)+max(c3), 20))  # 縱軸刻度標籤，從0到最大值，間距20
plt.legend((p1[0], p2[0], p3[0]), ('c1', 'c2','c3'))    # 圖例

plt.show()

# %% [markdown]
# ### 如果不疊加

# %%
N = len(c1)           # 柱子的個數
width = 0.2          # 柱子的寬度
ind1 = np.arange(N)- width    # 柱子的中心點位置
ind2 = np.arange(N)    # 柱子的中心點位置
ind3 = np.arange(N)+ width    # 柱子的中心點位置


plt.figure(figsize=(12,6))    # 圖區大小
# c1, c2 c3 為變數值，前已設定，alpha為透明度，color 為顏色，bottom 為柱子的啟始點
p1 = plt.bar(ind1, c1, width, alpha=0.3, color='blue' )   # p1 最下面
p2 = plt.bar(ind2, c2, width, alpha=0.5,color='yellow' )   # 在 c1 值上面疊加
p3 = plt.bar(ind3, c3, width, alpha=0.5,color='green' )  # 在 c1+c2 值上面疊加

plt.ylabel('變數大小')    # 縱軸文字
plt.title('長條圖疊加')   # 標題
plt.xticks(range(0,20))    # 橫軸刻度標籤
plt.yticks(np.arange(0, max(max(c1),max(c2),max(c3)), 20))  # 縱軸刻度標籤，從0到最大值，間距20
plt.legend((p1[0], p2[0], p3[0]), ('c1', 'c2','c3'))    # 圖例

plt.show()

# %% [markdown]
# ### 加註數字

# %%
N = len(c1)           # 柱子的個數
width = 0.2          # 柱子的寬度
ind1 = np.arange(N)- width    # 柱子的中心點位置
ind2 = np.arange(N)    # 柱子的中心點位置
ind3 = np.arange(N)+ width    # 柱子的中心點位置


plt.figure(figsize=(12,6))    # 圖區大小
# c1, c2 c3 為變數值，前已設定，alpha為透明度，color 為顏色，bottom 為柱子的啟始點
p1 = plt.bar(ind1, c1, width, alpha=0.3, color='blue' )   # p1 最下面
p2 = plt.bar(ind2, c2, width, alpha=0.5,color='yellow' )   # 在 c1 值上面疊加
p3 = plt.bar(ind3, c3, width, alpha=0.5,color='green' )  # 在 c1+c2 值上面疊加

plt.ylabel('變數大小')    # 縱軸文字
plt.title('長條圖疊加')   # 標題
plt.xticks(range(0,20))    # 橫軸刻度標籤
plt.yticks(np.arange(0, max(max(c1),max(c2),max(c3)), 20))  # 縱軸刻度標籤，從0到最大值，間距20
plt.legend((p1[0], p2[0], p3[0]), ('c1', 'c2','c3'))    # 圖例

# 加註數字
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = int(rect.get_height())
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(p1)
autolabel(p2)
autolabel(p3)

plt.show()

# %% [markdown]
# ## 橫向疊加，並加註數字

# %%
names = ['b1', 'b2','b3']
data=dict(df[['b1','b2','b3']].transpose())

def bar_percent(data, category_names):
    # dictionary 取 key 為 labels
    labels = list(data.keys())
    # dictionary 取 values 為 data
    data = np.array(list(data.values()))   
    # 各筆資料總合
    data_cum = data.cumsum(axis=1)
    # 決定類別的顏色
    category_colors = plt.get_cmap('RdYlGn')(np.linspace(0.15, 0.85, data.shape[1]))
    # 圖區大小
    fig, ax = plt.subplots(figsize=(10, 5)) 
    # y 刻度
    ax.set_yticks(range(len(labels)))
    # y 刻度標籤
    ax.set_yticklabels(range(len(labels)))
    # y 由小到大
    ax.invert_yaxis()
    # x 不出現刻度
    ax.xaxis.set_visible(False)
    # 設定 x 範圍
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        # 寬度
        widths = data[:, i]
        # 啟始處，總合減去寬度
        starts = data_cum[:, i] - widths
        # 水平的 bar 繪圖
        ax.barh(labels, widths, left=starts, height=0.7,label=colname, color=color)
        # bar 中點位置
        xcenters = starts + widths / 2
        # 讀取顏色資訊
        r, g, b, _ = color
        # 決定文字顏色，有兩種，白色與灰色
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        # 加入文字
        for y, (x, c) in enumerate(zip(xcenters, widths)):
            ax.text(x, y, str(int(c)), ha='center', va='center',color=text_color)
    # 增加圖例        
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1), loc='lower left', fontsize='small')
    
# 啟動函數
bar_percent(data, names)

# %% [markdown]
# # 折線圖 .plot()

# %%
# 圖區大小
plt.figure(figsize=(8,6))
# 三條線
p1 = plt.plot( c1, color='blue' )
p2 = plt.plot( c2, color='yellow' )
p3 = plt.plot( c3, color='green' )

plt.ylabel('變數')
plt.title('折線圖')
plt.xticks(ind, range(N))
plt.yticks(np.arange(0, max(max(c1),max(c2),max(c3)), 10))
plt.legend((p1[0], p2[0], p3[0]), ('c1', 'c2','c3'))

plt.show()

# %% [markdown]
# ## 增加資料點

# %%
x=range(20)
plt.figure(figsize=(8,6))
# 注意三種常用的線條 與 marker
plt.plot(x, c1, 'r',label="c1",marker='+')  
plt.plot(x, c2, 'g--',label="c2", marker='o')      
plt.plot(x, c3 ,'y.-',label="c3", marker='s')       
plt.legend(loc=0);  
plt.xticks(x)
plt.yticks(np.arange(0,90,10))
plt.xlabel('x')       # X 軸標記 
plt.ylabel('y')       # Y 軸標記
plt.title('title')    # X 標題
plt.show()

# %% [markdown]
# ## stacked area plot 疊加圖

# %%
# 三個變數的疊加圖
y1 = b1
y2 = b2
y3 = b3
# 變數 合併成為 array
y = np.vstack([y1, y2, y3])
# 圖區大小
plt.figure(figsize=(8,6))  
# 繪疊加圖
plt.stackplot(x, y1, y2, y3, labels=["b1 ", "b2", "b3"])
# 標記設定
plt.xticks(x)
plt.xlabel('x')    # X 軸標記 
plt.ylabel('y')    # Y 軸標記
plt.legend(loc='upper left')   # 圖例
plt.title('疊加圖')    # 標題
plt.show()

# %% [markdown]
# # 盒狀圖

# %%
cat=[c1,c2,c3,b1,b2,b3]
plt.figure(figsize=(8,6))
plt.boxplot(cat,labels=['c1','c2','c3','b1','b2','b3'])
plt.title('盒狀圖')    # 標題
plt.show()

# %% [markdown]
# # 圓餅圖

# %%
## pie chart
label=["c1","c2","c3"]
size=[np.average(c1),np.average(c2),np.average(c3) ]
plt.figure(figsize=(6,6))
plt.pie(size, labels=label, autopct='%1.1f%%', shadow=True, startangle=140) 
plt.axis('equal')
plt.show()

# %% [markdown]
# ## 顏色選擇有許多，請參考網站
# * https://www.cnblogs.com/darkknightzh/p/6117528.html

# %% [markdown]
# # 直方圖 Histogram

# %% [markdown]
# ### 單一變數

# %%
bins=10
plt.figure(figsize=(8,6))
plt.hist(c1,bins)
plt.show()

# %% [markdown]
# ### 多變數

# %%
data = [c1, c2, c3]
bins=10
plt.figure(figsize=(8,6))
plt.hist(data,bins,alpha=0.7, label=['c1', 'c2','c3'])
plt.legend(loc=0)
plt.show()

# %% [markdown]
# ### 疊加直方圖

# %%
# 疊加直方圖
bins=10
data=[c1,c2,c3]
plt.figure(figsize=(8,6))
plt.hist(data, bins, histtype='bar', stacked=True, color=['r','b','g'], label=['c1','c2','c3'], alpha=0.5)
plt.legend(prop={'size': 10})
plt.title('疊加直方圖')
plt.show()

# %% [markdown]
# ## 密度圖

# %%
# 密度圖，單一變數
df[['c1']].plot(kind='kde')

# %%
# 密度圖，注意有多個變數
df[['c1','c2','c3']].plot(kind='kde')

# %% [markdown]
# # 散布圖

# %%
plt.figure(figsize=(8,6))
plt.scatter(c1, c3)
plt.title("散佈圖")
plt.xlabel('c1')    # X 軸標記 
plt.ylabel('c3')    # Y 軸標記
# Out:
# Text(0, 0.5, 'c3')

# %% [markdown]
# ### 增加第三、四變數，決定點粒大小及顏色，泡泡圖

# %%
# 散布圖，顏色與大小設定
# matplotlib.rcdefaults() # 回復原始設定，讓底色為白

# X 變數 
x = c1
# Y 變數 
y = c3
color=c2
size=b3*100

plt.figure(figsize=(8,6))
plt.scatter(x, y,s=size, c=color,alpha=0.7)
plt.title("泡泡圖")
plt.xlabel('c1')    # X 軸標記 
plt.ylabel('c3')    # Y 軸標記
# Out:
# Text(0, 0.5, 'c3')

# %% [markdown]
# ##  Y 軸雙刻度

# %%
# 兩個變數折線圖，不同的刻度顯示
fig, ax1 = plt.subplots(figsize=(6,6))
# 藍色 c1
x=range(len(c1))
ax1.plot(x, c1, lw=1, color="blue")    ## plot 1
ax1.set_ylabel("變數c1", fontsize=18, color="blue")
for label in ax1.get_yticklabels():      ##  yticklabels of plot 1
    label.set_color("blue")
    
ax1.set_xticks(range(len(c1)))    
    
# 紅色 c3    
ax2 = ax1.twinx()            ## twinx
ax2.plot(x, c3, lw=1, color="red")      ## plot 2
ax2.set_ylabel("變數c3", fontsize=18, color="red")
for label in ax2.get_yticklabels():       ## yticklabels of plot 2
    label.set_color("red")

# %% [markdown]
# # 時間序列 (當筆數很多)

# %%
import matplotlib.pyplot as plt 
# 用 numpy 隨機產生二維的 table
c1= np.sort(np.random.normal(60,10,100))
c2= np.sort(np.random.random(100))*50
c3= np.random.random(100)*10+10
d1 =c1/(c1+c2+c3)*100
d2 =c2/(c1+c2+c3)*100
d3 =c3/(c1+c2+c3)*100
data=list(zip(c1,c2,c3,d1,d2,d3))
# 轉成 DataFrame
df1 = pd.DataFrame(data, columns=['c1', 'c2','c3','d1','d2','d3']) 
df1
# Out:
#            c1         c2         c3         d1         d2         d3
# 0   40.601886   0.619666  10.070577  79.158122   1.208112  19.633767
# 1   40.791568   0.641896  19.348547  67.111251   1.056063  31.832686
# 2   41.879877   0.714210  10.219713  79.297223   1.352317  19.350460
# 3   42.598992   1.204606  10.780077  78.043467   2.206897  19.749636
# 4   42.966723   1.209275  13.867302  74.025293   2.083401  23.891306
# 5   42.984196   1.217062  17.880121  69.238469   1.960429  28.801102
# 6   43.065427   2.332907  16.487680  69.588304   3.769683  26.642013
# 7   43.093321   3.915892  18.069537  66.217192   6.017159  27.765648
# 8   43.862844   4.428674  15.678674  68.567630   6.923027  24.509343
# 9   44.488868   4.987271  11.611218  72.828275   8.164162  19.007563
# 10  44.751181   5.746466  19.029332  64.365202   8.265089  27.369710
# 11  46.102889   6.461672  15.238852  67.994939   9.530010  22.475051
# 12  46.592086   6.470680  16.101785  67.364113   9.355486  23.280401
# 13  47.241437   7.851130  14.670615  67.716861  11.253973  21.029166
# 99  79.208723  49.250820  15.960034  54.846251  34.102593  11.051157
#
# [100 rows x 6 columns]

# %%
# rolling(10) 前十個平均
plt.figure(figsize=(8,6))
p1 = plt.plot( df1.c1, color='red' )

plt.ylabel('變數')
plt.title('折線圖')
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(40, max(c1), 10))

plt.show()

# %%
# rolling(10) 前十個平均
plt.figure(figsize=(8,6))
p1 = plt.plot( df1.c1.rolling(10).mean(), color='blue' )
p2 = plt.plot( df1.c1, color='red' )

plt.ylabel('Scores')
plt.title('rolling(10)')
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(40, max(c1), 10))
plt.legend((p1[0], p2[0]), ('rolling(10)', 'original'))

plt.show()

# %% [markdown]
# # 練習 ----

# %% [markdown]
# # 聯合報社論 關鍵字與主題
# * 某個主題或事件的時間變化趨勢
# * 不同主題或事件的比較
# * 立場與正反向關鍵字

# %%
import pandas as pd
path='d:/My python/'
dfn=pd.read_pickle(path+"_社論/df_聯合.pkl")
dfn
# Out:
#                                 title  \
# 0           《回顧與展望》系列一時間往前推進，台灣卻仍留在原地
# 1                      王金平案是國家憲政的奇恥大辱
# 2        《回顧與展望》系列三拚經濟的活路：開放與補破網要雙管齊下
# 3     《回顧與展望》系列四蛇尾馬首：兩岸關係的困局與新機\n\n\n
# 4         《回顧與展望》系列五第三勢力正躍躍欲試，或僅止於傳說？
# 5                     甩掉台獨  比推翻一個政權還難
# 6                     大埔案：法律解決與政治解決夾纏
# 7                    勿讓老農津貼淪為「老農版十八趴」
# 8                    熱病或瘟疫：關說案會走向哪一步？
# 9                      民進黨不可在台獨議題上耍盤子
# 10                沉默的器官：請正確對待國軍\n\n\n
# 11                  民怨有成本：ETC勿步歐記健保後塵
# 12                  日本的「偽老人」，台灣的「假農民」
# 13                    漫漫長照：真的太慢，格局也太小
# 14                     圓形的方塊：蘇貞昌回頭搞台獨
# 15                    小公大私：看國會如何濫用立法權
# 16                     總統智囊團不能只有「馬友友」
# 17             為他鳴笛：無言的斷腿是捨身的證據\n\n\n
# 18                   民進黨須慎防挺貪腐的幽靈重現\n
# 19                   馬總統九成七政見達成率是怎麼算的
# 20                       小英登陸的體制外與黑箱內
# 21               非不能也實不為也：政府對ＢＯＴ之過猶不及
# 22                    不容立委在遏堵炒房的堤防上打洞
# 23                      民進黨無法用兩小步跨越深淵
# 24                從鴻海和宏達電內賊案談企業反腐\n\n
# 25                     中國霾害：世界工廠到世界煙囪
# 26                    安倍爭的是個人顏面或國家光榮？
# 27                    胡志強十二年耕耘為何難以交棒？
# 28                       體制空洞化  民進黨危機
# 29                   蛇年甩尾：保二及覆議成功的賀歲禮
# ...                               ...
# 2101                   外交外包美國，斷交催化選票？
# 2102                  全民必將為蔡政府的免費午餐埋單
# 2103                   民進黨立委為何讓選民如此失望
# 2104                郭台銘展開感恩之旅，王金平還在蹭宋
# 2105                從「台灣無用論」看我外交的「兩失」
# 2106                   私菸、私錢，和徇私護短的官員
# 2107                中廣案凸顯追索轉型正義幽靈債的荒謬
# 2123  蔡總統在國慶演說中，強調「中華民國臺灣」是社會最大共識，並回顧七十年來共同經歷過種種嚴峻的挑...  2019-10-14  2019  聯合
# 2124  行政院長蘇貞昌核定的「高鐵南延案」備受質疑，他連日來極力辯解，誇耀自己規劃的遠見與決策的魄力...  2019-10-15  2019  聯合
# 2125  五天內發生三起美食外送員相關的死亡車禍，使這個新興行業的勞動安全受到關注，外送員與外送平臺間...  2019-10-16  2019  聯合
# 2126  僵持了十八個月之後，美中第十三輪貿易談判，在若干議題上取得了共識。川普隨後在白宮接見中方談判...  2019-10-17  2019  聯合
# 2127  歷經南方澳斷橋事件，民眾剛領教了民進黨「高雄幫」及「臺南幫」人馬對臺灣港務航運的低能治理。事...  2019-10-18  2019  聯合
# 2128  民進黨周三的中執會，因人數不足而意外流會。主要原因，是當天預定通過的不分區立委提名委員名單，...  2019-10-19  2019  聯合
# 2129  蔡英文總統才在國慶演說中強調推動國防自主，並提到國造高教機的原型機剛剛出廠，不到一周，立法院...  2019-10-20  2019  聯合
# 2130  在臺殺害女友的香港男子陳同佳近日表示願意來臺投案，港府也稱將安排他來臺受審；誰知蔡政府竟悍然...  2019-10-21  2019  聯合
#
# [2131 rows x 5 columns]

# %%
# 增加年月欄位
ym=[]
for n in range(len(dfn)):
    ym.append(str(dfn.time[n])[:7])
dfn['ym']=ym
dfn
# Out:
#                                 title  \
# 0           《回顧與展望》系列一時間往前推進，台灣卻仍留在原地
# 1                      王金平案是國家憲政的奇恥大辱
# 2        《回顧與展望》系列三拚經濟的活路：開放與補破網要雙管齊下
# 3     《回顧與展望》系列四蛇尾馬首：兩岸關係的困局與新機\n\n\n
# 4         《回顧與展望》系列五第三勢力正躍躍欲試，或僅止於傳說？
# 5                     甩掉台獨  比推翻一個政權還難
# 6                     大埔案：法律解決與政治解決夾纏
# 7                    勿讓老農津貼淪為「老農版十八趴」
# 8                    熱病或瘟疫：關說案會走向哪一步？
# 9                      民進黨不可在台獨議題上耍盤子
# 10                沉默的器官：請正確對待國軍\n\n\n
# 11                  民怨有成本：ETC勿步歐記健保後塵
# 12                  日本的「偽老人」，台灣的「假農民」
# 13                    漫漫長照：真的太慢，格局也太小
# 14                     圓形的方塊：蘇貞昌回頭搞台獨
# 15                    小公大私：看國會如何濫用立法權
# 16                     總統智囊團不能只有「馬友友」
# 17             為他鳴笛：無言的斷腿是捨身的證據\n\n\n
# 18                   民進黨須慎防挺貪腐的幽靈重現\n
# 19                   馬總統九成七政見達成率是怎麼算的
# 20                       小英登陸的體制外與黑箱內
# 21               非不能也實不為也：政府對ＢＯＴ之過猶不及
# 22                    不容立委在遏堵炒房的堤防上打洞
# 23                      民進黨無法用兩小步跨越深淵
# 24                從鴻海和宏達電內賊案談企業反腐\n\n
# 25                     中國霾害：世界工廠到世界煙囪
# 26                    安倍爭的是個人顏面或國家光榮？
# 27                    胡志強十二年耕耘為何難以交棒？
# 28                       體制空洞化  民進黨危機
# 29                   蛇年甩尾：保二及覆議成功的賀歲禮
dfn1.index=range(len(dfn1))
print (len(dfn1))
dfn1
# Out:
# 1028
#                                title  \
# 0                    甩掉台獨  比推翻一個政權還難
# 1                     民進黨不可在台獨議題上耍盤子
# 2                   民進黨須慎防挺貪腐的幽靈重現\n
# 3                       小英登陸的體制外與黑箱內
# 4                       體制空洞化  民進黨危機
# 5                政壇萬馬奔騰 民間百業待興\n\n\n
# 6                    砲打中央：看藍綠菁英的躁動現象
# 7              柯Ｐ是民進黨的迷幻藥？ 或呂秀蓮的紅抹布？
# 8                   蔡英文能解決民進黨的私有化問題？
# 9                     鎖國小確幸  何如開放大宏圖
# 10                   當民進黨只能在青年軍的場邊插花
# 11                 學運為「小英號列車」鋪了最後一哩？
# 12                      蔡英文的最後一哩或回頭路
# 13                       評太陽花的「左派台獨」
# 14                    總統，只換三名副主席是不夠的
# 15                  台獨‧街頭‧暴力：是回潮還是逆流
# 16                 「公民組合」是民進黨的側翼或對手？
# 17                 獻金、公益、集資：社運籌款如何監督
# 18      《馬總統執政六年╱四之一》難道這是一場「葉公好龍」的誤會
# 19    《馬總統執政六年╱四之四》馬英九兩岸政策 有賴藍綠紅共同收尾
# 20                  進一退二：蔡英文與後學運的民進黨
# 21                      概括承受 蔡英文別無他途
# 22                    賴清德代蔡英文宣示兩岸政策？
# 23                 藍綠皆與對岸談和，卻在島內互相廝殺
# 24                    蔡英文對張志軍來訪的六種矛盾
# 25                示範區條例審議的弔詭：朝野戰鬥或合作
# 26                   張志軍登門 民進黨如何借台唱戲
# 27                  朱立倫的抉擇：同志的羈絆大於對手
# 28                     凍獨的路徑：中華民國加台灣
# 29                試問「學生黨工」與「青年顧問」之高下
# ...                              ...
# 998                 郭台銘惡言退黨，信譽豪賭之下下策
# 999                  蔡政府的官場現形記與司改顯影劑
# 1000            李登輝建八萬農業大軍，蔡英文卻養百萬老農
# 1001               連斷六國，蔡英文的兩岸政策是無底洞
# 1002               蔡英文論文五大疑點，光提告無法釋疑
# 1003                  外交外包美國，斷交催化選票？
# 1004                 全民必將為蔡政府的免費午餐埋單
# 1005                  民進黨立委為何讓選民如此失望
# 1006               從「台灣無用論」看我外交的「兩失」
# 1007                  私菸、私錢，和徇私護短的官員
# 1008               國民黨整合之路：勿勾勾纏，先去藩籬
# 1009                「台灣派對」：失去群眾的民進黨慶
# 1010                民進黨吃相貪婪，不准任何人恥笑！
# 1011              南方澳跨港大橋垮塌，會不會只痛一天？
# 1012              二○二○大選的「母雞」與「小雞」亂象
# 1013             高鐵南延，蘇貞昌輾碎專業制度與文官價值
# 1014              蔡政府拿勇消的命作農地違章工廠續命丹
# 1015                虛構的亡國感，將成葬送民主的笛音
# 1016                 沒有人關心真相的南方澳斷橋事件
# 1017                 從陳吉仲的墮落，看民進黨的墮落
# 1018                 拜託，法律不是執政者的政治工具
# 1019               血統純正的斷橋肥貓透露了什麼訊息？
# 1020                     長照大撒幣，選票大勒贖
# 1021                妾國外交：美日膝下撐不起台灣尊嚴
# 1022               蔡英文記起八二三，卻遺忘了國家歷史
# 1023             民進黨把國營事業當禁臠，百姓隨人顧性命
# 1026  民進黨周三的中執會，因人數不足而意外流會。主要原因，是當天預定通過的不分區立委提名委員名單，...  2019-10-19  2019  聯合
# 1027  蔡英文總統才在國慶演說中強調推動國防自主，並提到國造高教機的原型機剛剛出廠，不到一周，立法院...  2019-10-20  2019  聯合
#
#            ym
# 0     2014-01
# 1     2014-01
# 2     2014-01
# 3     2014-01
# 4     2014-01
# 5     2014-02
# 6     2014-02
# 7     2014-02
# 8     2014-03
# 9     2014-04
# 10    2014-04
# 11    2014-04
# 12    2014-04
# 13    2014-04
# 14    2014-05
# 15    2014-05
# 16    2014-05
# 17    2014-05
# 18    2014-05
# 19    2014-05
# 20    2014-05
# 21    2014-06
# 22    2014-06
# 23    2014-06
# 24    2014-06
# 25    2014-06
# 26    2014-06
# 27    2014-06
# 28    2014-07
# 29    2014-07
# ...       ...
# 998   2019-09
# 999   2019-09
# 1000  2019-09
# 1001  2019-09
# 1002  2019-09
# 1003  2019-09
# 1004  2019-09
# 1005  2019-09
# 1006  2019-09
# 1007  2019-09
# 1008  2019-09
# 1009  2019-10
# 1010  2019-10
# 1011  2019-10
# 1012  2019-10
# 1013  2019-10
# 1014  2019-10
# 1015  2019-10
# 1016  2019-10
# 1017  2019-10
# 1018  2019-10
# 1019  2019-10
# 1020  2019-10
# 1021  2019-10
# 1022  2019-10
# 1023  2019-10
# 1024  2019-10
# 1025  2019-10
# 1026  2019-10
# 1027  2019-10
#
# [1028 rows x 6 columns]

# %% [markdown]
# ## 策略二、逐筆計算關鍵字的頻率

# %%
topic= ['民主','自由','憲法','法治','人權','民意','選舉','中華民國','政黨輪替']
find=[]
for s in range(len(dfn)):     
    amount=0 
    for k in topic:         
        count=dfn.content[s].count(k,0)
        amount+=count
    find.append(amount) 
dfn['民主']=find
dfn
# Out:
#                                 title  \
# 0           《回顧與展望》系列一時間往前推進，台灣卻仍留在原地
# 1                      王金平案是國家憲政的奇恥大辱
# 2        《回顧與展望》系列三拚經濟的活路：開放與補破網要雙管齊下
# 3     《回顧與展望》系列四蛇尾馬首：兩岸關係的困局與新機\n\n\n
# 4         《回顧與展望》系列五第三勢力正躍躍欲試，或僅止於傳說？
# 5                     甩掉台獨  比推翻一個政權還難
# 6                     大埔案：法律解決與政治解決夾纏
# 7                    勿讓老農津貼淪為「老農版十八趴」
# 8                    熱病或瘟疫：關說案會走向哪一步？
# 9                      民進黨不可在台獨議題上耍盤子
# 10                沉默的器官：請正確對待國軍\n\n\n
# 11                  民怨有成本：ETC勿步歐記健保後塵
# 12                  日本的「偽老人」，台灣的「假農民」
# 13                    漫漫長照：真的太慢，格局也太小
# 14                     圓形的方塊：蘇貞昌回頭搞台獨
# 15                    小公大私：看國會如何濫用立法權
# 16                     總統智囊團不能只有「馬友友」
# 17             為他鳴笛：無言的斷腿是捨身的證據\n\n\n
# 18                   民進黨須慎防挺貪腐的幽靈重現\n
# 19                   馬總統九成七政見達成率是怎麼算的
# 20                       小英登陸的體制外與黑箱內
# 21               非不能也實不為也：政府對ＢＯＴ之過猶不及
# 22                    不容立委在遏堵炒房的堤防上打洞
# 2117  2019-10    6
# 2118  2019-10    9
# 2119  2019-10   64
# 2120  2019-10    3
# 2121  2019-10    2
# 2122  2019-10   15
# 2123  2019-10  116
# 2124  2019-10    6
# 2125  2019-10    0
# 2126  2019-10    6
# 2127  2019-10    0
# 2128  2019-10   17
# 2129  2019-10   12
# 2130  2019-10   44
#
# [2131 rows x 7 columns]

# %%
topics=['生活水準','財富','競爭力','貨幣','成長','貿易','發展','經濟']
find=[]
for s in range(len(dfn)):     
    amount=0 
    for k in topics:         
        count=dfn.content[s].count(k,0)
        amount+=count
    find.append(amount) 
dfn['經濟']=find
dfn
# Out:
#                                 title  \
# 0           《回顧與展望》系列一時間往前推進，台灣卻仍留在原地
# 1                      王金平案是國家憲政的奇恥大辱
# 2        《回顧與展望》系列三拚經濟的活路：開放與補破網要雙管齊下
# 3     《回顧與展望》系列四蛇尾馬首：兩岸關係的困局與新機\n\n\n
# 4         《回顧與展望》系列五第三勢力正躍躍欲試，或僅止於傳說？
# 5                     甩掉台獨  比推翻一個政權還難
# 6                     大埔案：法律解決與政治解決夾纏
# 7                    勿讓老農津貼淪為「老農版十八趴」
# 8                    熱病或瘟疫：關說案會走向哪一步？
# 9                      民進黨不可在台獨議題上耍盤子
# 10                沉默的器官：請正確對待國軍\n\n\n
# 11                  民怨有成本：ETC勿步歐記健保後塵
# 12                  日本的「偽老人」，台灣的「假農民」
# 13                    漫漫長照：真的太慢，格局也太小
# 14                     圓形的方塊：蘇貞昌回頭搞台獨
# 15                    小公大私：看國會如何濫用立法權
# 16                     總統智囊團不能只有「馬友友」
# 17             為他鳴笛：無言的斷腿是捨身的證據\n\n\n
# 18                   民進黨須慎防挺貪腐的幽靈重現\n
# 19                   馬總統九成七政見達成率是怎麼算的
# 20                       小英登陸的體制外與黑箱內
# 21               非不能也實不為也：政府對ＢＯＴ之過猶不及
# 22                    不容立委在遏堵炒房的堤防上打洞
# 23                      民進黨無法用兩小步跨越深淵
# 24                從鴻海和宏達電內賊案談企業反腐\n\n
# 25                     中國霾害：世界工廠到世界煙囪
# 26                    安倍爭的是個人顏面或國家光榮？
# 27                    胡志強十二年耕耘為何難以交棒？
# 28                       體制空洞化  民進黨危機
# 29                   蛇年甩尾：保二及覆議成功的賀歲禮
# ...                               ...
# 2101                   外交外包美國，斷交催化選票？
# 2102                  全民必將為蔡政府的免費午餐埋單
# 2103                   民進黨立委為何讓選民如此失望
# 2104                郭台銘展開感恩之旅，王金平還在蹭宋
# 2105                從「台灣無用論」看我外交的「兩失」
# 2106                   私菸、私錢，和徇私護短的官員
# 2107                中廣案凸顯追索轉型正義幽靈債的荒謬
# 2108                  極端氣候常態化，台灣沒有豁免權
# 2109                國民黨整合之路：勿勾勾纏，先去藩籬
# 2110                 「台灣派對」：失去群眾的民進黨慶
# 2111                 民進黨吃相貪婪，不准任何人恥笑！
# 2112               南方澳跨港大橋垮塌，會不會只痛一天？
# 2113               二○二○大選的「母雞」與「小雞」亂象
# 2114              高鐵南延，蘇貞昌輾碎專業制度與文官價值
# 2115               蔡政府拿勇消的命作農地違章工廠續命丹
# 2125  五天內發生三起美食外送員相關的死亡車禍，使這個新興行業的勞動安全受到關注，外送員與外送平臺間...  2019-10-16  2019  聯合
# 2126  僵持了十八個月之後，美中第十三輪貿易談判，在若干議題上取得了共識。川普隨後在白宮接見中方談判...  2019-10-17  2019  聯合
# 2127  歷經南方澳斷橋事件，民眾剛領教了民進黨「高雄幫」及「臺南幫」人馬對臺灣港務航運的低能治理。事...  2019-10-18  2019  聯合
# 2128  民進黨周三的中執會，因人數不足而意外流會。主要原因，是當天預定通過的不分區立委提名委員名單，...  2019-10-19  2019  聯合
# 2129  蔡英文總統才在國慶演說中強調推動國防自主，並提到國造高教機的原型機剛剛出廠，不到一周，立法院...  2019-10-20  2019  聯合
# 2130  在臺殺害女友的香港男子陳同佳近日表示願意來臺投案，港府也稱將安排他來臺受審；誰知蔡政府竟悍然...  2019-10-21  2019  聯合
#
#            ym   民主   經濟
# 0     2014-01   12   31
# 1     2014-01   29    0
# 2     2014-01   24  157
# 3     2014-01   22   59
# 4     2014-01   14    6
# 5     2014-01   56    0
# 6     2014-01    2    0
# 7     2014-01    3   19
# 8     2014-01    6   11
# 9     2014-01   52    7
# 10    2014-01   16    9
# 11    2014-01   10    0
# 12    2014-01    6   11
# 13    2014-01    0   21
# 14    2014-01   88    7
# 15    2014-01   10    4
# 16    2014-01    7   12
# 17    2014-01    0    0
# 18    2014-01   31    0
# 19    2014-01    0   26
# 20    2014-01   21   12
# 21    2014-01    0    0
# 22    2014-01    1    0
# 23    2014-01  238    0
# 24    2014-01    5    0
# 25    2014-01    0   16
# 26    2014-01   25   22
# 27    2014-01   18    0
# 28    2014-01   13    0
# 29    2014-01   11   58
# ...       ...  ...  ...
# 2101  2019-09   28    0
# 2102  2019-09    7   50
# 2103  2019-09   30    6
# 2104  2019-09    0    0
# 2105  2019-09    3   27
# 2106  2019-09    5    0
# 2107  2019-09   15   12
# 2108  2019-09    0    9
# 2109  2019-09    0   16
# 2110  2019-10   12    8
# 2111  2019-10   31    0
# 2112  2019-10    0    0
# 2113  2019-10   32    0
# 2114  2019-10   28   20
# 2115  2019-10    0   21
# 2116  2019-10   57    2
# 2117  2019-10    6    0
# 2118  2019-10    9   11
# 2119  2019-10   64    0
# 2120  2019-10    3   28
# 2121  2019-10    2    0
# 2122  2019-10   15    0
# 2123  2019-10  116   27
# 2124  2019-10    6    0
# 2125  2019-10    0   13
# 2126  2019-10    6   32
# 2127  2019-10    0   10
# 2128  2019-10   17    0
# 2129  2019-10   12    0
# 2130  2019-10   44    0
#
# [2131 rows x 8 columns]

# %% [markdown]
# ## 依月份統計篇數

# %%
month=["2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12",
       "2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12",
      "2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12",
      "2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12",
      "2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12",
      "2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09"]
count=[]
for m in month:
    temp=dfn[(dfn.ym==m)].民主.sum()
    count.append(temp)
# 注意要將 type methok 轉成 numeric    
民主=pd.to_numeric(count) 

count=[]
for m in month:
    temp=dfn[(dfn.ym==m)].經濟.sum()
    count.append(temp)
# 注意要將 type methok 轉成 numeric    
經濟=pd.to_numeric(count)

# %%
## 時間趨勢
import matplotlib.pyplot as plt 
# 中文設定
from matplotlib import rcParams
rcParams["font.sans-serif"] = ["kaiu"] 
rcParams["font.family"] ="DFKai-sb"

# 加標題，圖例，x軸，y軸
fig, ax = plt.subplots(figsize=(20,10))
# 設定顏色，圖例，線的型態，標記
x=month
#.rolling(5).mean()
ax.plot(x, 民主, label='民主')       
ax.plot(x, 經濟, label='經濟')    

# 加年度線
# 年度線的位置
markx=[1,13,25,37,49,61]

# 年度線的高度
marky=1600
for m in markx:
    plt.plot([m,m],[0,1600],'gray') 

# 圖面加文字
text=["2014","2015","2016","2017","2018","2019"]
      
# 加標籤
for i, txt in enumerate(text):
    plt.annotate(txt, [markx[i],marky], size=15)


# 圖例位置由程式自己決定
ax.legend(loc=0);  
ax.set_xlabel('month')     # X label
ax.set_ylabel('count')    # y lobel
# 每隔半年一個標記
ax.set_xticks(np.arange(0,len(month),6))

# 標題
ax.set_title('民主與經濟 by month');   # title
plt.show()

# %% [markdown]
# # 兩張圖併列 subplots()

# %%
# 圖形共有一列，每列二個，圖形大小設定
fig, axes = plt.subplots(1, 2, figsize=(10,4))

# 第一個圖  axes[0]
p1 = axes[0].plot( df1.d1.rolling(10).mean(), color='blue' )
p2 = axes[0].plot( df1.d2.rolling(10).mean(), color='yellow' )
p3 = axes[0].plot( df1.d3.rolling(10).mean(), color='green' )
axes[0].set_ylabel('Scores')
axes[0].set_title('折線圖')
axes[0].set_xticks(np.arange(0,100,10))
axes[0].set_yticks(np.arange(0, max(max(c1),max(c2),max(c3)), 10))
axes[0].legend((p1[0], p2[0], p3[0]), ('d1', 'd2','d3')) 
axes[0].set_title("折線圖")

# 第二個圖  axes[1]
d1=df1.d1.rolling(10).mean()
d2=df1.d2.rolling(10).mean()
d3=df1.d3.rolling(10).mean()
axes[1].stackplot(range(100), d1, d2, d3, labels=["d1 ", "d2", "d3"])
axes[1].set_xticks(np.arange(0,100,10))
axes[1].set_xlabel('x')    # X 軸標記 
axes[1].set_ylabel('y')    # Y 軸標記
axes[1].legend(loc='upper left')
axes[1].set_title('疊加圖')    # 標題
# Out:
# Text(0.5, 1.0, '疊加圖')

# %% [markdown]
# # 四張圖併列

# %%
# 圖形共有二列，每列二個，圖形大小設定
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,8))
ax0, ax1, ax2, ax3 = axes.flatten()

# 變數
x = c1
x2 = c2
xs=[x,x2]
num_bins=20

# 長條圖
ax0.bar(range(len(c1)), c1,alpha=0.3,color='blue' )
ax0.set_title('bar chart')

# 折線圖
ax1.plot(range(len(c1)), c1,alpha=0.3,color='green' )
ax1.set_title('line')

# 直方圖 
ax2.hist(c1, 20, color=['r'], label=['c1'], alpha=0.5)
ax2.set_title('histogram')

# 圓餅圖

label=["c1","c2","c3"]
size=[np.average(c1),np.average(c2),np.average(c3) ]
ax3.pie(size, labels=label, autopct='%1.1f%%', shadow=False, startangle=140) 
ax3.axis('equal')
ax3.set_title('pi chart')

fig.tight_layout()
plt.show()

# %% [markdown]
# # 網格圖形
# * https://scipy-cookbook.readthedocs.io/items/idx_matplotlib.html

# %% [markdown]
# ## np.meshgrid(x,y)

# %%
# 由 x y 決定 Z
def cal_z(x, y):
    cal=np.cos(y/10)*(x*y)**.5-x*0.3
    return cal

#製作一個網格，定義 x, y
x = np.linspace(1, 10, 100)
y = np.linspace(1, 10, 100)

# 由 x,y 構成網格
X,Y = np.meshgrid(x, y)

# 計算網格每一點的 z值
Z = cal_z(X, Y)

# 散布圖，顏色與大小設定
matplotlib.rcdefaults() # 回復原始設定，讓底色為白
fig, ax = plt.subplots(figsize=(8,8))

ax.set_title("scatter")

# 散佈圖，顏色愈淺，數字愈大
ax.scatter(X, Y,c=Z)

cmap=matplotlib.cm.Purples_r         # 紅藍反向
p = ax.pcolor(X, Y, Z, cmap=cmap, vmin=Z.min(), vmax=Z.max())

cb = fig.colorbar(p, ax=ax)

# %% [markdown]
# ## 選擇不同的顏色 matplotlib.cm.

# %%
fig, ax = plt.subplots(figsize=(8,6))
# 顏色設定
#cmap=matplotlib.cm.gist_yarg_r   # 黑白
cmap=matplotlib.cm.RdBu_r         # 紅藍反向
#cmap=matplotlib.cm.RdYlBu         # 紅黃藍
p = ax.pcolor(X, Y, Z, cmap=cmap, vmin=Z.min(), vmax=Z.max())
cb = fig.colorbar(p, ax=ax)

# %% [markdown]
# ## possible color
# .Possible values are: Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Vega10, Vega10_r, Vega20, Vega20_r, Vega20b, Vega20b_r, Vega20c, Vega20c_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spectral, spectral_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, viridis, viridis_r, winter, winter_r

# %% [markdown]
# ## 雷達圖

# %%
# 中文設定
from matplotlib import rcParams
# 中文設定
rcParams["font.sans-serif"] = ["kaiu"] 
rcParams["font.family"] ="DFKai-sb"

# ggplot繪圖風格
plt.style.use('ggplot')

# 兩個個案比較，可多個比較，五個構面 *******
values = [3.2,2.1,3.5,2.8,3.2]
values2 = [4.9,4.1,4.5,5,4.1]
feature = ['構面一','構面二','構面三','構面四','構面五']

# 構面個數
N = len(values)

# 角度設定
angles=np.linspace(0, 2*np.pi, N, endpoint=False)

# 使圖形封閉
values=np.concatenate((values,[values[0]]))
values2=np.concatenate((values2,[values2[0]]))
angles=np.concatenate((angles,[angles[0]]))

# 繪圖，設定圖面大小
fig=plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, polar=True)

# 第一條折線圖
ax.plot(angles, values, 'o-', linewidth=2, label = '個案一')
# 顏色
ax.fill(angles, values, alpha=0.25)

# 第二條折線圖
ax.plot(angles, values2, 'o-', linewidth=2, label = '個案二')
# 顏色
ax.fill(angles, values2, alpha=0.25)

# 標籤
ax.set_thetagrids(angles * 180/np.pi, feature)

# 範圍
ax.set_ylim(0,5)

# 標題
plt.title('個案一與個案二在五個構面上的比較')

# 網格線
ax.grid(True)

# 圖例
plt.legend(loc = 'best')

# 顯示圖形
plt.show()

# %% [markdown]
# # 作業 比較 兩篇文章的雷達圖
# * 先要找出分析的構面(主題、立場......)，思考要怎麼定義這些構面，除了用關鍵字，還是有其他方法嗎？
# * 計算在各構面上的變數值。關鍵字出現的次數(比例，有提到關鍵字的句子除以總共的句子) 調整成 5個等級，代表構面強度。
# * 繪製雷達圖
